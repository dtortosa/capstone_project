# %% [markdown]
# # Processing Twitter sentiment

# %%
#set the working directory
import os
os.chdir("/media/dftortosa/Windows/Users/dftor/Documents/diego_docs/industry/data_incubator/capstone_project/")

#check
os.getcwd()
# Out:
# '/media/dftortosa/Windows/Users/dftor/Documents/diego_docs/industry/data_incubator/capstone_project'

# %% [markdown]
# ## Loading tweet data

# %% [markdown]
# We include tweets about the BCE, which is the entity in charge of protecting the value of the euro, but also tweets about debt crisis in Europe, because this can negatively impact the expectations around the euro. Also tweets about the economy of Europe, because this can influence the expectations of economic agents around the Euro. Specially relevant those countries with sovereing debt problems. I have included countries that experienced high interest rates during the 2008 economic crisis (above 6%, e.g., Spain or Greece; [link](https://en.wikipedia.org/wiki/File:Long-term_interest_rates_(eurozone).png)) and countries that currently having a percentage of debt respect GDP above 85.8%, which is the average of the Euro area ([link](https://www.statista.com/statistics/269684/national-debt-in-eu-countries-in-relation-to-gross-domestic-product-gdp/)). This is specially relevant because the BCE not only acts to preserve the value of the euro but to avoid the bankruptcy of the members states, and both goals can be incompatible in certain circumstances (e.g., buy EU debt when at the same time you have to fight against inflation raising the interest rates). It is worth to mention that the Euros can be seen as liabilities that it has respect to those having euros. Of course, today we do not have gold standard, so we cannot go to the ECB ansd ask for an exchange in gold. However, the ECB has a mandate to control the value of the Euro so those with Euros will not lose value, because of this, there is a goal of 2% inflation per year, that is the limit. For example, if for eany reason there is an increase of inflation (e.g., due to high energy prices), the ECB should use its assets to buy Euros and hence remove them from circulation, this would decrease the offer of Euros, and hence increase the value of the currency. But what happens if the ECB has not enough assets to compensate? or he has assets of low quality like for example bonds from European countries with debt problems? The ECB could have difficulties to use gain capitalization through these assets and use it to stabilize Euro's value. The economic agents know this because they can see the balance of the ECB, and they can decide to go away from Euro. This sentiment of the economic agents for the Euro is what I am trying to catch here, using twitter for that.

# %% [markdown]
# I am interested in the expectations of the economic agents about the Euro. If mane economic agents think and act in the same way, this is going to influence the demand and value of the currenct. For example, selling their euros because they expect a devaluation of the currency in the near future due to low confidence in Europe's economy. I am trying to capture the echoes of these expectations in twitter.
#
# This would be relevant for any componay interested in the prediction of currencies. If the consideration of the sentiment aroung the currency can help to improve predictions, they could do more advantageous trades. For example, for an american company doing business in Europe.

# %%
#read json files about BCE
import pandas as pd
ecb_search = pd.read_json("data/json_files/search_euro_bank_twitter_1999_1_1.json", lines=True)
ecb_hashtag = pd.read_json("data/json_files/hashtag_euro_bank_twitter_1999_1_1.json", lines=True)

# %% [markdown]
# We are loading the json files with the tweets as pandas data.frames:

# %%
ecb_search
# Out:
#                                  _type  \
# 0       snscrape.modules.twitter.Tweet
# 1       snscrape.modules.twitter.Tweet
# 2       snscrape.modules.twitter.Tweet
# 3       snscrape.modules.twitter.Tweet
# 4       snscrape.modules.twitter.Tweet
# ...                                ...
# 474268  snscrape.modules.twitter.Tweet
# 474269  snscrape.modules.twitter.Tweet
# 474270  snscrape.modules.twitter.Tweet
# 474271  snscrape.modules.twitter.Tweet
# 474272  snscrape.modules.twitter.Tweet
#
#                                                       url  \
# 0       https://twitter.com/Andy_Sayad/status/15484534...
# 1       https://twitter.com/rockisland48/status/154844...
# 2       https://twitter.com/unbanksyETH/status/1548448...
# 3       https://twitter.com/P_CryptoCoin/status/154844...
# 4       https://twitter.com/mendohenriques/status/1548...
# ...                                                   ...
# 474268        https://twitter.com/BBCWorld/status/5929582
# 474269     https://twitter.com/BBCBusiness/status/5909477
# 474270     https://twitter.com/BBCBusiness/status/5369405
# 474271        https://twitter.com/BBCWorld/status/5369342
# 474272     https://twitter.com/BBCBusiness/status/2622813
#
#                             date  \
# 0      2022-07-16 23:44:10+00:00
# 1      2022-07-16 23:29:21+00:00
# 2      2022-07-16 23:22:47+00:00
# 3      2022-07-16 23:02:47+00:00
# 4      2022-07-16 22:50:03+00:00
# ...                          ...
# 474268 2007-03-08 12:52:14+00:00
# 474269 2007-03-07 18:10:33+00:00
# 474270 2007-02-08 13:00:17+00:00
# 474271 2007-02-08 12:51:03+00:00
# 474272 2007-01-11 12:50:45+00:00
#
#                                                rawContent  \
# 0       🔥🔥🔥Less than a week left till July 21. All Eur...
# 1       @AnanSeven1 Not really. His strg sanc’s agst P...
# 2       QE almost guaranteed (if not already) to be in...
# 3       European Central Bank hints at PoW-based crypt...
# 4       Opponents of embattled PM Mario Draghi are doi...
# ...                                                   ...
# 474268  The European Central Bank raises its key inter...
# 474269  The European Central Bank is expected to raise...
# 474270  The European Central Bank keeps its key intere...
# 474271  The European Central Bank keeps its key intere...
# 474272  The European Central Bank   keeps its key euro...
#
#                                           renderedContent  \
# 0       🔥🔥🔥Less than a week left till July 21. All Eur...
# 1       @AnanSeven1 Not really. His strg sanc’s agst P...
# 2       QE almost guaranteed (if not already) to be in...
# 3       European Central Bank hints at PoW-based crypt...
# 4       Opponents of embattled PM Mario Draghi are doi...
# ...                                                   ...
# 474268  The European Central Bank raises its key inter...
# 474269  The European Central Bank is expected to raise...
# 474270  The European Central Bank keeps its key intere...
# 474271  The European Central Bank keeps its key intere...
# 474272  The European Central Bank   keeps its key euro...
#
#                          id  \
# 0       1548453468989693952
# 1       1548449741373001728
# 2       1548448085549862913
# 3       1548443053580378114
# 4       1548439848188489728
# ...                     ...
# 474268              5929582
# 474269              5909477
# 474270              5369405
# 474271              5369342
# 474272              2622813
#
#                                                      user  replyCount  \
# 0       {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 1       {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 2       {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 3       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 4       {'_type': 'snscrape.modules.twitter.User', 'us...           0
# ...                                                   ...         ...
# 474268  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 474269  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 474270  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 474271  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 474272  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#         retweetCount  likeCount  ...  retweetedTweet  \
# 0                  0          2  ...             NaN
# 1                  0          1  ...             NaN
# 2                  0          3  ...             NaN
# 3                  0          0  ...             NaN
# 4                  1          1  ...             NaN
# ...              ...        ...  ...             ...
# 474268             0          0  ...             NaN
# 474269             0          0  ...             NaN
# 474270             0          0  ...             NaN
# 474271             0          0  ...             NaN
# 474272             1          0  ...             NaN
#
#                                               quotedTweet inReplyToTweetId  \
# 0                                                    None              NaN
# 1                                                    None     1.548427e+18
# 2       {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
# 3                                                    None              NaN
# 4                                                    None              NaN
# ...                                                   ...              ...
# 474268                                               None              NaN
# 474269                                               None              NaN
# 474270                                               None              NaN
# 474271                                               None              NaN
# 474272                                               None              NaN
#
#                                             inReplyToUser  \
# 0                                                    None
# 1       {'_type': 'snscrape.modules.twitter.User', 'us...
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 474268                                               None
# 474269                                               None
# 474270                                               None
# 474271                                               None
# 474272                                               None
#
#                                            mentionedUsers coordinates place  \
# 0                                                    None        None  None
# 1       [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
# 2                                                    None        None  None
# 3                                                    None        None  None
# 4                                                    None        None  None
# ...                                                   ...         ...   ...
# 474268                                               None        None  None
# 474269                                               None        None  None
# 474270                                               None        None  None
# 474271                                               None        None  None
# 474272                                               None        None  None
#
#              hashtags  cashtags  \
# 0       [Nordstream1]      None
# 1                None      None
# 2                None      None
# 3                None      None
# 4                None      None
# ...               ...       ...
# 474268           None      None
# 474269           None      None
# 474270           None      None
# 474271           None      None
# 474272           None      None
#
#                                                      card
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3       {'_type': 'snscrape.modules.twitter.SummaryCar...
# 4                                                    None
# ...                                                   ...
# 474268                                               None
# 474269                                               None
# 474270                                               None
# 474271                                               None
# 474272                                               None
#
# [474273 rows x 28 columns]

# %%
#read json files about debt crisis and European economy
debt_crisis_search = pd.read_json("data/json_files/search_eu_debt_crisis_twitter_1999_1_1.json", lines=True)
eu_economy_search = pd.read_json("data/json_files/search_european_union_economy_twitter_1999_1_1.json", lines=True)

# %%
#read json files about the economy of specific European countries that had debt problems at some point
    #https://en.wikipedia.org/wiki/European_debt_crisis
iceland_economy_search = pd.read_json("data/json_files/search_iceland_economy_twitter_1999_1_1.json", lines=True)
portugal_economy_search = pd.read_json("data/json_files/search_portugal_economy_twitter_1999_1_1.json", lines=True)
italy_economy_search = pd.read_json("data/json_files/search_italy_economy_twitter_1999_1_1.json", lines=True)
ireland_economy_search = pd.read_json("data/json_files/search_ireland_economy_twitter_1999_1_1.json", lines=True)
greece_economy_search = pd.read_json("data/json_files/search_greece_economy_twitter_1999_1_1.json", lines=True)
spain_economy_search = pd.read_json("data/json_files/search_spain_economy_twitter_1999_1_1.json", lines=True)
cyprus_economy_search = pd.read_json("data/json_files/search_cyprus_economy_twitter_1999_1_1.json", lines=True)
slovenia_economy_search = pd.read_json("data/json_files/search_slovenia_economy_twitter_1999_1_1.json", lines=True)
france_economy_search = pd.read_json("data/json_files/search_france_economy_twitter_1999_1_1.json", lines=True)
belgium_economy_search = pd.read_json("data/json_files/search_belgium_economy_twitter_1999_1_1.json", lines=True)
croatia_economy_search = pd.read_json("data/json_files/search_croatia_economy_twitter_1999_1_1.json", lines=True)

# %% [markdown]
# We are going to use also tweets about the different presidents of the ECB during their mandate. This can be another proxy of the sentiment around the institution in charge of preserving the value of the Euro. We only consider tweet for the time window they were presidents of the ECB.

# %%
trichet_search = pd.read_json("data/json_files/search_trichet_twitter.json", lines=True)
    #searches for Draghi and Lagarde do not work

# %% [markdown]
# We are not using tweets about the USD because it is possible that the demand of US dollars increases (e.g., due to fears of recession and the corresponding search for safe heavens as it still has this reputation), but at the same time people can be unsatified with the way that the FED deals with inflation. In that scenario, the sentiment around USD in twitter would be negative in general, but it its demand can still increases.

# %%
#process json file
    #https://www.kaggle.com/code/prathamsharma123/clean-raw-json-tweets-data/notebook
print(ecb_search.shape)
    #as many rows as tweets
    #as many columns as features in each tweet
# Out:
# (474273, 28)

# %%
#see features
print(ecb_search.columns)
# Out:
# Index(['_type', 'url', 'date', 'rawContent', 'renderedContent', 'id', 'user',
#        'replyCount', 'retweetCount', 'likeCount', 'quoteCount',
#        'conversationId', 'lang', 'source', 'sourceUrl', 'sourceLabel', 'links',
#        'media', 'retweetedTweet', 'quotedTweet', 'inReplyToTweetId',
#        'inReplyToUser', 'mentionedUsers', 'coordinates', 'place', 'hashtags',
#        'cashtags', 'card'],
#       dtype='object')

# %%
#get all columns for the first tweet
print(ecb_search.iloc[0, :])
# Out:
# _type                                  snscrape.modules.twitter.Tweet
# url                 https://twitter.com/Andy_Sayad/status/15484534...
# date                                        2022-07-16 23:44:10+00:00
# rawContent          🔥🔥🔥Less than a week left till July 21. All Eur...
# renderedContent     🔥🔥🔥Less than a week left till July 21. All Eur...
# id                                                1548453468989693952
# user                {'_type': 'snscrape.modules.twitter.User', 'us...
# replyCount                                                          1
# retweetCount                                                        0
# likeCount                                                           2
# quoteCount                                                          0
# conversationId                                    1548453468989693952
# lang                                                               en
# source              <a href="http://twitter.com/download/iphone" r...
# sourceUrl                          http://twitter.com/download/iphone
# sourceLabel                                        Twitter for iPhone
# links                                                            None
# media                                                            None
# retweetedTweet                                                    NaN
# quotedTweet                                                      None
# inReplyToTweetId                                                  NaN
# inReplyToUser                                                    None
# mentionedUsers                                                   None
# coordinates                                                      None
# place                                                            None
# hashtags                                                [Nordstream1]
# cashtags                                                         None
# card                                                             None
# Name: 0, dtype: object

# %%
#check that the id is unique for each tweet
print(ecb_search["id"].is_unique)
print(ecb_hashtag["id"].is_unique)
print(debt_crisis_search["id"].is_unique)
print(eu_economy_search["id"].is_unique)
print(iceland_economy_search["id"].is_unique)
print(portugal_economy_search["id"].is_unique)
print(italy_economy_search["id"].is_unique)
print(ireland_economy_search["id"].is_unique)
print(greece_economy_search["id"].is_unique)
print(spain_economy_search ["id"].is_unique)
print(cyprus_economy_search["id"].is_unique)
print(slovenia_economy_search["id"].is_unique)
print(france_economy_search["id"].is_unique)
print(belgium_economy_search["id"].is_unique)
print(croatia_economy_search["id"].is_unique)
print(trichet_search["id"].is_unique)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
#bind data.frames of ecb search and ecb hashtag
tweets_df = ecb_hashtag.append([ecb_search, 
                                debt_crisis_search, 
                                eu_economy_search, 
                                iceland_economy_search,
                                portugal_economy_search,
                                italy_economy_search,
                                ireland_economy_search,
                                greece_economy_search,
                                spain_economy_search ,
                                cyprus_economy_search, 
                                slovenia_economy_search, 
                                france_economy_search,
                                belgium_economy_search,
                                croatia_economy_search,
                                trichet_search])
tweets_df[["id", "date", "rawContent"]]
# Out:
#                         id                      date  \
# 0      1548451710472839171 2022-07-16 23:37:11+00:00
# 1      1548449160541548545 2022-07-16 23:27:03+00:00
# 2      1548443968030928899 2022-07-16 23:06:25+00:00
# 3      1548442831143849984 2022-07-16 23:01:54+00:00
# 4      1548442355837022208 2022-07-16 23:00:00+00:00
# ...                    ...                       ...
# 24622            206053432 2007-08-14 20:03:44+00:00
# 24623            184113892 2007-08-03 08:30:37+00:00
# 24624            106039372 2007-06-15 17:19:26+00:00
# 24625            106039342 2007-06-15 17:19:24+00:00
# 24626             68467682 2007-05-18 11:02:43+00:00
#
#                                               rawContent
# 0      Ist der EURO noch zu retten? (EZB in der Zwick...
# 1      #ECB Bond Tool Seen Having No Limits as Steepe...
# 2      #Digitaleuro to be more efficient as a means o...
# 3      #Digitaleuro to be more efficient as a means o...
# 4      .@ECB_cricket🏴󠁧󠁢󠁥󠁮󠁧󠁿: England Men name squads ...
# ...                                                  ...
# 24622  ECB calls for calm as markets falter: Jean-Cla...
# 24623  Le dialogue entre BCE et exécutif européen est...
# 24624  TALK OF PARIS : Talk de Paris - Jean Claude Tr...
# 24625  TALK OF PARIS : Talk of Paris - Jean Claude Tr...
# 24626  Jean-Claude Trichet convida o Reino Unido a in...
#
# [2427806 rows x 3 columns]

# %%
#reset the indeces to avoid problems when indexing
tweets_df = tweets_df.reset_index(drop=True)
    #use drop drop parameter to avoid the old index being added as a column
tweets_df[["id", "date", "rawContent"]]
# Out:
#                           id                      date  \
# 0        1548451710472839171 2022-07-16 23:37:11+00:00
# 1        1548449160541548545 2022-07-16 23:27:03+00:00
# 2        1548443968030928899 2022-07-16 23:06:25+00:00
# 3        1548442831143849984 2022-07-16 23:01:54+00:00
# 4        1548442355837022208 2022-07-16 23:00:00+00:00
# ...                      ...                       ...
# 2427801            206053432 2007-08-14 20:03:44+00:00
# 2427802            184113892 2007-08-03 08:30:37+00:00
# 2427803            106039372 2007-06-15 17:19:26+00:00
# 2427804            106039342 2007-06-15 17:19:24+00:00
# 2427805             68467682 2007-05-18 11:02:43+00:00
#
#                                                 rawContent
# 0        Ist der EURO noch zu retten? (EZB in der Zwick...
# 1        #ECB Bond Tool Seen Having No Limits as Steepe...
# 2        #Digitaleuro to be more efficient as a means o...
# 3        #Digitaleuro to be more efficient as a means o...
# 4        .@ECB_cricket🏴󠁧󠁢󠁥󠁮󠁧󠁿: England Men name squads ...
# ...                                                    ...
# 2427801  ECB calls for calm as markets falter: Jean-Cla...
# 2427802  Le dialogue entre BCE et exécutif européen est...
# 2427803  TALK OF PARIS : Talk de Paris - Jean Claude Tr...
# 2427804  TALK OF PARIS : Talk of Paris - Jean Claude Tr...
# 2427805  Jean-Claude Trichet convida o Reino Unido a in...
#
# [2427806 rows x 3 columns]

# %%
#check we have the expected number of rows
#tweets_df.shape[0] == ecb_search.shape[0] + ecb_hashtag.shape[0] + debt_crisis_search.shape[0] + eu_economy_search.shape[0] + spain_economy_search.shape[0] + slovenia_economy_search.shape[0]

# %%
#release space
del([ecb_search, 
     debt_crisis_search, 
     eu_economy_search, 
     iceland_economy_search,
     portugal_economy_search,
     italy_economy_search,
     ireland_economy_search,
     greece_economy_search,
     spain_economy_search ,
     cyprus_economy_search, 
     slovenia_economy_search, 
     france_economy_search,
     belgium_economy_search,
     croatia_economy_search,
     trichet_search])
import gc
gc.collect()
# Out:
# 0

# %%
#check for duplicated IDs
tweets_df["id"].duplicated().any()
# Out:
# True

# %%
#take a look to one of the duplicated IDs
example_duplicated_id = tweets_df[tweets_df["id"].duplicated()].iloc[2,:].loc["id"] #get the ID

#get the URL for all tweets having the example ID and check if there are identical URLs
tweets_df.loc[tweets_df["id"] == example_duplicated_id, "url"].duplicated().any()
    #tweets with the same ID have the same URL, so they are the same tweet
# Out:
# True

# %%
#remove tweets with a duplicated id
tweets_df = tweets_df.drop_duplicates(subset=['id'])
tweets_df.shape
# Out:
# (2336081, 28)

# %%
#check languages
import numpy as np
np.unique(tweets_df["lang"])
# Out:
# array(['am', 'ar', 'bg', 'bn', 'ca', 'ckb', 'cs', 'cy', 'da', 'de', 'el',
#        'en', 'es', 'et', 'eu', 'fa', 'fi', 'fr', 'gu', 'hi', 'ht', 'hu',
#        'hy', 'in', 'is', 'it', 'iw', 'ja', 'ka', 'kn', 'ko', 'lt', 'lv',
#        'ml', 'mr', 'my', 'ne', 'nl', 'no', 'or', 'pa', 'pl', 'ps', 'pt',
#        'qam', 'qht', 'qme', 'qst', 'ro', 'ru', 'sd', 'si', 'sl', 'sr',
#        'sv', 'ta', 'te', 'th', 'tl', 'tr', 'uk', 'und', 'ur', 'vi', 'zh',
#        'zxx'], dtype=object)

# %%
#see tweets not in english
sum(tweets_df["lang"] != "en")
# Out:
# 226488

# %%
#select only tweets in english
tweets_df_en = tweets_df[tweets_df["lang"] == "en"]
tweets_df_en.shape
    #CHECK IF THE SENTIMENT MODEL USED CAN DEAL WITH OTHER LANGUAGES
# Out:
# (2109593, 28)

# %% [markdown]
# It seems that "rawContent" shows the raw tweet content, while "renderedContent" show the strings that would bet shown by the web app ([link](https://github.com/JustAnotherArchivist/snscrape/issues/479)).
#
# We are going to use the raw tweet because it seem it could have more information. They do not seem to be very different anyways:

# %%
tweets_df_en.loc[:, "rawContent"].iloc[0:10,]
# Out:
# 1     #ECB Bond Tool Seen Having No Limits as Steepe...
# 2     #Digitaleuro to be more efficient as a means o...
# 3     #Digitaleuro to be more efficient as a means o...
# 4     .@ECB_cricket🏴󠁧󠁢󠁥󠁮󠁧󠁿: England Men name squads ...
# 5     Another Big Week for Central B(W)ankers Ahead:...
# 6     Qualified today as an #ECB foundation cricket ...
# 7     #Jaws is nothing against this:\n\nby @topdownc...
# 8     #DXY monthly chart: my ultimate view. There is...
# 9     wow what a moment \n#vitalityblast #ECB @engla...
# 10    #ECB should take loan from #BCCI to upgrade th...
# Name: rawContent, dtype: object

# %%
tweets_df_en.loc[:, "renderedContent"].iloc[0:10,]
# Out:
# 1     #ECB Bond Tool Seen Having No Limits as Steepe...
# 2     #Digitaleuro to be more efficient as a means o...
# 3     #Digitaleuro to be more efficient as a means o...
# 4     .@ECB_cricket🏴󠁧󠁢󠁥󠁮󠁧󠁿: England Men name squads ...
# 5     Another Big Week for Central B(W)ankers Ahead:...
# 6     Qualified today as an #ECB foundation cricket ...
# 7     #Jaws is nothing against this:\n\nby @topdownc...
# 8     #DXY monthly chart: my ultimate view. There is...
# 9     wow what a moment \n#vitalityblast #ECB @engla...
# 10    #ECB should take loan from #BCCI to upgrade th...
# Name: renderedContent, dtype: object

# %% [markdown]
# ## Sentiment analysis of tweets

# %% [markdown]
# We will use VADER to perform the sentiment analysis. There are alternatives like TextBlob, but VADER meets well our requeriments
# - It is sensitive to both polarity (positive/negative) and intensity (strength) of emotion.
# - you get a positive, negative neutral scores and a compound score
# - labelled data not required because it is pre-trained ([link](https://towardsdatascience.com/sentimental-analysis-using-vader-a3415fef7664), [link](https://towardsdatascience.com/sentiment-analysis-of-tweets-167d040f0583))

# %%
#take example tweet
example_tweet = tweets_df_en.loc[1, "rawContent"]

# %%
#VADER can be used from vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

#open instance
analyzer = SentimentIntensityAnalyzer()

#example
print(analyzer.polarity_scores(example_tweet))
print(example_tweet)
# Out:
# {'neg': 0.296, 'neu': 0.704, 'pos': 0.0, 'compound': -0.7184}
# #ECB Bond Tool Seen Having No Limits as Steeper Rate Hikes Loom
#
# #MoneyPrinting #Gold #Silver #Stimulus #QE #BailOut #Liquidity #Monetize #Debt #DebtCrisis https://t.co/DiMb7magFj

# %%
#or from nlTK
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

#instance
sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/dftortosa/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
#we get similar results
print(sid.polarity_scores(example_tweet))
print(analyzer.polarity_scores(example_tweet))
# Out:
# {'neg': 0.163, 'neu': 0.837, 'pos': 0.0, 'compound': -0.4767}
# {'neg': 0.296, 'neu': 0.704, 'pos': 0.0, 'compound': -0.7184}

# %% [markdown]
# Define function to clean the tweet text

# %%
import re
def clean_tweet(tweet):
    '''
    Utility function to clean tweet text by removing links, special characters
    using simple regex statements.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) |(\w+:\/\/\S+)", " ", tweet).split()).replace("#", "")

##CHECK REGULAR EXPRESSIONS
#https://www.sciencedirect.com/science/article/pii/S104244312030072X

# %%
print(example_tweet)
clean_tweet(example_tweet)
# Out:
# #ECB Bond Tool Seen Having No Limits as Steeper Rate Hikes Loom
#
# #MoneyPrinting #Gold #Silver #Stimulus #QE #BailOut #Liquidity #Monetize #Debt #DebtCrisis https://t.co/DiMb7magFj
# 'ECB Bond Tool Seen Having No Limits as Steeper Rate Hikes Loom MoneyPrinting Gold Silver Stimulus QE BailOut Liquidity Monetize Debt DebtCrisis'

# %% [markdown]
# We are going to use the compound sentiment. In this way, we consider both the negative and positive sentiment around the BCE and the economy of Europe.

# %%
#define function to be applied per row
def sentiment_per_row(raw_tweet):
        
    #clean
    tweet_cleaned = clean_tweet(raw_tweet)
        #import preprocessor as p; p.clean()
    
    #get the negative sentiment
    sentiment = analyzer.polarity_scores(tweet_cleaned)["compound"]

    #return
    return sentiment

# %%
import multiprocessing as mp

with mp.Pool(10) as pool:
    tweets_df_en["sentiment"] = pool.map(sentiment_per_row, tweets_df_en["rawContent"])
        #for each row in tweets_df_en["rawContent"], apply sentiment_per_row across 10 cores
        #https://stackoverflow.com/questions/45545110/make-pandas-dataframe-apply-use-all-cores
    pool.close()
# Out:
# /home/dftortosa/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#get the date and sentiment
sentiment_results_df = tweets_df_en[["date", "sentiment"]]
sentiment_results_df
# Out:
#                              date  sentiment
# 1       2022-07-16 23:27:03+00:00    -0.7184
# 2       2022-07-16 23:06:25+00:00     0.4754
# 3       2022-07-16 23:01:54+00:00     0.4754
# 4       2022-07-16 23:00:00+00:00     0.0000
# 5       2022-07-16 22:12:31+00:00    -0.3818
# ...                           ...        ...
# 2427768 2008-03-07 04:12:04+00:00     0.0000
# 2427769 2008-03-03 19:52:21+00:00     0.0000
# 2427790 2007-09-27 23:21:05+00:00     0.0000
# 2427801 2007-08-14 20:03:44+00:00     0.3182
# 2427804 2007-06-15 17:19:24+00:00     0.0000
#
# [2109593 rows x 2 columns]

# %%
#leave only year, month and day
sentiment_results_df["date"] = pd.to_datetime(sentiment_results_df["date"].dt.strftime('%Y-%m-%d'))
    #https://stackoverflow.com/questions/38067704/how-to-change-the-datetime-format-in-pandas
    #https://stackoverflow.com/questions/20689288/converting-pandas-columns-to-datetime64-including-missing-values
sentiment_results_df

#CHECK WARNING
# Out:
# /home/dftortosa/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               date  sentiment
# 1       2022-07-16    -0.7184
# 2       2022-07-16     0.4754
# 3       2022-07-16     0.4754
# 4       2022-07-16     0.0000
# 5       2022-07-16    -0.3818
# ...            ...        ...
# 2427768 2008-03-07     0.0000
# 2427769 2008-03-03     0.0000
# 2427790 2007-09-27     0.0000
# 2427801 2007-08-14     0.3182
# 2427804 2007-06-15     0.0000
#
# [2109593 rows x 2 columns]

# %%
#check we have rows ordered in chronologicla order
sentiment_results_df.equals(sentiment_results_df.sort_index())
# Out:
# True

# %% [markdown]
# Now let's calculate several metrics for the sentiment of each day and save them in list of data.frames. We can calculate the average, quartiles, std...

# %%
sentiment_results_df.groupby("date")["sentiment"].mean()
# Out:
# date
# 2007-01-11    0.458800
# 2007-01-15    0.510600
# 2007-02-08    0.458800
# 2007-03-07    0.458800
# 2007-03-08    0.458800
#                 ...
# 2022-07-12    0.005844
# 2022-07-13   -0.018368
# 2022-07-14   -0.057981
# 2022-07-15   -0.031051
# 2022-07-16   -0.021342
# Name: sentiment, Length: 5281, dtype: float64

# %% [markdown]
# We can use lambda to define our own calculations like the interquartile range:

# %%
sentiment_results_df.groupby("date")["sentiment"].apply(lambda a: (np.percentile(a, 75) - np.percentile(a, 25)))
# Out:
# date
# 2007-01-11    0.00000
# 2007-01-15    0.00000
# 2007-02-08    0.00000
# 2007-03-07    0.00000
# 2007-03-08    0.00000
#                ...
# 2022-07-12    0.74300
# 2022-07-13    0.77770
# 2022-07-14    0.85110
# 2022-07-15    0.85850
# 2022-07-16    0.84645
# Name: sentiment, Length: 5281, dtype: float64

# %%
#get the most frequent value
from statistics import mode
mode([1,2,3,1,1])
# Out:
# 1

# %%
#std gives NA for cases with n=1
print(pd.DataFrame([1,1]).std()) #std = 0
print(pd.DataFrame([1,2]).std()) #std = 0.7
print(pd.DataFrame([1]).std()) #std = NaN
# Out:
# 0    0.0
# dtype: float64
# 0    0.707107
# dtype: float64
# 0   NaN
# dtype: float64

# %% [markdown]
# This is solved using ddof=0. ddof is Delta Degrees of Freedom. The divisor used in calculations is N - ddof, where N represents the number of elements

# %%
print(pd.DataFrame([1,1]).std(ddof=0)) #std = 0
print(pd.DataFrame([1,2]).std(ddof=0)) #std = 0.7
print(pd.DataFrame([1]).std(ddof=0)) #std = NaN
# Out:
# 0    0.0
# dtype: float64
# 0    0.5
# dtype: float64
# 0    0.0
# dtype: float64

# %% [markdown]
# We get the same results with np.std and .std(ddof=0)

# %%
print(np.std([1,1])) #std = 0
print(np.std([1,2])) #std = 0.7
print(np.std([1])) #std = NaN
# Out:
# 0.0
# 0.5
# 0.0

# %% [markdown]
# We can calculate the range

# %%
sentiment_results_df.groupby("date")["sentiment"].apply(lambda x: np.max(x) - np.min(x))
# Out:
# date
# 2007-01-11    0.0000
# 2007-01-15    0.0000
# 2007-02-08    0.0000
# 2007-03-07    0.0000
# 2007-03-08    0.0000
#                ...
# 2022-07-12    1.9261
# 2022-07-13    1.9200
# 2022-07-14    1.8954
# 2022-07-15    1.9467
# 2022-07-16    1.8872
# Name: sentiment, Length: 5281, dtype: float64

# %% [markdown]
# variance

# %%
sentiment_results_df.groupby("date")["sentiment"].var()
# Out:
# date
# 2007-01-11         NaN
# 2007-01-15         NaN
# 2007-02-08    0.000000
# 2007-03-07         NaN
# 2007-03-08         NaN
#                 ...
# 2022-07-12    0.220794
# 2022-07-13    0.233812
# 2022-07-14    0.250052
# 2022-07-15    0.251224
# 2022-07-16    0.261682
# Name: sentiment, Length: 5281, dtype: float64

# %% [markdown]
# We are going to use evaluate inside the function in order to perform the different operations we need. For example:

# %%
operation="mean"
string_evaluate = 'sentiment_results_df.groupby("date")["sentiment"].' + operation + '().to_frame()'
string_evaluate
# Out:
# 'sentiment_results_df.groupby("date")["sentiment"].mean().to_frame()'

# %%
eval(string_evaluate)
# Out:
#             sentiment
# date
# 2007-01-11   0.458800
# 2007-01-15   0.510600
# 2007-02-08   0.458800
# 2007-03-07   0.458800
# 2007-03-08   0.458800
# ...               ...
# 2022-07-12   0.005844
# 2022-07-13  -0.018368
# 2022-07-14  -0.057981
# 2022-07-15  -0.031051
# 2022-07-16  -0.021342
#
# [5281 rows x 1 columns]

# %% [markdown]
# We are interested in have a row per day, so we can exactly calculate the sentiment of 1, 10... days ago

# %%
#we can use min and max to select the earliest and latest dates
print(np.min(np.unique(sentiment_results_df["date"])))
print(np.max(np.unique(sentiment_results_df["date"])))
# Out:
# 2007-01-11T00:00:00.000000000
# 2022-07-16T00:00:00.000000000

# %%
#first calculate the time range from the earliest to latest date
idx = pd.date_range(np.min(np.unique(sentiment_results_df["date"])), 
                    np.max(np.unique(sentiment_results_df["date"])))
idx
# Out:
# DatetimeIndex(['2007-01-11', '2007-01-12', '2007-01-13', '2007-01-14',
#                '2007-01-15', '2007-01-16', '2007-01-17', '2007-01-18',
#                '2007-01-19', '2007-01-20',
#                ...
#                '2022-07-07', '2022-07-08', '2022-07-09', '2022-07-10',
#                '2022-07-11', '2022-07-12', '2022-07-13', '2022-07-14',
#                '2022-07-15', '2022-07-16'],
#               dtype='datetime64[ns]', length=5666, freq='D')

# %%
#calculate the mean sentiment in tweets per day and then re-index considering all days between the earliest and 
#latest date. Those dates without tweets will have NaN
sentiment_results_df.groupby("date")["sentiment"].mean().reindex(idx, fill_value=np.NaN)
# Out:
# 2007-01-11    0.458800
# 2007-01-12         NaN
# 2007-01-13         NaN
# 2007-01-14         NaN
# 2007-01-15    0.510600
#                 ...
# 2022-07-12    0.005844
# 2022-07-13   -0.018368
# 2022-07-14   -0.057981
# 2022-07-15   -0.031051
# 2022-07-16   -0.021342
# Freq: D, Name: sentiment, Length: 5666, dtype: float64

# %% [markdown]
# You can see how there is a gap without tweets between 11 and 15 of January and, accordingly, the days between have NaN

# %%
np.unique(sentiment_results_df["date"])[0:2]
# Out:
# array(['2007-01-11T00:00:00.000000000', '2007-01-15T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %% [markdown]
# We can also shift the rows after making an operation per day, i.e., move the value of day 1 to day 2, value of day 2 to day 3, and so on...

# %%
#first calculate the average sentiment per day
sentiment_results_df.groupby("date")["sentiment"].mean().reindex(idx, fill_value=np.NaN)
# Out:
# 2007-01-11    0.458800
# 2007-01-12         NaN
# 2007-01-13         NaN
# 2007-01-14         NaN
# 2007-01-15    0.510600
#                 ...
# 2022-07-12    0.005844
# 2022-07-13   -0.018368
# 2022-07-14   -0.057981
# 2022-07-15   -0.031051
# 2022-07-16   -0.021342
# Freq: D, Name: sentiment, Length: 5666, dtype: float64

# %%
#Now shift 2 days, so 2022-07-16 has now the average of the previous day (2022-07-15)
sentiment_results_df.groupby("date")["sentiment"].mean().reindex(idx, fill_value=np.NaN).shift(1)
# Out:
# 2007-01-11         NaN
# 2007-01-12    0.458800
# 2007-01-13         NaN
# 2007-01-14         NaN
# 2007-01-15         NaN
#                 ...
# 2022-07-12   -0.049440
# 2022-07-13    0.005844
# 2022-07-14   -0.018368
# 2022-07-15   -0.057981
# 2022-07-16   -0.031051
# Freq: D, Name: sentiment, Length: 5666, dtype: float64

# %% [markdown]
# Shift zero would be equal to the original variable, no change:

# %%
sentiment_results_df.groupby("date")["sentiment"].mean().reindex(idx, fill_value=np.NaN).shift(0).equals(sentiment_results_df.groupby("date")["sentiment"].mean().reindex(idx, fill_value=np.NaN))
# Out:
# True

# %%
sentiment_results_df["sentiment"].shift(0).equals(sentiment_results_df["sentiment"])
# Out:
# True

# %% [markdown]
# Now, we are going to calculate different summary statistics of the sentiment of the previous days (1, 5, 10, 60 days ago):

# %%
###CHECK THIS!!!

#define a function to do a given operation grouping by day but considering the a previous date
def groupby_calcs(operation, metric_name, args="", n_previous_days=2):
        
    #get the string with the operation name
    string_evaluate = 'sentiment_results_df.groupby("date")["sentiment"].' + operation + '(' + args + ').to_frame()'
        #do operations for the sentiment of each day and then convert to df

    #evaluate to get the DF with the calculations per day
    data_frame = eval(string_evaluate)
    
    #extract the range of days for which we have data
    time_range = pd.date_range(np.min(np.unique(sentiment_results_df["date"])), 
                        np.max(np.unique(sentiment_results_df["date"])))
    
    #fill with NaN those dates with data
    data_frame = data_frame.reindex(time_range, fill_value=np.NaN)
        #https://stackoverflow.com/questions/15610805/accessing-row-from-previous-day-in-pandas-dataframe-with-apply
    
    #get sentiment of the previous days
    data_frame['sentiment'] = data_frame['sentiment'].shift(n_previous_days)
        #https://stackoverflow.com/questions/19324453/add-missing-dates-to-pandas-dataframe
        
    #reset the index
    data_frame = data_frame.reset_index(level=0)
        #set the index (date) as column 
  
    #change the column name for sentiment
    data_frame = data_frame.rename(columns={'index': 'date', 'sentiment': metric_name + '_sent_previous_' + str(n_previous_days) + '_days'})

    #append the df to the list
    return data_frame
    

def groupby_calcs_across_dates(previous_date):
    
    #define a list of operations to do
    metrics_sentiment = ["quantile_0.05",
                         "quantile_0.1",
                         "quantile_0.2",
                         "quantile_0.3",
                         "quantile_0.4",
                         "quantile_0.5",
                         "quantile_0.6",
                         "quantile_0.7",
                         "quantile_0.8",
                         "quantile_0.9",
                         "quantile_0.95",
                         "mean",
                         "min",
                         "max",
                         "sum",
                         "count", 
                             #this can be useful to control for averages with low number of tweets
                             #but also to consider how much people is talking about europes economy 
                         "range", 
                         "var", 
                         "std", 
                         "iqr"]
    
    #open list to save each calculation
    list_data_frames = []
    
    #apply each operation
    for metric in metrics_sentiment:
        
        #for std
        if metric == "std":
            #use ddof=0 to get zero for cases with 1 tweet per day (see above)
            result_calc = groupby_calcs(operation=metric, 
                          metric_name=metric, 
                          args='ddof=0', 
                          n_previous_days=previous_date)
        elif "quantile" in metric: #if quantile
            #get the operation name and the quantile number
            operation_name = metric.split("_")[0]
            quantile_number = metric.split("_")[1]
            result_calc = groupby_calcs(operation=operation_name, 
                          metric_name=metric, 
                          args=quantile_number, 
                          n_previous_days=previous_date) 
        elif "range" in metric:
            result_calc = groupby_calcs(operation="apply", 
                          metric_name=metric, 
                          args="lambda x: np.max(x) - np.min(x)",
                          n_previous_days=previous_date)
        elif "iqr" in metric:
            result_calc = groupby_calcs(operation="apply", 
                          metric_name=metric, 
                          args="lambda x: (np.percentile(x, 75) - np.percentile(x, 25))",
                          n_previous_days=previous_date)   
        else: 
            result_calc = groupby_calcs(operation=metric, 
                          metric_name=metric, 
                          n_previous_days=previous_date)
           
        list_data_frames.append(result_calc)
        
    return list_data_frames

# %%
groupby_calcs_across_dates(2)
# Out:
# [           date  quantile_0.05_sent_previous_2_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                             0.45880
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                            -0.86890
#  5662 2022-07-13                            -0.81855
#  5663 2022-07-14                            -0.79836
#  5664 2022-07-15                            -0.82486
#  5665 2022-07-16                            -0.82421
#
#  [5666 rows x 2 columns],
#             date  quantile_0.1_sent_previous_2_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                            0.45880
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5661 2022-07-12                           -0.75060
#  5662 2022-07-13                           -0.71605
#  5663 2022-07-14                           -0.62490
#  5664 2022-07-15                           -0.70030
#  5665 2022-07-16                           -0.71664
#
#  [5666 rows x 2 columns],
#             date  quantile_0.2_sent_previous_2_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                            0.45880
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5661 2022-07-12                           -0.44040
#  5662 2022-07-13                           -0.55740
#  5663 2022-07-14                           -0.42150
#  5664 2022-07-15                           -0.50982
#  5665 2022-07-16                           -0.55740
#
#  [5666 rows x 2 columns],
#             date  quantile_0.3_sent_previous_2_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                            0.45880
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5661 2022-07-12                           -0.29600
#  5662 2022-07-13                           -0.36120
#  5663 2022-07-14                           -0.27320
#  5664 2022-07-15                           -0.27320
#  5665 2022-07-16                           -0.42778
#
#  [5666 rows x 2 columns],
#             date  quantile_0.4_sent_previous_2_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                            0.45880
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5661 2022-07-12                            0.00000
#  5662 2022-07-13                           -0.22800
#  5663 2022-07-14                            0.00000
#  5664 2022-07-15                           -0.10260
#  5665 2022-07-16                           -0.15344
#
#  [5666 rows x 2 columns],
#             date  quantile_0.5_sent_previous_2_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                             0.4588
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5661 2022-07-12                             0.0000
#  5662 2022-07-13                             0.0000
#  5663 2022-07-14                             0.0000
#  5664 2022-07-15                             0.0000
#  5665 2022-07-16                             0.0000
#
#  [5666 rows x 2 columns],
#             date  quantile_0.6_sent_previous_2_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                             0.4588
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5661 2022-07-12                             0.0622
#  5662 2022-07-13                             0.0000
#  5663 2022-07-14                             0.0000
#  5664 2022-07-15                             0.0000
#  5665 2022-07-16                             0.0000
#
#  [5666 rows x 2 columns],
#             date  quantile_0.7_sent_previous_2_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                            0.45880
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5661 2022-07-12                            0.42150
#  5662 2022-07-13                            0.25000
#  5663 2022-07-14                            0.27320
#  5664 2022-07-15                            0.27284
#  5665 2022-07-16                            0.20230
#
#  [5666 rows x 2 columns],
#             date  quantile_0.8_sent_previous_2_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                            0.45880
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5661 2022-07-12                            0.57190
#  5662 2022-07-13                            0.44040
#  5663 2022-07-14                            0.44040
#  5664 2022-07-15                            0.44776
#  5665 2022-07-16                            0.44040
#
#  [5666 rows x 2 columns],
#             date  quantile_0.9_sent_previous_2_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                            0.45880
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5661 2022-07-12                            0.72890
#  5662 2022-07-13                            0.66510
#  5663 2022-07-14                            0.67771
#  5664 2022-07-15                            0.66810
#  5665 2022-07-16                            0.67874
#
#  [5666 rows x 2 columns],
#             date  quantile_0.95_sent_previous_2_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                            0.458800
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                            0.826800
#  5662 2022-07-13                            0.781375
#  5663 2022-07-14                            0.802000
#  5664 2022-07-15                            0.775660
#  5665 2022-07-16                            0.810550
#
#  [5666 rows x 2 columns],
#             date  mean_sent_previous_2_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                   0.458800
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                   0.029138
#  5662 2022-07-13                  -0.049440
#  5663 2022-07-14                   0.005844
#  5664 2022-07-15                  -0.018368
#  5665 2022-07-16                  -0.057981
#
#  [5666 rows x 2 columns],
#             date  min_sent_previous_2_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                    0.4588
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5661 2022-07-12                   -0.9563
#  5662 2022-07-13                   -0.9829
#  5663 2022-07-14                   -0.9613
#  5664 2022-07-15                   -0.9625
#  5665 2022-07-16                   -0.9563
#
#  [5666 rows x 2 columns],
#             date  max_sent_previous_2_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                    0.4588
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5661 2022-07-12                    0.9718
#  5662 2022-07-13                    0.9853
#  5663 2022-07-14                    0.9648
#  5664 2022-07-15                    0.9575
#  5665 2022-07-16                    0.9391
#
#  [5666 rows x 2 columns],
#             date  sum_sent_previous_2_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                    0.4588
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5661 2022-07-12                    8.1877
#  5662 2022-07-13                  -26.4999
#  5663 2022-07-14                    3.9389
#  5664 2022-07-15                  -10.8190
#  5665 2022-07-16                  -45.3994
#
#  [5666 rows x 2 columns],
#             date  count_sent_previous_2_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         1.0
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5661 2022-07-12                       281.0
#  5662 2022-07-13                       536.0
#  5663 2022-07-14                       674.0
#  5664 2022-07-15                       589.0
#  5665 2022-07-16                       783.0
#
#  [5666 rows x 2 columns],
#             date  range_sent_previous_2_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                      0.0000
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5661 2022-07-12                      1.9281
#  5662 2022-07-13                      1.9682
#  5663 2022-07-14                      1.9261
#  5664 2022-07-15                      1.9200
#  5665 2022-07-16                      1.8954
#
#  [5666 rows x 2 columns],
#             date  var_sent_previous_2_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                       NaN
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5661 2022-07-12                  0.273317
#  5662 2022-07-13                  0.250097
#  5663 2022-07-14                  0.220794
#  5664 2022-07-15                  0.233812
#  5665 2022-07-16                  0.250052
#
#  [5666 rows x 2 columns],
#             date  std_sent_previous_2_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                  0.000000
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5661 2022-07-12                  0.521867
#  5662 2022-07-13                  0.499631
#  5663 2022-07-14                  0.469538
#  5664 2022-07-15                  0.483130
#  5665 2022-07-16                  0.499732
#
#  [5666 rows x 2 columns],
#             date  iqr_sent_previous_2_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                    0.0000
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5661 2022-07-12                    0.8506
#  5662 2022-07-13                    0.8222
#  5663 2022-07-14                    0.7430
#  5664 2022-07-15                    0.7777
#  5665 2022-07-16                    0.8511
#
#  [5666 rows x 2 columns]]

# %% [markdown]
# We are going to calculate the summary statistics for the sentiment several days before the current day

# %%
#get sentiment 1 and 2 weeks ago, along with 1, 2, 3, 4 and 5 months ago
list_dates = [7, 14, 30, 60, 90, 120]

#open a pool with 10 processes
pool_dates = mp.Pool(processes=10)

#apply the function for each previous day in parallel across 10 cores
list_data_frames = [pool_dates.apply_async(groupby_calcs_across_dates, args=(previous_date,)).get() for previous_date in list_dates]
    #https://stackoverflow.com/questions/42843203/how-to-get-the-result-of-multiprocessing-pool-apply-async

#close the pool
pool_dates.close()

# %%
#check we have the correct number of dfs in the list
#len(list_data_frames) == len(metrics_sentiment)*len(list_dates)

# %%
type(list_data_frames)
# Out:
# list

# %%
list_data_frames[0][0]
# Out:
#            date  quantile_0.05_sent_previous_7_days
# 0    2007-01-11                                 NaN
# 1    2007-01-12                                 NaN
# 2    2007-01-13                                 NaN
# 3    2007-01-14                                 NaN
# 4    2007-01-15                                 NaN
# ...         ...                                 ...
# 5661 2022-07-12                           -0.844600
# 5662 2022-07-13                           -0.823660
# 5663 2022-07-14                           -0.865970
# 5664 2022-07-15                           -0.835185
# 5665 2022-07-16                           -0.818050
#
# [5666 rows x 2 columns]

# %%
list_data_frames[1][1]
# Out:
#            date  quantile_0.1_sent_previous_14_days
# 0    2007-01-11                                 NaN
# 1    2007-01-12                                 NaN
# 2    2007-01-13                                 NaN
# 3    2007-01-14                                 NaN
# 4    2007-01-15                                 NaN
# ...         ...                                 ...
# 5661 2022-07-12                            -0.63690
# 5662 2022-07-13                            -0.62850
# 5663 2022-07-14                            -0.67206
# 5664 2022-07-15                            -0.65970
# 5665 2022-07-16                            -0.72528
#
# [5666 rows x 2 columns]

# %%
flat_list = [item for sublist in list_data_frames for item in sublist]
flat_list
# Out:
# [           date  quantile_0.05_sent_previous_7_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                           -0.844600
#  5662 2022-07-13                           -0.823660
#  5663 2022-07-14                           -0.865970
#  5664 2022-07-15                           -0.835185
#  5665 2022-07-16                           -0.818050
#
#  [5666 rows x 2 columns],
#             date  quantile_0.1_sent_previous_7_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                                NaN
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5661 2022-07-12                           -0.75574
#  5662 2022-07-13                           -0.71752
#  5663 2022-07-14                           -0.76500
#  5664 2022-07-15                           -0.72949
#  5665 2022-07-16                           -0.73806
#
#  [5666 rows x 2 columns],
#             date  quantile_0.2_sent_previous_7_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                                NaN
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5661 2022-07-12                           -0.56900
#  5662 2022-07-13                           -0.52348
#  5663 2022-07-14                           -0.56614
#  5664 2022-07-15                           -0.55740
#  5665 2022-07-16                           -0.55652
#
#  [5666 rows x 2 columns],
#             date  quantile_0.3_sent_previous_7_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                                NaN
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5661 2022-07-12                           -0.34000
#  5662 2022-07-13                           -0.30370
#  5663 2022-07-14                           -0.36015
#  5664 2022-07-15                           -0.40190
#  5665 2022-07-16                           -0.29330
#
#  [5666 rows x 2 columns],
#             date  quantile_0.4_sent_previous_7_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                                NaN
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5661 2022-07-12                           -0.17960
#  5662 2022-07-13                           -0.06174
#  5663 2022-07-14                           -0.13192
#  5664 2022-07-15                           -0.17790
#  5665 2022-07-16                           -0.02580
#
#  [5666 rows x 2 columns],
#             date  quantile_0.5_sent_previous_7_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                                NaN
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5661 2022-07-12                                0.0
#  5662 2022-07-13                                0.0
#  5663 2022-07-14                                0.0
#  5664 2022-07-15                                0.0
#  5665 2022-07-16                                0.0
#
#  [5666 rows x 2 columns],
#             date  quantile_0.6_sent_previous_7_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                                NaN
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5661 2022-07-12                            0.00000
#  5662 2022-07-13                            0.08932
#  5663 2022-07-14                            0.02580
#  5664 2022-07-15                            0.00000
#  5665 2022-07-16                            0.20230
#
#  [5666 rows x 2 columns],
#             date  quantile_0.7_sent_previous_7_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                                NaN
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5661 2022-07-12                             0.2328
#  5662 2022-07-13                             0.3400
#  5663 2022-07-14                             0.2732
#  5664 2022-07-15                             0.2960
#  5665 2022-07-16                             0.4215
#
#  [5666 rows x 2 columns],
#             date  quantile_0.8_sent_previous_7_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                                NaN
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5661 2022-07-12                            0.44040
#  5662 2022-07-13                            0.49390
#  5663 2022-07-14                            0.44050
#  5664 2022-07-15                            0.45824
#  5665 2022-07-16                            0.57190
#
#  [5666 rows x 2 columns],
#             date  quantile_0.9_sent_previous_7_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                                NaN
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5661 2022-07-12                            0.69080
#  5662 2022-07-13                            0.69080
#  5663 2022-07-14                            0.65115
#  5664 2022-07-15                            0.68080
#  5665 2022-07-16                            0.72095
#
#  [5666 rows x 2 columns],
#             date  quantile_0.95_sent_previous_7_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                            0.759320
#  5662 2022-07-13                            0.831600
#  5663 2022-07-14                            0.765335
#  5664 2022-07-15                            0.768895
#  5665 2022-07-16                            0.802810
#
#  [5666 rows x 2 columns],
#             date  mean_sent_previous_7_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                  -0.044121
#  5662 2022-07-13                   0.007835
#  5663 2022-07-14                  -0.040434
#  5664 2022-07-15                  -0.037051
#  5665 2022-07-16                   0.025454
#
#  [5666 rows x 2 columns],
#             date  min_sent_previous_7_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                       NaN
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5661 2022-07-12                   -0.9538
#  5662 2022-07-13                   -0.9729
#  5663 2022-07-14                   -0.9735
#  5664 2022-07-15                   -0.9766
#  5665 2022-07-16                   -0.9413
#
#  [5666 rows x 2 columns],
#             date  max_sent_previous_7_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                       NaN
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5661 2022-07-12                    0.9308
#  5662 2022-07-13                    0.9583
#  5663 2022-07-14                    0.9659
#  5664 2022-07-15                    0.9854
#  5665 2022-07-16                    0.9518
#
#  [5666 rows x 2 columns],
#             date  sum_sent_previous_7_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                       NaN
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5661 2022-07-12                  -28.9874
#  5662 2022-07-13                    3.6198
#  5663 2022-07-14                  -22.6429
#  5664 2022-07-15                  -19.9337
#  5665 2022-07-16                    7.5854
#
#  [5666 rows x 2 columns],
#             date  count_sent_previous_7_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5661 2022-07-12                       657.0
#  5662 2022-07-13                       462.0
#  5663 2022-07-14                       560.0
#  5664 2022-07-15                       538.0
#  5665 2022-07-16                       298.0
#
#  [5666 rows x 2 columns],
#             date  range_sent_previous_7_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5661 2022-07-12                      1.8846
#  5662 2022-07-13                      1.9312
#  5663 2022-07-14                      1.9394
#  5664 2022-07-15                      1.9620
#  5665 2022-07-16                      1.8931
#
#  [5666 rows x 2 columns],
#             date  var_sent_previous_7_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                       NaN
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5661 2022-07-12                  0.249871
#  5662 2022-07-13                  0.258426
#  5663 2022-07-14                  0.258324
#  5664 2022-07-15                  0.258318
#  5665 2022-07-16                  0.276028
#
#  [5666 rows x 2 columns],
#             date  std_sent_previous_7_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                       NaN
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5661 2022-07-12                  0.499490
#  5662 2022-07-13                  0.507805
#  5663 2022-07-14                  0.507802
#  5664 2022-07-15                  0.507778
#  5665 2022-07-16                  0.524501
#
#  [5666 rows x 2 columns],
#             date  iqr_sent_previous_7_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                       NaN
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5661 2022-07-12                  0.822200
#  5662 2022-07-13                  0.830675
#  5663 2022-07-14                  0.822200
#  5664 2022-07-15                  0.867650
#  5665 2022-07-16                  0.893725
#
#  [5666 rows x 2 columns],
#             date  quantile_0.05_sent_previous_14_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5661 2022-07-12                            -0.787995
#  5662 2022-07-13                            -0.748105
#  5663 2022-07-14                            -0.784500
#  5664 2022-07-15                            -0.790600
#  5665 2022-07-16                            -0.836000
#
#  [5666 rows x 2 columns],
#             date  quantile_0.1_sent_previous_14_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                            -0.63690
#  5662 2022-07-13                            -0.62850
#  5663 2022-07-14                            -0.67206
#  5664 2022-07-15                            -0.65970
#  5665 2022-07-16                            -0.72528
#
#  [5666 rows x 2 columns],
#             date  quantile_0.2_sent_previous_14_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                            -0.36120
#  5662 2022-07-13                            -0.30932
#  5663 2022-07-14                            -0.49594
#  5664 2022-07-15                            -0.38376
#  5665 2022-07-16                            -0.47670
#
#  [5666 rows x 2 columns],
#             date  quantile_0.3_sent_previous_14_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                            -0.02481
#  5662 2022-07-13                            -0.07507
#  5663 2022-07-14                            -0.29600
#  5664 2022-07-15                            -0.04064
#  5665 2022-07-16                            -0.25439
#
#  [5666 rows x 2 columns],
#             date  quantile_0.4_sent_previous_14_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                              0.0000
#  5662 2022-07-13                              0.0000
#  5663 2022-07-14                             -0.0652
#  5664 2022-07-15                              0.0000
#  5665 2022-07-16                              0.0000
#
#  [5666 rows x 2 columns],
#             date  quantile_0.5_sent_previous_14_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                                 0.0
#  5662 2022-07-13                                 0.0
#  5663 2022-07-14                                 0.0
#  5664 2022-07-15                                 0.0
#  5665 2022-07-16                                 0.0
#
#  [5666 rows x 2 columns],
#             date  quantile_0.6_sent_previous_14_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                              0.1531
#  5662 2022-07-13                              0.0772
#  5663 2022-07-14                              0.0516
#  5664 2022-07-15                              0.0000
#  5665 2022-07-16                              0.0000
#
#  [5666 rows x 2 columns],
#             date  quantile_0.7_sent_previous_14_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                              0.3612
#  5662 2022-07-13                              0.3182
#  5663 2022-07-14                              0.3182
#  5664 2022-07-15                              0.2732
#  5665 2022-07-16                              0.2023
#
#  [5666 rows x 2 columns],
#             date  quantile_0.8_sent_previous_14_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                             0.50512
#  5662 2022-07-13                             0.43988
#  5663 2022-07-14                             0.49262
#  5664 2022-07-15                             0.45880
#  5665 2022-07-16                             0.44040
#
#  [5666 rows x 2 columns],
#             date  quantile_0.9_sent_previous_14_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                             0.68080
#  5662 2022-07-13                             0.71175
#  5663 2022-07-14                             0.71816
#  5664 2022-07-15                             0.63642
#  5665 2022-07-16                             0.62917
#
#  [5666 rows x 2 columns],
#             date  quantile_0.95_sent_previous_14_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5661 2022-07-12                             0.807970
#  5662 2022-07-13                             0.820365
#  5663 2022-07-14                             0.821520
#  5664 2022-07-15                             0.784500
#  5665 2022-07-16                             0.825195
#
#  [5666 rows x 2 columns],
#             date  mean_sent_previous_14_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5661 2022-07-12                    0.065728
#  5662 2022-07-13                    0.047734
#  5663 2022-07-14                    0.004573
#  5664 2022-07-15                    0.029080
#  5665 2022-07-16                   -0.011397
#
#  [5666 rows x 2 columns],
#             date  min_sent_previous_14_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                    -0.9810
#  5662 2022-07-13                    -0.9661
#  5663 2022-07-14                    -0.9671
#  5664 2022-07-15                    -0.9485
#  5665 2022-07-16                    -0.9628
#
#  [5666 rows x 2 columns],
#             date  max_sent_previous_14_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                     0.9740
#  5662 2022-07-13                     0.9738
#  5663 2022-07-14                     0.9509
#  5664 2022-07-15                     0.9550
#  5665 2022-07-16                     0.9587
#
#  [5666 rows x 2 columns],
#             date  sum_sent_previous_14_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                    47.8501
#  5662 2022-07-13                    35.7047
#  5663 2022-07-14                     2.5836
#  5664 2022-07-15                    17.3606
#  5665 2022-07-16                    -4.8322
#
#  [5666 rows x 2 columns],
#             date  count_sent_previous_14_days
#  0    2007-01-11                          NaN
#  1    2007-01-12                          NaN
#  2    2007-01-13                          NaN
#  3    2007-01-14                          NaN
#  4    2007-01-15                          NaN
#  ...         ...                          ...
#  5661 2022-07-12                        728.0
#  5662 2022-07-13                        748.0
#  5663 2022-07-14                        565.0
#  5664 2022-07-15                        597.0
#  5665 2022-07-16                        424.0
#
#  [5666 rows x 2 columns],
#             date  range_sent_previous_14_days
#  0    2007-01-11                          NaN
#  1    2007-01-12                          NaN
#  2    2007-01-13                          NaN
#  3    2007-01-14                          NaN
#  4    2007-01-15                          NaN
#  ...         ...                          ...
#  5661 2022-07-12                       1.9550
#  5662 2022-07-13                       1.9399
#  5663 2022-07-14                       1.9180
#  5664 2022-07-15                       1.9035
#  5665 2022-07-16                       1.9215
#
#  [5666 rows x 2 columns],
#             date  var_sent_previous_14_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                   0.218397
#  5662 2022-07-13                   0.205185
#  5663 2022-07-14                   0.242984
#  5664 2022-07-15                   0.207190
#  5665 2022-07-16                   0.227890
#
#  [5666 rows x 2 columns],
#             date  std_sent_previous_14_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                   0.467009
#  5662 2022-07-13                   0.452671
#  5663 2022-07-14                   0.492497
#  5664 2022-07-15                   0.454800
#  5665 2022-07-16                   0.476815
#
#  [5666 rows x 2 columns],
#             date  iqr_sent_previous_14_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                   0.667325
#  5662 2022-07-13                   0.610825
#  5663 2022-07-14                   0.775500
#  5664 2022-07-15                   0.705100
#  5665 2022-07-16                   0.729125
#
#  [5666 rows x 2 columns],
#             date  quantile_0.05_sent_previous_30_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5661 2022-07-12                            -0.848985
#  5662 2022-07-13                            -0.840200
#  5663 2022-07-14                            -0.783570
#  5664 2022-07-15                            -0.822500
#  5665 2022-07-16                            -0.822500
#
#  [5666 rows x 2 columns],
#             date  quantile_0.1_sent_previous_30_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                            -0.73747
#  5662 2022-07-13                            -0.72690
#  5663 2022-07-14                            -0.67050
#  5664 2022-07-15                            -0.74597
#  5665 2022-07-16                            -0.70960
#
#  [5666 rows x 2 columns],
#             date  quantile_0.2_sent_previous_30_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                            -0.53706
#  5662 2022-07-13                            -0.58480
#  5663 2022-07-14                            -0.52670
#  5664 2022-07-15                            -0.54230
#  5665 2022-07-16                            -0.51060
#
#  [5666 rows x 2 columns],
#             date  quantile_0.3_sent_previous_30_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                            -0.33928
#  5662 2022-07-13                            -0.36120
#  5663 2022-07-14                            -0.29600
#  5664 2022-07-15                            -0.38180
#  5665 2022-07-16                            -0.31820
#
#  [5666 rows x 2 columns],
#             date  quantile_0.4_sent_previous_30_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                            -0.10030
#  5662 2022-07-13                            -0.17790
#  5663 2022-07-14                            -0.02378
#  5664 2022-07-15                            -0.29600
#  5665 2022-07-16                            -0.10270
#
#  [5666 rows x 2 columns],
#             date  quantile_0.5_sent_previous_30_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                                 0.0
#  5662 2022-07-13                                 0.0
#  5663 2022-07-14                                 0.0
#  5664 2022-07-15                                 0.0
#  5665 2022-07-16                                 0.0
#
#  [5666 rows x 2 columns],
#             date  quantile_0.6_sent_previous_30_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                             0.11672
#  5662 2022-07-13                             0.00000
#  5663 2022-07-14                             0.00000
#  5664 2022-07-15                             0.00000
#  5665 2022-07-16                             0.00000
#
#  [5666 rows x 2 columns],
#             date  quantile_0.7_sent_previous_30_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                             0.31805
#  5662 2022-07-13                             0.20230
#  5663 2022-07-14                             0.27320
#  5664 2022-07-15                             0.00000
#  5665 2022-07-16                             0.29084
#
#  [5666 rows x 2 columns],
#             date  quantile_0.8_sent_previous_30_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                              0.5267
#  5662 2022-07-13                              0.4215
#  5663 2022-07-14                              0.4588
#  5664 2022-07-15                              0.3182
#  5665 2022-07-16                              0.4624
#
#  [5666 rows x 2 columns],
#             date  quantile_0.9_sent_previous_30_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                             0.70960
#  5662 2022-07-13                             0.62400
#  5663 2022-07-14                             0.71527
#  5664 2022-07-15                             0.55740
#  5665 2022-07-16                             0.69080
#
#  [5666 rows x 2 columns],
#             date  quantile_0.95_sent_previous_30_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5661 2022-07-12                             0.807500
#  5662 2022-07-13                             0.743000
#  5663 2022-07-14                             0.824965
#  5664 2022-07-15                             0.718400
#  5665 2022-07-16                             0.790960
#
#  [5666 rows x 2 columns],
#             date  mean_sent_previous_30_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5661 2022-07-12                   -0.002613
#  5662 2022-07-13                   -0.058899
#  5663 2022-07-14                   -0.005054
#  5664 2022-07-15                   -0.110073
#  5665 2022-07-16                   -0.016726
#
#  [5666 rows x 2 columns],
#             date  min_sent_previous_30_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                    -0.9521
#  5662 2022-07-13                    -0.9789
#  5663 2022-07-14                    -0.9656
#  5664 2022-07-15                    -0.9749
#  5665 2022-07-16                    -0.9451
#
#  [5666 rows x 2 columns],
#             date  max_sent_previous_30_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                     0.9531
#  5662 2022-07-13                     0.9783
#  5663 2022-07-14                     0.9690
#  5664 2022-07-15                     0.9825
#  5665 2022-07-16                     0.9889
#
#  [5666 rows x 2 columns],
#             date  sum_sent_previous_30_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                    -1.0400
#  5662 2022-07-13                   -51.8897
#  5663 2022-07-14                    -3.7605
#  5664 2022-07-15                  -219.4850
#  5665 2022-07-16                   -16.0231
#
#  [5666 rows x 2 columns],
#             date  count_sent_previous_30_days
#  0    2007-01-11                          NaN
#  1    2007-01-12                          NaN
#  2    2007-01-13                          NaN
#  3    2007-01-14                          NaN
#  4    2007-01-15                          NaN
#  ...         ...                          ...
#  5661 2022-07-12                        398.0
#  5662 2022-07-13                        881.0
#  5663 2022-07-14                        744.0
#  5664 2022-07-15                       1994.0
#  5665 2022-07-16                        958.0
#
#  [5666 rows x 2 columns],
#             date  range_sent_previous_30_days
#  0    2007-01-11                          NaN
#  1    2007-01-12                          NaN
#  2    2007-01-13                          NaN
#  3    2007-01-14                          NaN
#  4    2007-01-15                          NaN
#  ...         ...                          ...
#  5661 2022-07-12                       1.9052
#  5662 2022-07-13                       1.9572
#  5663 2022-07-14                       1.9346
#  5664 2022-07-15                       1.9574
#  5665 2022-07-16                       1.9340
#
#  [5666 rows x 2 columns],
#             date  var_sent_previous_30_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                   0.268873
#  5662 2022-07-13                   0.235806
#  5663 2022-07-14                   0.241022
#  5664 2022-07-15                   0.212631
#  5665 2022-07-16                   0.247527
#
#  [5666 rows x 2 columns],
#             date  std_sent_previous_30_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                   0.517878
#  5662 2022-07-13                   0.485323
#  5663 2022-07-14                   0.490610
#  5664 2022-07-15                   0.461004
#  5665 2022-07-16                   0.497261
#
#  [5666 rows x 2 columns],
#             date  iqr_sent_previous_30_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                   0.899700
#  5662 2022-07-13                   0.837900
#  5663 2022-07-14                   0.788325
#  5664 2022-07-15                   0.599400
#  5665 2022-07-16                   0.763600
#
#  [5666 rows x 2 columns],
#             date  quantile_0.05_sent_previous_60_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5661 2022-07-12                            -0.890270
#  5662 2022-07-13                            -0.827185
#  5663 2022-07-14                            -0.798350
#  5664 2022-07-15                            -0.778300
#  5665 2022-07-16                            -0.812290
#
#  [5666 rows x 2 columns],
#             date  quantile_0.1_sent_previous_60_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                            -0.75736
#  5662 2022-07-13                            -0.73330
#  5663 2022-07-14                            -0.70815
#  5664 2022-07-15                            -0.64860
#  5665 2022-07-16                            -0.69840
#
#  [5666 rows x 2 columns],
#             date  quantile_0.2_sent_previous_60_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                            -0.52474
#  5662 2022-07-13                            -0.53742
#  5663 2022-07-14                            -0.50000
#  5664 2022-07-15                            -0.41940
#  5665 2022-07-16                            -0.45880
#
#  [5666 rows x 2 columns],
#             date  quantile_0.3_sent_previous_60_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                            -0.32737
#  5662 2022-07-13                            -0.29600
#  5663 2022-07-14                            -0.32520
#  5664 2022-07-15                            -0.25117
#  5665 2022-07-16                            -0.22630
#
#  [5666 rows x 2 columns],
#             date  quantile_0.4_sent_previous_60_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                            -0.03012
#  5662 2022-07-13                             0.00000
#  5663 2022-07-14                            -0.31820
#  5664 2022-07-15                             0.00000
#  5665 2022-07-16                             0.00000
#
#  [5666 rows x 2 columns],
#             date  quantile_0.5_sent_previous_60_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                                 0.0
#  5662 2022-07-13                                 0.0
#  5663 2022-07-14                                 0.0
#  5664 2022-07-15                                 0.0
#  5665 2022-07-16                                 0.0
#
#  [5666 rows x 2 columns],
#             date  quantile_0.6_sent_previous_60_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                             0.06860
#  5662 2022-07-13                             0.00516
#  5663 2022-07-14                             0.00000
#  5664 2022-07-15                             0.04396
#  5665 2022-07-16                             0.16294
#
#  [5666 rows x 2 columns],
#             date  quantile_0.7_sent_previous_60_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                             0.32583
#  5662 2022-07-13                             0.26347
#  5663 2022-07-14                             0.23425
#  5664 2022-07-15                             0.31820
#  5665 2022-07-16                             0.31820
#
#  [5666 rows x 2 columns],
#             date  quantile_0.8_sent_previous_60_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                             0.49718
#  5662 2022-07-13                             0.51222
#  5663 2022-07-14                             0.45880
#  5664 2022-07-15                             0.49614
#  5665 2022-07-16                             0.44040
#
#  [5666 rows x 2 columns],
#             date  quantile_0.9_sent_previous_60_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5661 2022-07-12                             0.69251
#  5662 2022-07-13                             0.70960
#  5663 2022-07-14                             0.65765
#  5664 2022-07-15                             0.69166
#  5665 2022-07-16                             0.67658
#
#  [5666 rows x 2 columns],
#             date  quantile_0.95_sent_previous_60_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5661 2022-07-12                             0.796110
#  5662 2022-07-13                             0.818360
#  5663 2022-07-14                             0.804025
#  5664 2022-07-15                             0.812600
#  5665 2022-07-16                             0.771700
#
#  [5666 rows x 2 columns],
#             date  mean_sent_previous_60_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5661 2022-07-12                   -0.008197
#  5662 2022-07-13                   -0.003316
#  5663 2022-07-14                   -0.053744
#  5664 2022-07-15                    0.020439
#  5665 2022-07-16                    0.019803
#
#  [5666 rows x 2 columns],
#             date  min_sent_previous_60_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                    -0.9554
#  5662 2022-07-13                    -0.9407
#  5663 2022-07-14                    -0.9601
#  5664 2022-07-15                    -0.9690
#  5665 2022-07-16                    -0.9792
#
#  [5666 rows x 2 columns],
#             date  max_sent_previous_60_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                     0.9446
#  5662 2022-07-13                     0.9595
#  5663 2022-07-14                     0.9571
#  5664 2022-07-15                     0.9704
#  5665 2022-07-16                     0.9590
#
#  [5666 rows x 2 columns],
#             date  sum_sent_previous_60_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                    -3.4590
#  5662 2022-07-13                    -1.0280
#  5663 2022-07-14                   -16.4457
#  5664 2022-07-15                    10.3015
#  5665 2022-07-16                     9.9607
#
#  [5666 rows x 2 columns],
#             date  count_sent_previous_60_days
#  0    2007-01-11                          NaN
#  1    2007-01-12                          NaN
#  2    2007-01-13                          NaN
#  3    2007-01-14                          NaN
#  4    2007-01-15                          NaN
#  ...         ...                          ...
#  5661 2022-07-12                        422.0
#  5662 2022-07-13                        310.0
#  5663 2022-07-14                        306.0
#  5664 2022-07-15                        504.0
#  5665 2022-07-16                        503.0
#
#  [5666 rows x 2 columns],
#             date  range_sent_previous_60_days
#  0    2007-01-11                          NaN
#  1    2007-01-12                          NaN
#  2    2007-01-13                          NaN
#  3    2007-01-14                          NaN
#  4    2007-01-15                          NaN
#  ...         ...                          ...
#  5661 2022-07-12                       1.9000
#  5662 2022-07-13                       1.9002
#  5663 2022-07-14                       1.9172
#  5664 2022-07-15                       1.9394
#  5665 2022-07-16                       1.9382
#
#  [5666 rows x 2 columns],
#             date  var_sent_previous_60_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
# ...
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                    -2.6166
#  5662 2022-07-13                    30.7725
#  5663 2022-07-14                    27.1471
#  5664 2022-07-15                    -6.6566
#  5665 2022-07-16                   -12.7955
#
#  [5666 rows x 2 columns],
#             date  count_sent_previous_90_days
#  0    2007-01-11                          NaN
#  1    2007-01-12                          NaN
#  2    2007-01-13                          NaN
#  3    2007-01-14                          NaN
#  4    2007-01-15                          NaN
#  ...         ...                          ...
#  5661 2022-07-12                        368.0
#  5662 2022-07-13                       1012.0
#  5663 2022-07-14                        527.0
#  5664 2022-07-15                        232.0
#  5665 2022-07-16                        220.0
#
#  [5666 rows x 2 columns],
#             date  range_sent_previous_90_days
#  0    2007-01-11                          NaN
#  1    2007-01-12                          NaN
#  2    2007-01-13                          NaN
#  3    2007-01-14                          NaN
#  4    2007-01-15                          NaN
#  ...         ...                          ...
#  5661 2022-07-12                       1.9151
#  5662 2022-07-13                       1.9147
#  5663 2022-07-14                       1.9345
#  5664 2022-07-15                       1.8920
#  5665 2022-07-16                       1.9625
#
#  [5666 rows x 2 columns],
#             date  var_sent_previous_90_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                   0.272463
#  5662 2022-07-13                   0.191030
#  5663 2022-07-14                   0.205170
#  5664 2022-07-15                   0.280327
#  5665 2022-07-16                   0.261664
#
#  [5666 rows x 2 columns],
#             date  std_sent_previous_90_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                   0.521270
#  5662 2022-07-13                   0.436853
#  5663 2022-07-14                   0.452528
#  5664 2022-07-15                   0.528317
#  5665 2022-07-16                   0.510367
#
#  [5666 rows x 2 columns],
#             date  iqr_sent_previous_90_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5661 2022-07-12                   0.898075
#  5662 2022-07-13                   0.676050
#  5663 2022-07-14                   0.587500
#  5664 2022-07-15                   0.919650
#  5665 2022-07-16                   0.890675
#
#  [5666 rows x 2 columns],
#             date  quantile_0.05_sent_previous_120_days
#  0    2007-01-11                                   NaN
#  1    2007-01-12                                   NaN
#  2    2007-01-13                                   NaN
#  3    2007-01-14                                   NaN
#  4    2007-01-15                                   NaN
#  ...         ...                                   ...
#  5661 2022-07-12                              -0.75096
#  5662 2022-07-13                              -0.80465
#  5663 2022-07-14                              -0.79986
#  5664 2022-07-15                              -0.80670
#  5665 2022-07-16                              -0.79720
#
#  [5666 rows x 2 columns],
#             date  quantile_0.1_sent_previous_120_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5661 2022-07-12                             -0.63880
#  5662 2022-07-13                             -0.68330
#  5663 2022-07-14                             -0.64374
#  5664 2022-07-15                             -0.69810
#  5665 2022-07-16                             -0.65970
#
#  [5666 rows x 2 columns],
#             date  quantile_0.2_sent_previous_120_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5661 2022-07-12                             -0.34836
#  5662 2022-07-13                             -0.49390
#  5663 2022-07-14                             -0.45880
#  5664 2022-07-15                             -0.51060
#  5665 2022-07-16                             -0.45880
#
#  [5666 rows x 2 columns],
#             date  quantile_0.3_sent_previous_120_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5661 2022-07-12                             -0.09760
#  5662 2022-07-13                             -0.18570
#  5663 2022-07-14                             -0.27446
#  5664 2022-07-15                             -0.31670
#  5665 2022-07-16                             -0.18740
#
#  [5666 rows x 2 columns],
#             date  quantile_0.4_sent_previous_120_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5661 2022-07-12                               0.0000
#  5662 2022-07-13                               0.0000
#  5663 2022-07-14                               0.0000
#  5664 2022-07-15                              -0.1027
#  5665 2022-07-16                               0.0000
#
#  [5666 rows x 2 columns],
#             date  quantile_0.5_sent_previous_120_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5661 2022-07-12                                  0.0
#  5662 2022-07-13                                  0.0
#  5663 2022-07-14                                  0.0
#  5664 2022-07-15                                  0.0
#  5665 2022-07-16                                  0.0
#
#  [5666 rows x 2 columns],
#             date  quantile_0.6_sent_previous_120_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5661 2022-07-12                              0.29600
#  5662 2022-07-13                              0.27320
#  5663 2022-07-14                              0.23104
#  5664 2022-07-15                              0.00000
#  5665 2022-07-16                              0.17790
#
#  [5666 rows x 2 columns],
#             date  quantile_0.7_sent_previous_120_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5661 2022-07-12                              0.42150
#  5662 2022-07-13                              0.44425
#  5663 2022-07-14                              0.42008
#  5664 2022-07-15                              0.27320
#  5665 2022-07-16                              0.36120
#
#  [5666 rows x 2 columns],
#             date  quantile_0.8_sent_previous_120_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5661 2022-07-12                              0.52828
#  5662 2022-07-13                              0.54230
#  5663 2022-07-14                              0.52670
#  5664 2022-07-15                              0.44040
#  5665 2022-07-16                              0.49270
#
#  [5666 rows x 2 columns],
#             date  quantile_0.9_sent_previous_120_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5661 2022-07-12                              0.73882
#  5662 2022-07-13                              0.71345
#  5663 2022-07-14                              0.70030
#  5664 2022-07-15                              0.65970
#  5665 2022-07-16                              0.63885
#
#  [5666 rows x 2 columns],
#             date  quantile_0.95_sent_previous_120_days
#  0    2007-01-11                                   NaN
#  1    2007-01-12                                   NaN
#  2    2007-01-13                                   NaN
#  3    2007-01-14                                   NaN
#  4    2007-01-15                                   NaN
#  ...         ...                                   ...
#  5661 2022-07-12                               0.80533
#  5662 2022-07-13                               0.82710
#  5663 2022-07-14                               0.76721
#  5664 2022-07-15                               0.77170
#  5665 2022-07-16                               0.77950
#
#  [5666 rows x 2 columns],
#             date  mean_sent_previous_120_days
#  0    2007-01-11                          NaN
#  1    2007-01-12                          NaN
#  2    2007-01-13                          NaN
#  3    2007-01-14                          NaN
#  4    2007-01-15                          NaN
#  ...         ...                          ...
#  5661 2022-07-12                     0.098309
#  5662 2022-07-13                     0.058973
#  5663 2022-07-14                     0.051948
#  5664 2022-07-15                    -0.021812
#  5665 2022-07-16                     0.035931
#
#  [5666 rows x 2 columns],
#             date  min_sent_previous_120_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5661 2022-07-12                     -0.9578
#  5662 2022-07-13                     -0.9300
#  5663 2022-07-14                     -0.9490
#  5664 2022-07-15                     -0.9545
#  5665 2022-07-16                     -0.9398
#
#  [5666 rows x 2 columns],
#             date  max_sent_previous_120_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5661 2022-07-12                      0.9545
#  5662 2022-07-13                      0.9492
#  5663 2022-07-14                      0.9260
#  5664 2022-07-15                      0.9571
#  5665 2022-07-16                      0.9509
#
#  [5666 rows x 2 columns],
#             date  sum_sent_previous_120_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5661 2022-07-12                     36.8659
#  5662 2022-07-13                     22.7634
#  5663 2022-07-14                     19.1170
#  5664 2022-07-15                     -9.1827
#  5665 2022-07-16                      8.4797
#
#  [5666 rows x 2 columns],
#             date  count_sent_previous_120_days
#  0    2007-01-11                           NaN
#  1    2007-01-12                           NaN
#  2    2007-01-13                           NaN
#  3    2007-01-14                           NaN
#  4    2007-01-15                           NaN
#  ...         ...                           ...
#  5661 2022-07-12                         375.0
#  5662 2022-07-13                         386.0
#  5663 2022-07-14                         368.0
#  5664 2022-07-15                         421.0
#  5665 2022-07-16                         236.0
#
#  [5666 rows x 2 columns],
#             date  range_sent_previous_120_days
#  0    2007-01-11                           NaN
#  1    2007-01-12                           NaN
#  2    2007-01-13                           NaN
#  3    2007-01-14                           NaN
#  4    2007-01-15                           NaN
#  ...         ...                           ...
#  5661 2022-07-12                        1.9123
#  5662 2022-07-13                        1.8792
#  5663 2022-07-14                        1.8750
#  5664 2022-07-15                        1.9116
#  5665 2022-07-16                        1.8907
#
#  [5666 rows x 2 columns],
#             date  var_sent_previous_120_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5661 2022-07-12                    0.235202
#  5662 2022-07-13                    0.256798
#  5663 2022-07-14                    0.252380
#  5664 2022-07-15                    0.235715
#  5665 2022-07-16                    0.230535
#
#  [5666 rows x 2 columns],
#             date  std_sent_previous_120_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5661 2022-07-12                    0.484329
#  5662 2022-07-13                    0.506095
#  5663 2022-07-14                    0.501691
#  5664 2022-07-15                    0.484928
#  5665 2022-07-16                    0.479122
#
#  [5666 rows x 2 columns],
#             date  iqr_sent_previous_120_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5661 2022-07-12                    0.746950
#  5662 2022-07-13                    0.812100
#  5663 2022-07-14                    0.803275
#  5664 2022-07-15                    0.777400
#  5665 2022-07-16                    0.781300
#
#  [5666 rows x 2 columns]]

# %%
##merge all data.frames
from functools import reduce

#merge them using reduce
df_merged = reduce(lambda left, right: pd.merge(left, right, on=['date'], how='inner'), [element for element in flat_list])
    #leave only those rows having date in the datasets of currency value and sentiment
    #https://stackoverflow.com/questions/44327999/python-pandas-merge-multiple-dataframes
df_merged
    #note that here the previous eur pricing can be different than the eur pricing of the previous row
    #because when merging we lose days without tweet sentiment, so there is no longer continuous days
# Out:
#            date  quantile_0.05_sent_previous_7_days  \
# 0    2007-01-11                                 NaN
# 1    2007-01-12                                 NaN
# 2    2007-01-13                                 NaN
# 3    2007-01-14                                 NaN
# 4    2007-01-15                                 NaN
# ...         ...                                 ...
# 5661 2022-07-12                           -0.844600
# 5662 2022-07-13                           -0.823660
# 5663 2022-07-14                           -0.865970
# 5664 2022-07-15                           -0.835185
# 5665 2022-07-16                           -0.818050
#
#       quantile_0.1_sent_previous_7_days  quantile_0.2_sent_previous_7_days  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 5661                           -0.75574                           -0.56900
# 5662                           -0.71752                           -0.52348
# 5663                           -0.76500                           -0.56614
# 5664                           -0.72949                           -0.55740
# 5665                           -0.73806                           -0.55652
#
#       quantile_0.3_sent_previous_7_days  quantile_0.4_sent_previous_7_days  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 5661                           -0.34000                           -0.17960
# 5662                           -0.30370                           -0.06174
# 5663                           -0.36015                           -0.13192
# 5664                           -0.40190                           -0.17790
# 5665                           -0.29330                           -0.02580
#
#       quantile_0.5_sent_previous_7_days  quantile_0.6_sent_previous_7_days  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 5661                                0.0                            0.00000
# 5662                                0.0                            0.08932
# 5663                                0.0                            0.02580
# 5664                                0.0                            0.00000
# 5665                                0.0                            0.20230
#
#       quantile_0.7_sent_previous_7_days  quantile_0.8_sent_previous_7_days  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 5661                             0.2328                            0.44040
# 5662                             0.3400                            0.49390
# 5663                             0.2732                            0.44050
# 5664                             0.2960                            0.45824
# 5665                             0.4215                            0.57190
#
#       ...  quantile_0.95_sent_previous_120_days  mean_sent_previous_120_days  \
# 0     ...                                   NaN                          NaN
# 1     ...                                   NaN                          NaN
# 2     ...                                   NaN                          NaN
# 3     ...                                   NaN                          NaN
# 4     ...                                   NaN                          NaN
# ...   ...                                   ...                          ...
# 5661  ...                               0.80533                     0.098309
# 5662  ...                               0.82710                     0.058973
# 5663  ...                               0.76721                     0.051948
# 5664  ...                               0.77170                    -0.021812
# 5665  ...                               0.77950                     0.035931
#
#       min_sent_previous_120_days  max_sent_previous_120_days  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
# ...                          ...                         ...
# 5661                     -0.9578                      0.9545
# 5662                     -0.9300                      0.9492
# 5663                     -0.9490                      0.9260
# 5664                     -0.9545                      0.9571
# 5665                     -0.9398                      0.9509
#
#       sum_sent_previous_120_days  count_sent_previous_120_days  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# ...                          ...                           ...
# 5661                     36.8659                         375.0
# 5662                     22.7634                         386.0
# 5663                     19.1170                         368.0
# 5664                     -9.1827                         421.0
# 5665                      8.4797                         236.0
#
#       range_sent_previous_120_days  var_sent_previous_120_days  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 5661                        1.9123                    0.235202
# 5662                        1.8792                    0.256798
# 5663                        1.8750                    0.252380
# 5664                        1.9116                    0.235715
# 5665                        1.8907                    0.230535
#
#       std_sent_previous_120_days  iqr_sent_previous_120_days
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
# ...                          ...                         ...
# 5661                    0.484329                    0.746950
# 5662                    0.506095                    0.812100
# 5663                    0.501691                    0.803275
# 5664                    0.484928                    0.777400
# 5665                    0.479122                    0.781300
#
# [5666 rows x 121 columns]

# %%
df_merged = df_merged.dropna()
df_merged
# Out:
#            date  quantile_0.05_sent_previous_7_days  \
# 715  2008-12-26                           -0.421500
# 723  2009-01-03                           -0.382230
# 726  2009-01-06                           -0.289160
# 734  2009-01-14                           -0.082160
# 740  2009-01-20                           -0.620675
# ...         ...                                 ...
# 5661 2022-07-12                           -0.844600
# 5662 2022-07-13                           -0.823660
# 5663 2022-07-14                           -0.865970
# 5664 2022-07-15                           -0.835185
# 5665 2022-07-16                           -0.818050
#
#       quantile_0.1_sent_previous_7_days  quantile_0.2_sent_previous_7_days  \
# 715                            -0.42150                           -0.27320
# 723                            -0.28776                           -0.09882
# 726                            -0.28232                           -0.25902
# 734                            -0.06162                           -0.02054
# 740                            -0.54105                           -0.38180
# ...                                 ...                                ...
# 5661                           -0.75574                           -0.56900
# 5662                           -0.71752                           -0.52348
# 5663                           -0.76500                           -0.56614
# 5664                           -0.72949                           -0.55740
# 5665                           -0.73806                           -0.55652
#
#       quantile_0.3_sent_previous_7_days  quantile_0.4_sent_previous_7_days  \
# 715                             0.00000                            0.00000
# 723                             0.09012                            0.19884
# 726                            -0.21648                           -0.08030
# 734                             0.00000                            0.00000
# 740                            -0.25565                           -0.12950
# ...                                 ...                                ...
# 5661                           -0.34000                           -0.17960
# 5662                           -0.30370                           -0.06174
# 5663                           -0.36015                           -0.13192
# 5664                           -0.40190                           -0.17790
# 5665                           -0.29330                           -0.02580
#
#       quantile_0.5_sent_previous_7_days  quantile_0.6_sent_previous_7_days  \
# 715                             0.00000                            0.00000
# 723                             0.26745                            0.33606
# 726                             0.10270                            0.27016
# 734                             0.00000                            0.00000
# 740                            -0.06475                            0.00000
# ...                                 ...                                ...
# 5661                            0.00000                            0.00000
# 5662                            0.00000                            0.08932
# 5663                            0.00000                            0.02580
# 5664                            0.00000                            0.00000
# 5665                            0.00000                            0.20230
#
#       quantile_0.7_sent_previous_7_days  quantile_0.8_sent_previous_7_days  \
# 715                             0.00000                            0.27320
# 723                             0.40128                            0.45972
# 726                             0.39322                            0.42748
# 734                             0.00000                            0.00000
# 740                             0.03860                            0.07720
# ...                                 ...                                ...
# 5661                            0.23280                            0.44040
# 5662                            0.34000                            0.49390
# 5663                            0.27320                            0.44050
# 5664                            0.29600                            0.45824
# 5665                            0.42150                            0.57190
#
#       ...  quantile_0.95_sent_previous_120_days  mean_sent_previous_120_days  \
# 715   ...                              0.212500                    -0.152625
# 723   ...                              0.694480                     0.049000
# 726   ...                              0.469205                     0.246950
# 734   ...                              0.281330                    -0.020057
# 740   ...                              0.321520                     0.080380
# ...   ...                                   ...                          ...
# 5661  ...                              0.805330                     0.098309
# 5662  ...                              0.827100                     0.058973
# 5663  ...                              0.767210                     0.051948
# 5664  ...                              0.771700                    -0.021812
# 5665  ...                              0.779500                     0.035931
#
#       min_sent_previous_120_days  max_sent_previous_120_days  \
# 715                      -0.5423                      0.2500
# 723                      -0.3818                      0.8020
# 726                       0.0000                      0.4939
# 734                      -0.5423                      0.4019
# 740                       0.0000                      0.4019
# ...                          ...                         ...
# 5661                     -0.9578                      0.9545
# 5662                     -0.9300                      0.9492
# 5663                     -0.9490                      0.9260
# 5664                     -0.9545                      0.9571
# 5665                     -0.9398                      0.9509
#
#       sum_sent_previous_120_days  count_sent_previous_120_days  \
# 715                      -0.6105                           4.0
# 723                       0.1470                           3.0
# 726                       0.4939                           2.0
# 734                      -0.1404                           7.0
# 740                       0.4019                           5.0
# ...                          ...                           ...
# 5661                     36.8659                         375.0
# 5662                     22.7634                         386.0
# 5663                     19.1170                         368.0
# 5664                     -9.1827                         421.0
# 5665                      8.4797                         236.0
#
#       range_sent_previous_120_days  var_sent_previous_120_days  \
# 715                         0.7923                    0.121554
# 723                         1.1838                    0.428205
# 726                         0.4939                    0.121969
# 734                         0.9442                    0.075466
# 740                         0.4019                    0.032305
# ...                            ...                         ...
# 5661                        1.9123                    0.235202
# 5662                        1.8792                    0.256798
# 5663                        1.8750                    0.252380
# 5664                        1.9116                    0.235715
# 5665                        1.8907                    0.230535
#
#       std_sent_previous_120_days  iqr_sent_previous_120_days
# 715                     0.301937                    0.436725
# 723                     0.534294                    0.591900
# 726                     0.246950                    0.246950
# 734                     0.254333                    0.000000
# 740                     0.160760                    0.000000
# ...                          ...                         ...
# 5661                    0.484329                    0.746950
# 5662                    0.506095                    0.812100
# 5663                    0.501691                    0.803275
# 5664                    0.484928                    0.777400
# 5665                    0.479122                    0.781300
#
# [4901 rows x 121 columns]

# %%
#check that all days with just 1 tweet have std=0
#np.unique(df_merged[df_merged["count_sent"] == 1]["std_sent"]) == 0

# %%
'''
##plot the metrics
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

#for each metric
for metric in metrics_sentiment:
    
    #open a plot with two panels
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15,4))

    #plot scatter against date and eur pricing
    ax1.scatter(x=df_merged["date"], y=df_merged[metric + "_sent"], s=0.5)
    ax2.scatter(x=df_merged["percent_change_pricing"], y=df_merged[metric + "_sent"], s=0.5)
    
    #set ylabel
    ax1.set_ylabel(metric + " negative sentiment")
    ax1.set_xlabel("Year")
    ax2.set_ylabel(metric + " negative sentiment")
    ax2.set_xlabel("Percent change in EUR/USD exchange rate")
    
    #close
    plt.show()
'''
# Out:
# '\n##plot the metrics\nimport matplotlib.pyplot as plt\nfrom matplotlib.pyplot import figure\n\n#for each metric\nfor metric in metrics_sentiment:\n    \n    #open a plot with two panels\n    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15,4))\n\n    #plot scatter against date and eur pricing\n    ax1.scatter(x=df_merged["date"], y=df_merged[metric + "_sent"], s=0.5)\n    ax2.scatter(x=df_merged["percent_change_pricing"], y=df_merged[metric + "_sent"], s=0.5)\n    \n    #set ylabel\n    ax1.set_ylabel(metric + " negative sentiment")\n    ax1.set_xlabel("Year")\n    ax2.set_ylabel(metric + " negative sentiment")\n    ax2.set_xlabel("Percent change in EUR/USD exchange rate")\n    \n    #close\n    plt.show()\n'

# %% [markdown]
# Mean shows that low currency values tend to be associated with high negative sentiment. As the value increase, there is more variation. With more negative but specially much more less negative days. This is even clearer for max. The main difference is that high currency values are associated with a lot of 0 negative days.
#
# It seems that once economic problems arise, then worries extend across economic agents and hence twitter, making less likely to have positive/neutral tweets.

# %%
#save the final data.frame with all metrics and eur pricing
df_merged.to_csv("results/twitter_sentiment_data.csv.gz", compression="gzip", index=False)
#df_merged = pd.read_csv("results/twitter_sentiment_data.csv.gz", compression="gzip")
