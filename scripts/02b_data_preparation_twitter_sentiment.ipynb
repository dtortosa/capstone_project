# %% [markdown]
# # Processing Twitter sentiment

# %%
#set the working directory
import os
os.chdir("/media/dftortosa/Windows/Users/dftor/Documents/diego_docs/industry/data_incubator/capstone_project/")

#check
os.getcwd()
# Out:
# '/media/dftortosa/Windows/Users/dftor/Documents/diego_docs/industry/data_incubator/capstone_project'

# %% [markdown]
# ## Loading tweet data

# %% [markdown]
# We include tweets about the BCE, which is the entity in charge of protecting the value of the euro, but also tweets about debt crisis in Europe, because this can negatively impact the expectations around the euro. Also tweets about the economy of Europe, because this can influence the expectations of economic agents around the Euro. Specially relevant those countries with sovereing debt problems. I have included countries that experienced high interest rates during the 2008 economic crisis (above 6%, e.g., Spain or Greece; [link](https://en.wikipedia.org/wiki/File:Long-term_interest_rates_(eurozone).png)) and countries that currently having a percentage of debt respect GDP above 85.8%, which is the average of the Euro area ([link](https://www.statista.com/statistics/269684/national-debt-in-eu-countries-in-relation-to-gross-domestic-product-gdp/)). This is specially relevant because the BCE not only acts to preserve the value of the euro but to avoid the bankruptcy of the members states, and both goals can be incompatible in certain circumstances (e.g., buy EU debt when at the same time you have to fight against inflation raising the interest rates). It is worth to mention that the Euros can be seen as liabilities that it has respect to those having euros. Of course, today we do not have gold standard, so we cannot go to the ECB ansd ask for an exchange in gold. However, the ECB has a mandate to control the value of the Euro so those with Euros will not lose value, because of this, there is a goal of 2% inflation per year, that is the limit. For example, if for eany reason there is an increase of inflation (e.g., due to high energy prices), the ECB should use its assets to buy Euros and hence remove them from circulation, this would decrease the offer of Euros, and hence increase the value of the currency. But what happens if the ECB has not enough assets to compensate? or he has assets of low quality like for example bonds from European countries with debt problems? The ECB could have difficulties to use gain capitalization through these assets and use it to stabilize Euro's value. The economic agents know this because they can see the balance of the ECB, and they can decide to go away from Euro. This sentiment of the economic agents for the Euro is what I am trying to catch here, using twitter for that.
#
# We are also going to include tweets about ECB'presidents as a way to cover better the setiment around this institution.

# %% [markdown]
# I am interested in the expectations of the economic agents about the Euro. If mane economic agents think and act in the same way, this is going to influence the demand and value of the currenct. For example, selling their euros because they expect a devaluation of the currency in the near future due to low confidence in Europe's economy. I am trying to capture the echoes of these expectations in twitter.
#
# This would be relevant for any componay interested in the prediction of currencies. If the consideration of the sentiment aroung the currency can help to improve predictions, they could do more advantageous trades. For example, for an american company doing business in Europe.

# %%
list_paths = ["search_euro_bank_twitter_1999_1_1.json",
              "hashtag_euro_bank_twitter_1999_1_1.json",
              "search_european_union_economy_twitter_1999_1_1.json",
              "search_eu_debt_crisis_twitter_1999_1_1.json", 
              "search_greece_economy_twitter_1999_1_1.json",
              "search_italy_economy_twitter_1999_1_1.json",
              "search_spain_economy_twitter_1999_1_1.json",
              "search_portugal_economy_twitter_1999_1_1.json",
              "search_cyprus_economy_twitter_1999_1_1.json",
              "search_slovenia_economy_twitter_1999_1_1.json",
              "search_france_economy_twitter_1999_1_1.json",
              "search_belgium_economy_twitter_1999_1_1.json",
              "search_croatia_economy_twitter_1999_1_1.json", 
              "search_ireland_economy_twitter_1999_1_1.json", 
              "search_trichet_twitter.json", 
              "hashtag_draghi_twitter.json", 
              "hashtag_lagarde_twitter.json"]
len(list_paths)
# Out:
# 17

# %%
# %%time
import multiprocessing as mp
import pandas as pd

def read_tweet_data(path):
    return pd.read_json("data/json_files/"+path, lines=True)

with mp.Pool(10) as pool:
    list_input_df = list(pool.map(read_tweet_data, list_paths))
        #for each row in tweets_df_en["rawContent"], apply sentiment_per_row across 10 cores
        #https://stackoverflow.com/questions/45545110/make-pandas-dataframe-apply-use-all-cores
    pool.close()
list_input_df
# Out:
# CPU times: user 1min 11s, sys: 15.6 s, total: 1min 26s
# Wall time: 1min 42s
# [                                 _type  \
#  0       snscrape.modules.twitter.Tweet
#  1       snscrape.modules.twitter.Tweet
#  2       snscrape.modules.twitter.Tweet
#  3       snscrape.modules.twitter.Tweet
#  4       snscrape.modules.twitter.Tweet
#  ...                                ...
#  479054  snscrape.modules.twitter.Tweet
#  479055  snscrape.modules.twitter.Tweet
#  479056  snscrape.modules.twitter.Tweet
#  479057  snscrape.modules.twitter.Tweet
#  479058  snscrape.modules.twitter.Tweet
#
#                                                        url  \
#  0       https://twitter.com/harisonhbn9718/status/1562...
#  1       https://twitter.com/TheBigArena/status/1562521...
#  2       https://twitter.com/DefoesInvest/status/156251...
#  3       https://twitter.com/N013Q/status/1562510373445...
#  4       https://twitter.com/CleanAirMoms/status/156249...
#  ...                                                   ...
#  479054        https://twitter.com/BBCWorld/status/5929582
#  479055     https://twitter.com/BBCBusiness/status/5909477
#  479056     https://twitter.com/BBCBusiness/status/5369405
#  479057        https://twitter.com/BBCWorld/status/5369342
#  479058     https://twitter.com/BBCBusiness/status/2622813
#
#                              date  \
#  0      2022-08-24 20:45:05+00:00
#  1      2022-08-24 19:26:32+00:00
#  2      2022-08-24 19:01:15+00:00
#  3      2022-08-24 18:41:17+00:00
#  4      2022-08-24 17:58:41+00:00
#  ...                          ...
#  479054 2007-03-08 12:52:14+00:00
#  479055 2007-03-07 18:10:33+00:00
#  479056 2007-02-08 13:00:17+00:00
#  479057 2007-02-08 12:51:03+00:00
#  479058 2007-01-11 12:50:45+00:00
#
#                                                 rawContent  \
#  0       Economic Calendar for Tomorrow:\n\n🇩🇪1) German...
#  1       #EURUSD at 0.99 for the first time since 2003....
#  2       The European Central Bank (ECB) is planning to...
#  3       In the digital economy, cash is no longer a us...
#  4       Reading: What the U.S. Federal Reserve must do...
#  ...                                                   ...
#  479054  The European Central Bank raises its key inter...
#  479055  The European Central Bank is expected to raise...
#  479056  The European Central Bank keeps its key intere...
#  479057  The European Central Bank keeps its key intere...
#  479058  The European Central Bank   keeps its key euro...
#
#                                            renderedContent  \
#  0       Economic Calendar for Tomorrow:\n\n🇩🇪1) German...
#  1       #EURUSD at 0.99 for the first time since 2003....
#  2       The European Central Bank (ECB) is planning to...
#  3       In the digital economy, cash is no longer a us...
#  4       Reading: What the U.S. Federal Reserve must do...
#  ...                                                   ...
#  479054  The European Central Bank raises its key inter...
#  479055  The European Central Bank is expected to raise...
#  479056  The European Central Bank keeps its key intere...
#  479057  The European Central Bank keeps its key intere...
#  479058  The European Central Bank   keeps its key euro...
#
#                           id  \
#  0       1562541528740151296
#  1       1562521759454138368
#  2       1562515396330422275
#  3       1562510373445545985
#  4       1562499651952996352
#  ...                     ...
#  479054              5929582
#  479055              5909477
#  479056              5369405
#  479057              5369342
#  479058              2622813
#
#                                                       user  replyCount  \
#  0       {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  1       {'_type': 'snscrape.modules.twitter.User', 'us...           1
#  2       {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  3       {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  4       {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  ...                                                   ...         ...
#  479054  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  479055  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  479056  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  479057  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  479058  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#          retweetCount  likeCount  ...  retweetedTweet  quotedTweet  \
#  0                  0          0  ...             NaN         None
#  1                  0          0  ...             NaN         None
#  2                  0          0  ...             NaN         None
#  3                  1          8  ...             NaN         None
#  4                  0          0  ...             NaN         None
#  ...              ...        ...  ...             ...          ...
#  479054             0          0  ...             NaN         None
#  479055             0          0  ...             NaN         None
#  479056             0          0  ...             NaN         None
#  479057             0          0  ...             NaN         None
#  479058             1          0  ...             NaN         None
#
#         inReplyToTweetId inReplyToUser mentionedUsers coordinates place  \
#  0                   NaN          None           None        None  None
#  1                   NaN          None           None        None  None
#  2                   NaN          None           None        None  None
#  3                   NaN          None           None        None  None
#  4                   NaN          None           None        None  None
#  ...                 ...           ...            ...         ...   ...
#  479054              NaN          None           None        None  None
#  479055              NaN          None           None        None  None
#  479056              NaN          None           None        None  None
#  479057              NaN          None           None        None  None
#  479058              NaN          None           None        None  None
#
#                    hashtags  cashtags  \
#  0                     None      None
#  1                 [EURUSD]      None
#  2       [defoes, defoesag]      None
#  3                     None      None
#  4                [Climate]      None
#  ...                    ...       ...
#  479054                None      None
#  479055                None      None
#  479056                None      None
#  479057                None      None
#  479058                None      None
#
#                                                       card
#  0                                                    None
#  1                                                    None
#  2                                                    None
#  3                                                    None
#  4       {'_type': 'snscrape.modules.twitter.SummaryCar...
#  ...                                                   ...
#  479054                                               None
#  479055                                               None
#  479056                                               None
#  479057                                               None
#  479058                                               None
#
#  [479059 rows x 28 columns],
#                                   _type  \
#  0       snscrape.modules.twitter.Tweet
#  1       snscrape.modules.twitter.Tweet
#  2       snscrape.modules.twitter.Tweet
#  3       snscrape.modules.twitter.Tweet
#  4       snscrape.modules.twitter.Tweet
#  ...                                ...
#  684130  snscrape.modules.twitter.Tweet
#  684131  snscrape.modules.twitter.Tweet
#  684132  snscrape.modules.twitter.Tweet
#  684133  snscrape.modules.twitter.Tweet
#  684134  snscrape.modules.twitter.Tweet
#
#                                                        url  \
#  0       https://twitter.com/Cryptschko/status/15484517...
#  1       https://twitter.com/AndrewHigsdrew/status/1548...
#  2       https://twitter.com/Bitcoin_Korea/status/15484...
#  3       https://twitter.com/BTCTN/status/1548442831143...
#  4       https://twitter.com/cricexec/status/1548442355...
#  ...                                                   ...
#  684130         https://twitter.com/canha/status/786509743
#  684131         https://twitter.com/canha/status/781707878
#  684132         https://twitter.com/canha/status/774147150
#  684133         https://twitter.com/canha/status/768229597
#  684134         https://twitter.com/canha/status/717583392
#
#                              date  \
#  0      2022-07-16 23:37:11+00:00
#  1      2022-07-16 23:27:03+00:00
#  2      2022-07-16 23:06:25+00:00
#  3      2022-07-16 23:01:54+00:00
#  4      2022-07-16 23:00:00+00:00
#  ...                          ...
#  684130 2008-04-10 15:00:39+00:00
#  684131 2008-04-02 20:31:49+00:00
#  684132 2008-03-19 22:59:43+00:00
#  684133 2008-03-07 21:29:25+00:00
#  684134 2008-02-15 21:39:47+00:00
#
#                                                 rawContent  \
#  0       Ist der EURO noch zu retten? (EZB in der Zwick...
#  1       #ECB Bond Tool Seen Having No Limits as Steepe...
#  2       #Digitaleuro to be more efficient as a means o...
#  3       #Digitaleuro to be more efficient as a means o...
#  4       .@ECB_cricket🏴󠁧󠁢󠁥󠁮󠁧󠁿: England Men name squads ...
#  ...                                                   ...
#  684130  Bem que hj podia ser sexta. E bem que eu podia...
#  684131  @allanrfs @nagueva e pessoal do #ecb - vide se...
#  684132  @webparatodos #ecb toda sexta, com excessão de...
#  684133  Tamo indo pro #ecb mais tarde (eu, o @aguinelo...
#  684134   Chegando no #ebc ou #ecb qse morrendo atropelado
#
#                                            renderedContent  \
#  0       Ist der EURO noch zu retten? (EZB in der Zwick...
#  1       #ECB Bond Tool Seen Having No Limits as Steepe...
#  2       #Digitaleuro to be more efficient as a means o...
#  3       #Digitaleuro to be more efficient as a means o...
#  4       .@ECB_cricket🏴󠁧󠁢󠁥󠁮󠁧󠁿: England Men name squads ...
#  ...                                                   ...
#  684130  Bem que hj podia ser sexta. E bem que eu podia...
#  684131  @allanrfs @nagueva e pessoal do #ecb - vide se...
#  684132  @webparatodos #ecb toda sexta, com excessão de...
#  684133  Tamo indo pro #ecb mais tarde (eu, o @aguinelo...
#  684134   Chegando no #ebc ou #ecb qse morrendo atropelado
#
#                           id  \
#  0       1548451710472839171
#  1       1548449160541548545
#  2       1548443968030928899
#  3       1548442831143849984
#  4       1548442355837022208
#  ...                     ...
#  684130            786509743
#  684131            781707878
#  684132            774147150
#  684133            768229597
#  684134            717583392
#
#                                                       user  replyCount  \
#  0       {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  1       {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  2       {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  3       {'_type': 'snscrape.modules.twitter.User', 'us...         108
#  4       {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  ...                                                   ...         ...
#  684130  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  684131  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  684132  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  684133  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  684134  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#          retweetCount  likeCount  ...  retweetedTweet  \
#  0                  0          0  ...             NaN
#  1                  0          0  ...             NaN
#  2                  0          0  ...             NaN
#  3                 44        140  ...             NaN
#  4                  0          0  ...             NaN
#  ...              ...        ...  ...             ...
#  684130             0          0  ...             NaN
#  684131             0          0  ...             NaN
#  684132             0          0  ...             NaN
#  684133             0          0  ...             NaN
#  684134             0          0  ...             NaN
#
#                                                quotedTweet inReplyToTweetId  \
#  0                                                    None              NaN
#  1                                                    None              NaN
#  2       {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
#  3                                                    None              NaN
#  4                                                    None              NaN
#  ...                                                   ...              ...
#  684130                                               None              NaN
#  684131                                               None      781626997.0
#  684132                                               None      774145855.0
#  684133                                               None              NaN
#  684134                                               None              NaN
#
#                                              inReplyToUser  \
#  0                                                    None
#  1                                                    None
#  2                                                    None
#  3                                                    None
#  4                                                    None
#  ...                                                   ...
#  684130                                               None
#  684131  {'_type': 'snscrape.modules.twitter.User', 'us...
#  684132  {'_type': 'snscrape.modules.twitter.User', 'us...
#  684133                                               None
#  684134                                               None
#
#                                             mentionedUsers coordinates place  \
#  0                                                    None        None  None
#  1                                                    None        None  None
#  2                                                    None        None  None
#  3                                                    None        None  None
#  4       [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  ...                                                   ...         ...   ...
#  684130                                               None        None  None
#  684131  [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  684132  [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  684133  [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  684134                                               None        None  None
#
#                                                   hashtags  cashtags  \
#  0                                  [euro, ecb, inflation]      None
#  1       [ECB, MoneyPrinting, Gold, Silver, Stimulus, Q...      None
#  2                    [Digitaleuro, cryptocurrencies, ECB]      None
#  3                    [Digitaleuro, cryptocurrencies, ECB]      None
#  4                           [ECB, EnglandCricket, ENGvSA]      None
#  ...                                                   ...       ...
#  684130                                              [ecb]      None
#  684131                                              [ecb]      None
#  684132                                              [ecb]      None
#  684133                                              [ecb]      None
#  684134                                         [ebc, ecb]      None
#
#                                                       card
#  0       {'_type': 'snscrape.modules.twitter.PlayerCard...
#  1       {'_type': 'snscrape.modules.twitter.SummaryCar...
#  2       {'_type': 'snscrape.modules.twitter.SummaryCar...
#  3       {'_type': 'snscrape.modules.twitter.SummaryCar...
#  4                                                    None
#  ...                                                   ...
#  684130                                               None
#  684131                                               None
#  684132                                               None
#  684133                                               None
#  684134                                               None
#
#  [684135 rows x 28 columns],
#                                  _type  \
#  0      snscrape.modules.twitter.Tweet
#  1      snscrape.modules.twitter.Tweet
#  2      snscrape.modules.twitter.Tweet
#  3      snscrape.modules.twitter.Tweet
#  4      snscrape.modules.twitter.Tweet
#  ...                               ...
#  32853  snscrape.modules.twitter.Tweet
#  32854  snscrape.modules.twitter.Tweet
#  32855  snscrape.modules.twitter.Tweet
#  32856  snscrape.modules.twitter.Tweet
#  32857  snscrape.modules.twitter.Tweet
#
#                                                       url  \
#  0      https://twitter.com/llCereal_Boxll/status/1562...
#  1      https://twitter.com/KGlevina/status/1562519572...
#  2      https://twitter.com/vivekkb07/status/156249702...
#  3      https://twitter.com/hathareskan/status/1562496...
#  4      https://twitter.com/finimage/status/1562457715...
#  ...                                                  ...
#  32853        https://twitter.com/EEPaul/status/811776556
#  32854      https://twitter.com/FRANCE24/status/798620499
#  32855  https://twitter.com/cnafrontpage/status/591802832
#  32856   https://twitter.com/BBCBusiness/status/100087342
#  32857  https://twitter.com/BBCScienceNews/status/1000...
#
#                             date  \
#  0     2022-08-24 22:57:47+00:00
#  1     2022-08-24 19:17:50+00:00
#  2     2022-08-24 17:48:15+00:00
#  3     2022-08-24 17:46:12+00:00
#  4     2022-08-24 15:12:03+00:00
#  ...                         ...
#  32853 2008-05-15 09:23:49+00:00
#  32854 2008-04-28 11:13:45+00:00
#  32855 2008-01-12 18:29:33+00:00
#  32856 2007-06-11 17:10:11+00:00
#  32857 2007-06-11 17:00:17+00:00
#
#                                                rawContent  \
#  0      @FeralJesus @LIFEWITHNUANCE @WhiskeyMutineer @...
#  1      especially about the energy. The contract betw...
#  2      GS3 Economy: The 12th Ministerial Conference (...
#  3      European Union’s economies are under considera...
#  4      @Douglas4Moray Surprise us, you're defending t...
#  ...                                                  ...
#  32853  European Union to promote use of ICT to improv...
#  32854  www.france24.com EUROPEAN UNION - ECONOMY: Bru...
#  32855  Strong euro reflects European economy: Barroso...
#  32856  The European Union's vision of building a hi-t...
#  32857  The European Union's vision of building a hi-t...
#
#                                           renderedContent                   id  \
#  0      @FeralJesus @LIFEWITHNUANCE @WhiskeyMutineer @...  1562574923326885888
#  1      especially about the energy. The contract betw...  1562519572678574085
#  2      GS3 Economy: The 12th Ministerial Conference (...  1562497025832546309
#  3      European Union’s economies are under considera...  1562496512034107393
#  4      @Douglas4Moray Surprise us, you're defending t...  1562457715490050051
#  ...                                                  ...                  ...
#  32853  European Union to promote use of ICT to improv...            811776556
#  32854  www.france24.com EUROPEAN UNION - ECONOMY: Bru...            798620499
#  32855  Strong euro reflects European economy: Barroso...            591802832
#  32856  The European Union's vision of building a hi-t...            100087342
#  32857  The European Union's vision of building a hi-t...            100069682
#
#                                                      user  replyCount  \
#  0      {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  1      {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  2      {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  3      {'_type': 'snscrape.modules.twitter.User', 'us...           1
#  4      {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  ...                                                  ...         ...
#  32853  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  32854  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  32855  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  32856  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  32857  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#         retweetCount  likeCount  ...  retweetedTweet  quotedTweet  \
#  0                 0          0  ...             NaN         None
#  1                 0          0  ...             NaN         None
#  2                 0          0  ...             NaN         None
#  3                 0          0  ...             NaN         None
#  4                 0          0  ...             NaN         None
#  ...             ...        ...  ...             ...          ...
#  32853             0          0  ...             NaN         None
#  32854             0          0  ...             NaN         None
#  32855             0          0  ...             NaN         None
#  32856             0          0  ...             NaN         None
#  32857             0          0  ...             NaN         None
#
#        inReplyToTweetId                                      inReplyToUser  \
#  0         1.562573e+18  {'_type': 'snscrape.modules.twitter.User', 'us...
#  1                  NaN                                               None
#  2                  NaN                                               None
#  3         1.562470e+18  {'_type': 'snscrape.modules.twitter.User', 'us...
#  4         1.562360e+18  {'_type': 'snscrape.modules.twitter.User', 'us...
#  ...                ...                                                ...
#  32853              NaN                                               None
#  32854              NaN                                               None
#  32855              NaN                                               None
#  32856              NaN                                               None
#  32857              NaN                                               None
#
#                                            mentionedUsers coordinates place  \
#  0      [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  1                                                   None        None  None
#  2                                                   None        None  None
#  3                                                   None        None  None
#  4      [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  ...                                                  ...         ...   ...
#  32853                                               None        None  None
#  32854                                               None        None  None
#  32855                                               None        None  None
#  32856                                               None        None  None
#  32857                                               None        None  None
#
#        hashtags  cashtags                                               card
#  0         None      None                                               None
#  1         None      None                                               None
#  2         None      None  {'_type': 'snscrape.modules.twitter.SummaryCar...
#  3         None      None                                               None
#  4         None      None                                               None
#  ...        ...       ...                                                ...
#  32853     None      None                                               None
#  32854     None      None                                               None
#  32855     None      None                                               None
#  32856     None      None                                               None
#  32857     None      None                                               None
#
#  [32858 rows x 28 columns],
#                                  _type  \
#  0      snscrape.modules.twitter.Tweet
#  1      snscrape.modules.twitter.Tweet
#  2      snscrape.modules.twitter.Tweet
#  3      snscrape.modules.twitter.Tweet
#  4      snscrape.modules.twitter.Tweet
#  ...                               ...
#  74302  snscrape.modules.twitter.Tweet
#  74303  snscrape.modules.twitter.Tweet
#  74304  snscrape.modules.twitter.Tweet
#  74305  snscrape.modules.twitter.Tweet
#  74306  snscrape.modules.twitter.Tweet
#
#                                                       url  \
#  0      https://twitter.com/sco15375772/status/1562203...
#  1      https://twitter.com/jontheholder/status/156202...
#  2      https://twitter.com/GreekFire23/status/1561855...
#  3      https://twitter.com/Jay35574472/status/1561731...
#  4      https://twitter.com/TLDRNewsEU/status/15616877...
#  ...                                                  ...
#  74302  https://twitter.com/bajorgensen/status/3845338289
#  74303   https://twitter.com/OPEN_INTEL/status/2028278239
#  74304    https://twitter.com/Telegraph/status/2019958141
#  74305  https://twitter.com/HuffPostPol/status/1295980976
#  74306         https://twitter.com/biffo/status/955883092
#
#                             date  \
#  0     2022-08-23 22:20:26+00:00
#  1     2022-08-23 10:49:07+00:00
#  2     2022-08-22 23:17:38+00:00
#  3     2022-08-22 15:05:29+00:00
#  4     2022-08-22 12:12:19+00:00
#  ...                         ...
#  74302 2009-09-08 18:24:18+00:00
#  74303 2009-06-04 11:22:49+00:00
#  74304 2009-06-03 19:17:14+00:00
#  74305 2009-03-08 10:29:52+00:00
#  74306 2008-10-11 22:07:15+00:00
#
#                                                rawContent  \
#  0      The EU spent 4 years prevaricating over the so...
#  1      @stackhodler Hyperinflation &amp; fiat system ...
#  2      @merrillmatter Lol, no. If the EU didn’t disso...
#  3      @clkleinmonaco The EU debt crisis in 2011 will...
#  4      If you want to learn more about Greece's debt ...
#  ...                                                  ...
#  74302  RUMOR: Close trading partner to the #EU in sov...
#  74303  #economy #risks #EU Latvian debt crisis shakes...
#  74304  Latvian debt crisis shakes Eastern Europe: Lat...
#  74305  Sober reading on EU debt crisis. When US catch...
#  74306  Cowen for EU meeting on debt crisis - RTE.ie h...
#
#                                           renderedContent                   id  \
#  0      The EU spent 4 years prevaricating over the so...  1562203135166533632
#  1      @stackhodler Hyperinflation &amp; fiat system ...  1562029160352153601
#  2      @merrillmatter Lol, no. If the EU didn’t disso...  1561855141023711232
#  3      @clkleinmonaco The EU debt crisis in 2011 will...  1561731290050838529
#  4      If you want to learn more about Greece's debt ...  1561687709781037057
#  ...                                                  ...                  ...
#  74302  RUMOR: Close trading partner to the #EU in sov...           3845338289
#  74303  #economy #risks #EU Latvian debt crisis shakes...           2028278239
#  74304  Latvian debt crisis shakes Eastern Europe: Lat...           2019958141
#  74305  Sober reading on EU debt crisis. When US catch...           1295980976
#  74306  Cowen for EU meeting on debt crisis - RTE.ie h...            955883092
#
#                                                      user  replyCount  \
#  0      {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  1      {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  2      {'_type': 'snscrape.modules.twitter.User', 'us...           1
#  3      {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  4      {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  ...                                                  ...         ...
#  74302  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  74303  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  74304  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  74305  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  74306  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#         retweetCount  likeCount  ...  retweetedTweet  quotedTweet  \
#  0                 0          5  ...             NaN         None
#  1                 0          0  ...             NaN         None
#  2                 0          5  ...             NaN         None
#  3                 0          0  ...             NaN         None
#  4                 1         18  ...             NaN         None
#  ...             ...        ...  ...             ...          ...
#  74302             0          0  ...             NaN         None
#  74303             0          0  ...             NaN         None
#  74304             0          0  ...             NaN         None
#  74305             0          0  ...             NaN         None
#  74306             0          0  ...             NaN         None
#
#        inReplyToTweetId                                      inReplyToUser  \
#  0         1.562203e+18  {'_type': 'snscrape.modules.twitter.User', 'us...
#  1         1.562010e+18  {'_type': 'snscrape.modules.twitter.User', 'us...
#  2         1.561845e+18  {'_type': 'snscrape.modules.twitter.User', 'us...
#  3         1.561707e+18  {'_type': 'snscrape.modules.twitter.User', 'us...
#  4         1.561687e+18  {'_type': 'snscrape.modules.twitter.User', 'us...
#  ...                ...                                                ...
#  74302              NaN                                               None
#  74303              NaN                                               None
#  74304              NaN                                               None
#  74305              NaN                                               None
#  74306              NaN                                               None
#
#                                            mentionedUsers coordinates place  \
#  0                                                   None        None  None
#  1      [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  2      [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  3      [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  4                                                   None        None  None
#  ...                                                  ...         ...   ...
#  74302                                               None        None  None
#  74303                                               None        None  None
#  74304                                               None        None  None
#  74305                                               None        None  None
#  74306                                               None        None  None
#
#                             hashtags  cashtags  \
#  0                              None      None
#  1                              None      None
#  2                              None      None
#  3                              None      None
#  4                              None      None
#  ...                             ...       ...
#  74302   [EU, IMF, finance, economy]      None
#  74303          [economy, risks, EU]      None
#  74304                          None      None
#  74305  [topprog, journotwits, tcot]      None
#  74306                          None      None
#
#                                                      card
#  0                                                   None
#  1                                                   None
#  2                                                   None
#  3                                                   None
#  4      {'_type': 'snscrape.modules.twitter.PlayerCard...
#  ...                                                  ...
#  74302                                               None
#  74303                                               None
#  74304                                               None
#  74305                                               None
#  74306                                               None
#
#  [74307 rows x 28 columns],
#                                   _type  \
#  0       snscrape.modules.twitter.Tweet
#  1       snscrape.modules.twitter.Tweet
#  2       snscrape.modules.twitter.Tweet
#  3       snscrape.modules.twitter.Tweet
#  4       snscrape.modules.twitter.Tweet
#  ...                                ...
#  250498  snscrape.modules.twitter.Tweet
#  250499  snscrape.modules.twitter.Tweet
#  250500  snscrape.modules.twitter.Tweet
#  250501  snscrape.modules.twitter.Tweet
#  250502  snscrape.modules.twitter.Tweet
#
#                                                        url  \
#  0       https://twitter.com/MrMarchi/status/1562549351...
#  1       https://twitter.com/MrSkanner/status/156254934...
#  2       https://twitter.com/MikeGal44340608/status/156...
#  3       https://twitter.com/HalfHal18768994/status/156...
#  4       https://twitter.com/FirewallB/status/156251305...
#  ...                                                   ...
#  250498      https://twitter.com/tillski/status/1045650985
#  250499     https://twitter.com/photoshae/status/893598156
#  250500      https://twitter.com/saliment/status/847328820
#  250501       https://twitter.com/karagos/status/605066902
#  250502  https://twitter.com/chrisjohnston/status/24319...
#
#                              date  \
#  0      2022-08-24 21:16:10+00:00
#  1      2022-08-24 21:16:08+00:00
#  2      2022-08-24 19:39:30+00:00
#  3      2022-08-24 19:29:30+00:00
#  4      2022-08-24 18:51:57+00:00
#  ...                          ...
#  250498 2008-12-08 20:05:08+00:00
#  250499 2008-08-20 19:26:56+00:00
#  250500 2008-07-01 02:31:42+00:00
#  250501 2008-01-16 11:46:58+00:00
#  250502 2007-09-02 22:38:53+00:00
#
#                                                 rawContent  \
#  0       #CCPinCEE Chinese Influence in Greece\n\n-- Po...
#  1       #CCPinCEE Chinese Influence in Greece\n\n-- Po...
#  2       @MarkGerretsen Are you saying Switzerland is n...
#  3       @RobertM12997643 @staylorish It contributes 8%...
#  4       @JimmyLemke @THEDJQUEEN @RawieDarren @ALT_DOJ ...
#  ...                                                   ...
#  250498  searching for some backround-facts about the r...
#  250499  @pistachio you think China's going to be in de...
#  250500  Turkey now has the 17th largest economy in the...
#  250501  Greece dials up growth Broadband is poised to ...
#  250502  1st class tickets to Greece for next summer ar...
#
#                                            renderedContent  \
#  0       #CCPinCEE Chinese Influence in Greece\n\n-- Po...
#  1       #CCPinCEE Chinese Influence in Greece\n\n-- Po...
#  2       @MarkGerretsen Are you saying Switzerland is n...
#  3       @RobertM12997643 @staylorish It contributes 8%...
#  4       @JimmyLemke @THEDJQUEEN @RawieDarren @ALT_DOJ ...
#  ...                                                   ...
#  250498  searching for some backround-facts about the r...
#  250499  @pistachio you think China's going to be in de...
#  250500  Turkey now has the 17th largest economy in the...
#  250501  Greece dials up growth Broadband is poised to ...
#  250502  1st class tickets to Greece for next summer ar...
#
#                           id  \
#  0       1562549351989538816
#  1       1562549340614586368
#  2       1562525022597435393
#  3       1562522506363568128
#  4       1562513056701116416
#  ...                     ...
#  250498           1045650985
#  250499            893598156
#  250500            847328820
#  250501            605066902
#  250502            243198412
#
#                                                       user  replyCount  \
#  0       {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  1       {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  2       {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  3       {'_type': 'snscrape.modules.twitter.User', 'us...           1
#  4       {'_type': 'snscrape.modules.twitter.User', 'us...           1
#  ...                                                   ...         ...
#  250498  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  250499  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  250500  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  250501  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  250502  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#          retweetCount  likeCount  ...  retweetedTweet  quotedTweet  \
#  0                  0          0  ...             NaN         None
#  1                  0          0  ...             NaN         None
#  2                  0          0  ...             NaN         None
#  3                  0          1  ...             NaN         None
#  4                  0          2  ...             NaN         None
#  ...              ...        ...  ...             ...          ...
#  250498             0          0  ...             NaN         None
#  250499             0          0  ...             NaN         None
#  250500             0          0  ...             NaN         None
#  250501             0          0  ...             NaN         None
#  250502             0          0  ...             NaN         None
#
#         inReplyToTweetId                                      inReplyToUser  \
#  0                   NaN                                               None
#  1                   NaN                                               None
#  2          1.562392e+18  {'_type': 'snscrape.modules.twitter.User', 'us...
#  3          1.562517e+18  {'_type': 'snscrape.modules.twitter.User', 'us...
#  4          1.562512e+18  {'_type': 'snscrape.modules.twitter.User', 'us...
#  ...                 ...                                                ...
#  250498              NaN                                               None
#  250499     8.935784e+08  {'_type': 'snscrape.modules.twitter.User', 'us...
#  250500              NaN                                               None
#  250501              NaN                                               None
#  250502              NaN                                               None
#
#                                             mentionedUsers coordinates place  \
#  0                                                    None        None  None
#  1                                                    None        None  None
#  2       [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  3       [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  4       [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  ...                                                   ...         ...   ...
#  250498                                               None        None  None
#  250499  [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  250500                                               None        None  None
#  250501                                               None        None  None
#  250502                                               None        None  None
#
#                                  hashtags  cashtags  \
#  0       [CCPinCEE, Coronavirus, Economy]      None
#  1       [CCPinCEE, Coronavirus, Economy]      None
#  2                                   None      None
#  3                                   None      None
#  4                                   None      None
#  ...                                  ...       ...
#  250498                              None      None
#  250499                              None      None
#  250500                              None      None
#  250501                              None      None
#  250502                              None      None
#
#                                                       card
#  0       {'_type': 'snscrape.modules.twitter.SummaryCar...
#  1       {'_type': 'snscrape.modules.twitter.SummaryCar...
#  2                                                    None
#  3                                                    None
#  4                                                    None
#  ...                                                   ...
#  250498                                               None
#  250499                                               None
#  250500                                               None
#  250501                                               None
#  250502                                               None
#
#  [250503 rows x 28 columns],
#                                   _type  \
#  0       snscrape.modules.twitter.Tweet
#  1       snscrape.modules.twitter.Tweet
#  2       snscrape.modules.twitter.Tweet
#  3       snscrape.modules.twitter.Tweet
#  4       snscrape.modules.twitter.Tweet
#  ...                                ...
#  173923  snscrape.modules.twitter.Tweet
#  173924  snscrape.modules.twitter.Tweet
#  173925  snscrape.modules.twitter.Tweet
#  173926  snscrape.modules.twitter.Tweet
#  173927  snscrape.modules.twitter.Tweet
#
#                                                        url  \
#  0       https://twitter.com/the_comms_guy/status/15625...
#  1       https://twitter.com/Samuel96306657/status/1562...
#  2       https://twitter.com/Kotoid1/status/15625636126...
#  3       https://twitter.com/delphinoto/status/15625606...
#  4       https://twitter.com/AlexFergus0n/status/156255...
#  ...                                                   ...
#  173923  https://twitter.com/nytimesworld/status/355601972
#  173924       https://twitter.com/nytimes/status/355362222
#  173925       https://twitter.com/rtenews/status/314357922
#  173926  https://twitter.com/absolutesubzero/status/281...
#  173927   https://twitter.com/BBCBusiness/status/198050082
#
#                              date  \
#  0      2022-08-24 22:52:51+00:00
#  1      2022-08-24 22:24:00+00:00
#  2      2022-08-24 22:12:50+00:00
#  3      2022-08-24 22:00:57+00:00
#  4      2022-08-24 21:34:40+00:00
#  ...                          ...
#  173923 2007-10-22 21:06:28+00:00
#  173924 2007-10-22 19:05:58+00:00
#  173925 2007-10-05 14:36:31+00:00
#  173926 2007-09-20 08:44:29+00:00
#  173927 2007-08-10 11:20:11+00:00
#
#                                                 rawContent  \
#  0       @RiZMiGGeNiUS @ChrisWohoa @shashj Yep, Russia,...
#  1       Мы подписали новые соглашения по увеличению по...
#  2       @Zontar_Dow @devtrospective @Internet_TLCM Exc...
#  3       @_gpop @NFT_Shooter bonkers you need to be a r...
#  4       @MikeyTheBuddie @tbablue1 @iScotGov @QP12Guy @...
#  ...                                                   ...
#  173923  Organized Crime Takes Lead in Italy’s Economy ...
#  173924  Organized Crime Takes Lead in Italy’s Economy ...
#  173925  Uproar over tax break for Italy's ‘big babies'...
#  173926  Italy is a nice place except for health, techn...
#  173927  Italy's economy grew just 0.1% in the past qua...
#
#                                            renderedContent  \
#  0       @RiZMiGGeNiUS @ChrisWohoa @shashj Yep, Russia,...
#  1       Мы подписали новые соглашения по увеличению по...
#  2       @Zontar_Dow @devtrospective @Internet_TLCM Exc...
#  3       @_gpop @NFT_Shooter bonkers you need to be a r...
#  4       @MikeyTheBuddie @tbablue1 @iScotGov @QP12Guy @...
#  ...                                                   ...
#  173923  Organized Crime Takes Lead in Italy’s Economy ...
#  173924  Organized Crime Takes Lead in Italy’s Economy ...
#  173925  Uproar over tax break for Italy's ‘big babies'...
#  173926  Italy is a nice place except for health, techn...
#  173927  Italy's economy grew just 0.1% in the past qua...
#
#                           id  \
#  0       1562573683042164736
#  1       1562566419895570437
#  2       1562563612614397954
#  3       1562560621576474624
#  4       1562554004889997313
#  ...                     ...
#  173923            355601972
#  173924            355362222
#  173925            314357922
#  173926            281087742
#  173927            198050082
#
#                                                       user  replyCount  \
#  0       {'_type': 'snscrape.modules.twitter.User', 'us...           2
#  1       {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  2       {'_type': 'snscrape.modules.twitter.User', 'us...           2
#  3       {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  4       {'_type': 'snscrape.modules.twitter.User', 'us...           1
#  ...                                                   ...         ...
#  173923  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  173924  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  173925  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  173926  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  173927  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#          retweetCount  likeCount  ...  retweetedTweet  quotedTweet  \
#  0                  0          5  ...             NaN         None
#  1                  0          0  ...             NaN         None
#  2                  0          0  ...             NaN         None
#  3                  0          1  ...             NaN         None
#  4                  1          3  ...             NaN         None
#  ...              ...        ...  ...             ...          ...
#  173923             0          0  ...             NaN         None
#  173924             0          1  ...             NaN         None
#  173925             0          0  ...             NaN         None
#  173926             0          1  ...             NaN         None
#  173927             0          0  ...             NaN         None
#
#         inReplyToTweetId                                      inReplyToUser  \
#  0          1.562566e+18  {'_type': 'snscrape.modules.twitter.User', 'us...
#  1                   NaN                                               None
#  2          1.562562e+18  {'_type': 'snscrape.modules.twitter.User', 'us...
#  3          1.562512e+18  {'_type': 'snscrape.modules.twitter.User', 'us...
#  4          1.562553e+18  {'_type': 'snscrape.modules.twitter.User', 'us...
#  ...                 ...                                                ...
#  173923              NaN                                               None
# ...
#  2       non ho capito perchè tutti lodano il mandato a...
#  3       Private banks must be indipendent Mr #Draghi, ...
#  4       @RevolteRevoltee Les fidèles devant leur gouro...
#  ...                                                   ...
#  238953  #EU leaders appoint Italian Mario Draghi presi...
#  238954  Mario #Draghi officiellement nommé à la tête d...
#  238955  Yesterday #EUCO delayed decision to appoint #D...
#  238956  RT@bankingnewsgr Το Ευρωπαϊκό Συμβούλιο διόρισ...
#  238957  Goldman Sachs enters the ECB bit.ly/k5I5A8 #Dr...
#
#                           id  \
#  0       1189673568986128385
#  1       1189671591665377280
#  2       1189669552931647488
#  3       1189668967427776519
#  4       1189664043599941633
#  ...                     ...
#  238953    84152505986072576
#  238954    84149890992713728
#  238955    84148969013387264
#  238956    84146480172113920
#  238957    84146103389401088
#
#                                                       user  replyCount  \
#  0       {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  1       {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  2       {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  3       {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  4       {'_type': 'snscrape.modules.twitter.User', 'us...           1
#  ...                                                   ...         ...
#  238953  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  238954  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  238955  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  238956  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  238957  {'_type': 'snscrape.modules.twitter.User', 'us...           3
#
#          retweetCount  likeCount  ...  retweetedTweet  \
#  0                  0          0  ...             NaN
#  1                 22         21  ...             NaN
#  2                  0          1  ...             NaN
#  3                  0          1  ...             NaN
#  4                  1          2  ...             NaN
#  ...              ...        ...  ...             ...
#  238953             0          0  ...             NaN
#  238954             0          0  ...             NaN
#  238955             0          0  ...             NaN
#  238956             0          0  ...             NaN
#  238957             1          0  ...             NaN
#
#                                                quotedTweet inReplyToTweetId  \
#  0                                                    None              NaN
#  1                                                    None              NaN
#  2                                                    None              NaN
#  3       {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
#  4                                                    None     1.189653e+18
#  ...                                                   ...              ...
#  238953                                               None              NaN
#  238954                                               None              NaN
#  238955                                               None              NaN
#  238956                                               None              NaN
#  238957                                               None              NaN
#
#                                              inReplyToUser  \
#  0                                                    None
#  1                                                    None
#  2                                                    None
#  3                                                    None
#  4       {'_type': 'snscrape.modules.twitter.User', 'us...
#  ...                                                   ...
#  238953                                               None
#  238954                                               None
#  238955                                               None
#  238956                                               None
#  238957                                               None
#
#                                             mentionedUsers coordinates place  \
#  0       [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  1                                                    None        None  None
#  2                                                    None        None  None
#  3       [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  4       [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  ...                                                   ...         ...   ...
#  238953                                               None        None  None
#  238954                                               None        None  None
#  238955                                               None        None  None
#  238956  [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  238957                                               None        None  None
#
#                                                   hashtags  cashtags  \
#  0                [EZB, Draghi, Merkel, Minuszinsen, Euro]      None
#  1                                      [FakeNews, Draghi]      None
#  2       [BCE, Mario, Draghi, cartabianca, Carta, carta...      None
#  3                                                [Draghi]      None
#  4                [Zemmour, Draghi, BCE, ChristineLagarde]      None
#  ...                                                   ...       ...
#  238953                        [EU, Draghi, ECB, EUsummit]      None
#  238954                                      [Draghi, BCE]      None
#  238955                           [EUCO, Draghi, ECB, ECB]      None
#  238956                                           [Draghi]      None
#  238957                                [Draghi, ECB, euro]      None
#
#                                                       card
#  0       {'_type': 'snscrape.modules.twitter.SummaryCar...
#  1       {'_type': 'snscrape.modules.twitter.SummaryCar...
#  2                                                    None
#  3                                                    None
#  4                                                    None
#  ...                                                   ...
#  238953                                               None
#  238954                                               None
#  238955                                               None
#  238956                                               None
#  238957                                               None
#
#  [238958 rows x 28 columns],
#                                  _type  \
#  0      snscrape.modules.twitter.Tweet
#  1      snscrape.modules.twitter.Tweet
#  2      snscrape.modules.twitter.Tweet
#  3      snscrape.modules.twitter.Tweet
#  4      snscrape.modules.twitter.Tweet
#  ...                               ...
#  34302  snscrape.modules.twitter.Tweet
#  34303  snscrape.modules.twitter.Tweet
#  34304  snscrape.modules.twitter.Tweet
#  34305  snscrape.modules.twitter.Tweet
#  34306  snscrape.modules.twitter.Tweet
#
#                                                       url  \
#  0      https://twitter.com/HMKnapp/status/15625528952...
#  1      https://twitter.com/CantillonCH/status/1562500...
#  2      https://twitter.com/Ronniemarkets/status/15624...
#  3      https://twitter.com/YvesPDB/status/15623990663...
#  4      https://twitter.com/malaky95/status/1562340262...
#  ...                                                  ...
#  34302  https://twitter.com/platowverlag/status/117387...
#  34303  https://twitter.com/jabkees/status/11738629618...
#  34304  https://twitter.com/FerranFont/status/11738617...
#  34305  https://twitter.com/EricVanraes/status/1173861...
#  34306  https://twitter.com/euroecolos/status/11738585...
#
#                             date  \
#  0     2022-08-24 21:30:15+00:00
#  1     2022-08-24 18:02:35+00:00
#  2     2022-08-24 13:18:25+00:00
#  3     2022-08-24 11:19:00+00:00
#  4     2022-08-24 07:25:20+00:00
#  ...                         ...
#  34302 2019-09-17 08:04:13+00:00
#  34303 2019-09-17 07:35:14+00:00
#  34304 2019-09-17 07:30:17+00:00
#  34305 2019-09-17 07:29:30+00:00
#  34306 2019-09-17 07:17:50+00:00
#
#                                                rawContent  \
#  0      Unsere Mannschaft*Innen verstehen ja auch nich...
#  1      The slow fuse of secular decline, lit by the g...
#  2      She hasn’t  got a clue #lagarde https://t.co/S...
#  3      @Mr_Frexit Bravo #Macron !Bravo #UrsulaVonDerL...
#  4      Petit #running les pieds dans le sable et l'ea...
#  ...                                                  ...
#  34302  Pulver endgültig verschossen, #EZB-Rat tief ge...
#  34303  #ECB, i.c. #Draghi, bedrijft politiek; dat wor...
#  34304  ¿Cómo serán las #hipotecas con #Lagarde al fre...
#  34305  Ma chronique hebdo taux @allnews_ch #Powell #f...
#  34306  Rencontre avec la presse européenne en #PlenPE...
#
#                                           renderedContent                   id  \
#  0      Unsere Mannschaft*Innen verstehen ja auch nich...  1562552895228477441
#  1      The slow fuse of secular decline, lit by the g...  1562500633244356617
#  2      She hasn’t  got a clue #lagarde twitter.com/ab...  1562429120138526722
#  3      @Mr_Frexit Bravo #Macron !Bravo #UrsulaVonDerL...  1562399066310451200
#  4      Petit #running les pieds dans le sable et l'ea...  1562340262097162240
#  ...                                                  ...                  ...
#  34302  Pulver endgültig verschossen, #EZB-Rat tief ge...  1173870255543902214
#  34303  #ECB, i.c. #Draghi, bedrijft politiek; dat wor...  1173862961817014273
#  34304  ¿Cómo serán las #hipotecas con #Lagarde al fre...  1173861717358665728
#  34305  Ma chronique hebdo taux @allnews_ch #Powell #f...  1173861522092765184
#  34306  Rencontre avec la presse européenne en #PlenPE...  1173858586470080512
#
#                                                      user  replyCount  \
#  0      {'_type': 'snscrape.modules.twitter.User', 'us...           1
#  1      {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  2      {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  3      {'_type': 'snscrape.modules.twitter.User', 'us...          10
#  4      {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  ...                                                  ...         ...
#  34302  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  34303  {'_type': 'snscrape.modules.twitter.User', 'us...           1
#  34304  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  34305  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#  34306  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#         retweetCount  likeCount  ...  retweetedTweet  \
#  0                 0          0  ...             NaN
#  1                 0          4  ...             NaN
#  2                 0          0  ...             NaN
#  3                53        225  ...             NaN
#  4                 0          3  ...             NaN
#  ...             ...        ...  ...             ...
#  34302             0          0  ...             NaN
#  34303             1          0  ...             NaN
#  34304             0          0  ...             NaN
#  34305             0          1  ...             NaN
#  34306             2          4  ...             NaN
#
#                                               quotedTweet inReplyToTweetId  \
#  0                                                   None     1.562552e+18
#  1      {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
#  2      {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
#  3                                                   None     1.561961e+18
#  4                                                   None              NaN
#  ...                                                  ...              ...
#  34302                                               None              NaN
#  34303                                               None              NaN
#  34304                                               None              NaN
#  34305  {'_type': 'snscrape.modules.twitter.Tweet', 'u...              NaN
#  34306                                               None              NaN
#
#                                             inReplyToUser  \
#  0      {'_type': 'snscrape.modules.twitter.User', 'us...
#  1                                                   None
#  2                                                   None
#  3      {'_type': 'snscrape.modules.twitter.User', 'us...
#  4                                                   None
#  ...                                                  ...
#  34302                                               None
#  34303                                               None
#  34304                                               None
#  34305                                               None
#  34306                                               None
#
#                                            mentionedUsers coordinates place  \
#  0                                                   None        None  None
#  1                                                   None        None  None
#  2                                                   None        None  None
#  3      [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  4      [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  ...                                                  ...         ...   ...
#  34302                                               None        None  None
#  34303                                               None        None  None
#  34304  [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  34305  [{'_type': 'snscrape.modules.twitter.User', 'u...        None  None
#  34306                                               None        None  None
#
#                                                  hashtags  cashtags  \
#  0                                              [LaGarde]      None
#  1      [Merkel, Macron, Draghi, Lagarde, Ampel, Green...      None
#  2                                              [lagarde]      None
#  3              [Macron, UrsulaVonDerLeyen, Lagarde, BCE]      None
#  4      [running, hyeres, toulon, var, paca, southoffr...      None
#  ...                                                  ...       ...
#  34302                             [EZB, Lagarde, Draghi]      None
#  34303  [ECB, Draghi, Lagarde, Frankrijk, pensioenen, ...      None
#  34304                               [hipotecas, Lagarde]      None
#  34305  [Powell, fed, macro, fonds, ecb, draghi, Lagar...      None
#  34306  [PlenPE, Strasbourg, vonderLeyen, UNClimateSum...      None
#
#                                                      card
#  0                                                   None
#  1                                                   None
#  2                                                   None
#  3                                                   None
#  4                                                   None
#  ...                                                  ...
#  34302  {'_type': 'snscrape.modules.twitter.SummaryCar...
#  34303  {'_type': 'snscrape.modules.twitter.SummaryCar...
#  34304                                               None
#  34305                                               None
#  34306                                               None
#
#  [34307 rows x 28 columns]]

# %%
# %%script false --no-raise-error
#     #alternative approach to load the json files, slower and larger memory footprint, so avoid running it
# %%time
# import pandas as pd
# list_input_df = list(map(lambda path: pd.read_json("data/json_files/"+path, lines=True), list_paths))
# list_input_df

# %%
tweets_df = pd.concat(list_input_df)
tweets_df[["id", "date", "rawContent"]]
# Out:
#                         id                      date  \
# 0      1562541528740151296 2022-08-24 20:45:05+00:00
# 1      1562521759454138368 2022-08-24 19:26:32+00:00
# 2      1562515396330422275 2022-08-24 19:01:15+00:00
# 3      1562510373445545985 2022-08-24 18:41:17+00:00
# 4      1562499651952996352 2022-08-24 17:58:41+00:00
# ...                    ...                       ...
# 34302  1173870255543902214 2019-09-17 08:04:13+00:00
# 34303  1173862961817014273 2019-09-17 07:35:14+00:00
# 34304  1173861717358665728 2019-09-17 07:30:17+00:00
# 34305  1173861522092765184 2019-09-17 07:29:30+00:00
# 34306  1173858586470080512 2019-09-17 07:17:50+00:00
#
#                                               rawContent
# 0      Economic Calendar for Tomorrow:\n\n🇩🇪1) German...
# 1      #EURUSD at 0.99 for the first time since 2003....
# 2      The European Central Bank (ECB) is planning to...
# 3      In the digital economy, cash is no longer a us...
# 4      Reading: What the U.S. Federal Reserve must do...
# ...                                                  ...
# 34302  Pulver endgültig verschossen, #EZB-Rat tief ge...
# 34303  #ECB, i.c. #Draghi, bedrijft politiek; dat wor...
# 34304  ¿Cómo serán las #hipotecas con #Lagarde al fre...
# 34305  Ma chronique hebdo taux @allnews_ch #Powell #f...
# 34306  Rencontre avec la presse européenne en #PlenPE...
#
# [2671777 rows x 3 columns]

# %% [markdown]
# We are not using tweets about the USD because it is possible that the demand of US dollars increases (e.g., due to fears of recession and the corresponding search for safe heavens as it still has this reputation), but at the same time people can be unsatified with the way that the FED deals with inflation. In that scenario, the sentiment around USD in twitter would be negative in general, but it its demand can still increases.

# %%
#process json file
    #https://www.kaggle.com/code/prathamsharma123/clean-raw-json-tweets-data/notebook
print(tweets_df.shape)
    #as many rows as tweets
    #as many columns as features in each tweet
# Out:
# (2671777, 28)

# %%
#see features
print(tweets_df.columns)
# Out:
# Index(['_type', 'url', 'date', 'rawContent', 'renderedContent', 'id', 'user',
#        'replyCount', 'retweetCount', 'likeCount', 'quoteCount',
#        'conversationId', 'lang', 'source', 'sourceUrl', 'sourceLabel', 'links',
#        'media', 'retweetedTweet', 'quotedTweet', 'inReplyToTweetId',
#        'inReplyToUser', 'mentionedUsers', 'coordinates', 'place', 'hashtags',
#        'cashtags', 'card'],
#       dtype='object')

# %%
#get all columns for the first tweet
print(tweets_df.iloc[0, :])
# Out:
# _type                                  snscrape.modules.twitter.Tweet
# url                 https://twitter.com/harisonhbn9718/status/1562...
# date                                        2022-08-24 20:45:05+00:00
# rawContent          Economic Calendar for Tomorrow:\n\n🇩🇪1) German...
# renderedContent     Economic Calendar for Tomorrow:\n\n🇩🇪1) German...
# id                                                1562541528740151296
# user                {'_type': 'snscrape.modules.twitter.User', 'us...
# replyCount                                                          0
# retweetCount                                                        0
# likeCount                                                           0
# quoteCount                                                          0
# conversationId                                    1562541528740151296
# lang                                                               en
# source              <a href="https://mobile.twitter.com" rel="nofo...
# sourceUrl                                  https://mobile.twitter.com
# sourceLabel                                           Twitter Web App
# links                                                            None
# media                                                            None
# retweetedTweet                                                    NaN
# quotedTweet                                                      None
# inReplyToTweetId                                                  NaN
# inReplyToUser                                                    None
# mentionedUsers                                                   None
# coordinates                                                      None
# place                                                            None
# hashtags                                                         None
# cashtags                                                         None
# card                                                             None
# Name: 0, dtype: object

# %%
#reset the indeces to avoid problems when indexing
tweets_df = tweets_df.reset_index(drop=True)
    #use drop drop parameter to avoid the old index being added as a column
tweets_df[["id", "date", "rawContent"]]
# Out:
#                           id                      date  \
# 0        1562541528740151296 2022-08-24 20:45:05+00:00
# 1        1562521759454138368 2022-08-24 19:26:32+00:00
# 2        1562515396330422275 2022-08-24 19:01:15+00:00
# 3        1562510373445545985 2022-08-24 18:41:17+00:00
# 4        1562499651952996352 2022-08-24 17:58:41+00:00
# ...                      ...                       ...
# 2671772  1173870255543902214 2019-09-17 08:04:13+00:00
# 2671773  1173862961817014273 2019-09-17 07:35:14+00:00
# 2671774  1173861717358665728 2019-09-17 07:30:17+00:00
# 2671775  1173861522092765184 2019-09-17 07:29:30+00:00
# 2671776  1173858586470080512 2019-09-17 07:17:50+00:00
#
#                                                 rawContent
# 0        Economic Calendar for Tomorrow:\n\n🇩🇪1) German...
# 1        #EURUSD at 0.99 for the first time since 2003....
# 2        The European Central Bank (ECB) is planning to...
# 3        In the digital economy, cash is no longer a us...
# 4        Reading: What the U.S. Federal Reserve must do...
# ...                                                    ...
# 2671772  Pulver endgültig verschossen, #EZB-Rat tief ge...
# 2671773  #ECB, i.c. #Draghi, bedrijft politiek; dat wor...
# 2671774  ¿Cómo serán las #hipotecas con #Lagarde al fre...
# 2671775  Ma chronique hebdo taux @allnews_ch #Powell #f...
# 2671776  Rencontre avec la presse européenne en #PlenPE...
#
# [2671777 rows x 3 columns]

# %%
#check we have the expected number of rows
tweets_df.shape[0] == sum([len(data_frame) for data_frame in list_input_df])
# Out:
# True

# %%
#release space
del(list_input_df)
import gc
gc.collect()
# Out:
# 0

# %%
#check for duplicated IDs
tweets_df["id"].duplicated().any()
# Out:
# True

# %%
#take a look to one of the duplicated IDs
example_duplicated_id = tweets_df[tweets_df["id"].duplicated()].iloc[2,:].loc["id"] #get the ID

#get the URL for all tweets having the example ID and check if there are identical URLs
tweets_df.loc[tweets_df["id"] == example_duplicated_id, "url"].duplicated().any()
    #tweets with the same ID have the same URL, so they are the same tweet
# Out:
# True

# %%
#remove tweets with a duplicated id
tweets_df = tweets_df.drop_duplicates(subset=['id'])
tweets_df.shape
# Out:
# (2531545, 28)

# %%
#check languages
import numpy as np
np.unique(tweets_df["lang"])
# Out:
# array(['ar', 'bg', 'bn', 'ca', 'ckb', 'cs', 'cy', 'da', 'de', 'el', 'en',
#        'es', 'et', 'eu', 'fa', 'fi', 'fr', 'gu', 'hi', 'ht', 'hu', 'hy',
#        'in', 'is', 'it', 'iw', 'ja', 'ka', 'kn', 'ko', 'lt', 'lv', 'ml',
#        'mr', 'my', 'ne', 'nl', 'no', 'or', 'pa', 'pl', 'ps', 'pt', 'qam',
#        'qht', 'qme', 'qst', 'ro', 'ru', 'sd', 'si', 'sl', 'sr', 'sv',
#        'ta', 'te', 'th', 'tl', 'tr', 'uk', 'und', 'ur', 'vi', 'zh', 'zxx'],
#       dtype=object)

# %%
#see tweets not in english
sum(tweets_df["lang"] != "en")
# Out:
# 392435

# %%
#select only tweets in english
tweets_df_en = tweets_df[tweets_df["lang"] == "en"]
tweets_df_en.shape
    #CHECK IF THE SENTIMENT MODEL USED CAN DEAL WITH OTHER LANGUAGES
# Out:
# (2139110, 28)

# %% [markdown]
# It seems that "rawContent" shows the raw tweet content, while "renderedContent" show the strings that would bet shown by the web app ([link](https://github.com/JustAnotherArchivist/snscrape/issues/479)).
#
# We are going to use the raw tweet because it seem it could have more information. They do not seem to be very different anyways:

# %%
tweets_df_en.loc[:, "rawContent"].iloc[0:10,]
# Out:
# 0    Economic Calendar for Tomorrow:\n\n🇩🇪1) German...
# 1    #EURUSD at 0.99 for the first time since 2003....
# 2    The European Central Bank (ECB) is planning to...
# 3    In the digital economy, cash is no longer a us...
# 4    Reading: What the U.S. Federal Reserve must do...
# 5    NEW - European Central Bank’s Rehn: The invest...
# 6    Crypto: European industry in danger! https://t...
# 7    If there is one thing households in this count...
# 8    @moonblocks_ @lucas_gool @FinanceChainge @Bloc...
# 9    The European Central Bank creates a unified re...
# Name: rawContent, dtype: object

# %%
tweets_df_en.loc[:, "renderedContent"].iloc[0:10,]
# Out:
# 0    Economic Calendar for Tomorrow:\n\n🇩🇪1) German...
# 1    #EURUSD at 0.99 for the first time since 2003....
# 2    The European Central Bank (ECB) is planning to...
# 3    In the digital economy, cash is no longer a us...
# 4    Reading: What the U.S. Federal Reserve must do...
# 5    NEW - European Central Bank’s Rehn: The invest...
# 6    Crypto: European industry in danger! geeky.new...
# 7    If there is one thing households in this count...
# 8    @moonblocks_ @lucas_gool @FinanceChainge @Bloc...
# 9    The European Central Bank creates a unified re...
# Name: renderedContent, dtype: object

# %% [markdown]
# ## Sentiment analysis of tweets

# %% [markdown]
# We will use VADER to perform the sentiment analysis. There are alternatives like TextBlob, but VADER meets well our requeriments
# - It is sensitive to both polarity (positive/negative) and intensity (strength) of emotion.
# - you get a positive, negative neutral scores and a compound score
# - labelled data not required because it is pre-trained ([link](https://towardsdatascience.com/sentimental-analysis-using-vader-a3415fef7664), [link](https://towardsdatascience.com/sentiment-analysis-of-tweets-167d040f0583))

# %%
#take example tweet
example_tweet = tweets_df_en.loc[1, "rawContent"]

# %%
#VADER can be used from vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

#open instance
analyzer = SentimentIntensityAnalyzer()

#example
print(analyzer.polarity_scores(example_tweet))
print(example_tweet)
# Out:
# {'neg': 0.252, 'neu': 0.71, 'pos': 0.038, 'compound': -0.8294}
# #EURUSD at 0.99 for the first time since 2003.
#  The war, the energy crisis, the drought, but also the delayed reaction of the European Central Bank to moderate inflation weakened the EU currency. https://t.co/qkNjD8u8ND

# %%
#or from nlTK
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

#instance
sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/dftortosa/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
#we get similar results
print(sid.polarity_scores(example_tweet))
print(analyzer.polarity_scores(example_tweet))
# Out:
# {'neg': 0.252, 'neu': 0.71, 'pos': 0.038, 'compound': -0.8294}
# {'neg': 0.252, 'neu': 0.71, 'pos': 0.038, 'compound': -0.8294}

# %% [markdown]
# Define function to clean the tweet text

# %%
import re
def clean_tweet(tweet):
    '''
    Utility function to clean tweet text by removing links, special characters
    using simple regex statements.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) |(\w+:\/\/\S+)", " ", tweet).split()).replace("#", "")

##CHECK REGULAR EXPRESSIONS
#https://www.sciencedirect.com/science/article/pii/S104244312030072X

# %%
print(example_tweet)
clean_tweet(example_tweet)
# Out:
# #EURUSD at 0.99 for the first time since 2003.
#  The war, the energy crisis, the drought, but also the delayed reaction of the European Central Bank to moderate inflation weakened the EU currency. https://t.co/qkNjD8u8ND
# 'EURUSD at 0.99 for the first time since 2003. The war the energy crisis the drought but also the delayed reaction of the European Central Bank to moderate inflation weakened the EU currency'

# %%
print(analyzer.polarity_scores(clean_tweet(example_tweet)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-306363fd5dbd> in <module>
# ----> 1 print(analyzer.polarity_scores(clean_tweet(example_tweet)))
#
# NameError: name 'analyzer' is not defined

# %% [markdown]
# We are going to use the compound sentiment. In this way, we consider both the negative and positive sentiment around the BCE and the economy of Europe.

# %%
#define function to be applied per row
def sentiment_per_row(raw_tweet):
        
    #clean
    tweet_cleaned = clean_tweet(raw_tweet)
        #import preprocessor as p; p.clean()
    
    #get the negative sentiment
    sentiment = analyzer.polarity_scores(tweet_cleaned)["compound"]

    #return
    return sentiment

# %%
import multiprocessing as mp

with mp.Pool(10) as pool:
    tweets_df_en["sentiment"] = pool.map(sentiment_per_row, tweets_df_en["rawContent"])
        #for each row in tweets_df_en["rawContent"], apply sentiment_per_row across 10 cores
        #https://stackoverflow.com/questions/45545110/make-pandas-dataframe-apply-use-all-cores
    pool.close()
    
#CHECK: https://stackoverflow.com/questions/20625582/how-to-deal-with-settingwithcopywarning-in-pandas
# Out:
# /home/dftortosa/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
#get the date and sentiment
sentiment_results_df = tweets_df_en[["date", "sentiment"]]
sentiment_results_df
# Out:
#                              date  sentiment
# 0       2022-08-24 20:45:05+00:00    -0.7351
# 1       2022-08-24 19:26:32+00:00    -0.8294
# 2       2022-08-24 19:01:15+00:00     0.4404
# 3       2022-08-24 18:41:17+00:00     0.4588
# 4       2022-08-24 17:58:41+00:00    -0.2732
# ...                           ...        ...
# 2671751 2019-09-17 09:51:04+00:00    -0.9360
# 2671752 2019-09-17 09:42:17+00:00    -0.2120
# 2671755 2019-09-17 09:29:04+00:00    -0.1036
# 2671756 2019-09-17 09:18:08+00:00    -0.0806
# 2671769 2019-09-17 08:39:29+00:00     0.0000
#
# [2139110 rows x 2 columns]

# %%
#leave only year, month and day
sentiment_results_df["date"] = pd.to_datetime(sentiment_results_df["date"].dt.strftime('%Y-%m-%d'))
    #https://stackoverflow.com/questions/38067704/how-to-change-the-datetime-format-in-pandas
    #https://stackoverflow.com/questions/20689288/converting-pandas-columns-to-datetime64-including-missing-values
sentiment_results_df

#CHECK WARNING
# Out:
# /home/dftortosa/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               date  sentiment
# 0       2022-08-24    -0.7351
# 1       2022-08-24    -0.8294
# 2       2022-08-24     0.4404
# 3       2022-08-24     0.4588
# 4       2022-08-24    -0.2732
# ...            ...        ...
# 2671751 2019-09-17    -0.9360
# 2671752 2019-09-17    -0.2120
# 2671755 2019-09-17    -0.1036
# 2671756 2019-09-17    -0.0806
# 2671769 2019-09-17     0.0000
#
# [2139110 rows x 2 columns]

# %%
#check we have rows ordered in chronologicla order
sentiment_results_df.equals(sentiment_results_df.sort_index())
# Out:
# True

# %% [markdown]
# Now let's calculate several metrics for the sentiment of each day and save them in list of data.frames. We can calculate the average, quartiles, std...

# %%
sentiment_results_df.groupby("date")["sentiment"].mean()
# Out:
# date
# 2007-01-11    0.458800
# 2007-01-15    0.510600
# 2007-02-08    0.458800
# 2007-03-07    0.458800
# 2007-03-08    0.458800
#                 ...
# 2022-08-20   -0.013050
# 2022-08-21    0.008140
# 2022-08-22    0.005362
# 2022-08-23   -0.020686
# 2022-08-24   -0.029310
# Name: sentiment, Length: 5312, dtype: float64

# %% [markdown]
# We can use lambda to define our own calculations like the interquartile range:

# %%
sentiment_results_df.groupby("date")["sentiment"].apply(lambda a: (np.percentile(a, 75) - np.percentile(a, 25)))
# Out:
# date
# 2007-01-11    0.000000
# 2007-01-15    0.000000
# 2007-02-08    0.000000
# 2007-03-07    0.000000
# 2007-03-08    0.000000
#                 ...
# 2022-08-20    0.823400
# 2022-08-21    0.889600
# 2022-08-22    0.782300
# 2022-08-23    0.932100
# 2022-08-24    0.748725
# Name: sentiment, Length: 5312, dtype: float64

# %%
#get the most frequent value
from statistics import mode
mode([1,2,3,1,1])
# Out:
# 1

# %%
#std gives NA for cases with n=1
print(pd.DataFrame([1,1]).std()) #std = 0
print(pd.DataFrame([1,2]).std()) #std = 0.7
print(pd.DataFrame([1]).std()) #std = NaN
# Out:
# 0    0.0
# dtype: float64
# 0    0.707107
# dtype: float64
# 0   NaN
# dtype: float64

# %% [markdown]
# This is solved using ddof=0. ddof is Delta Degrees of Freedom. The divisor used in calculations is N - ddof, where N represents the number of elements

# %%
print(pd.DataFrame([1,1]).std(ddof=0)) #std = 0
print(pd.DataFrame([1,2]).std(ddof=0)) #std = 0.7
print(pd.DataFrame([1]).std(ddof=0)) #std = NaN
# Out:
# 0    0.0
# dtype: float64
# 0    0.5
# dtype: float64
# 0    0.0
# dtype: float64

# %% [markdown]
# We get the same results with np.std and .std(ddof=0)

# %%
print(np.std([1,1])) #std = 0
print(np.std([1,2])) #std = 0.7
print(np.std([1])) #std = NaN
# Out:
# 0.0
# 0.5
# 0.0

# %% [markdown]
# We can calculate the range

# %%
sentiment_results_df.groupby("date")["sentiment"].apply(lambda x: np.max(x) - np.min(x))
# Out:
# date
# 2007-01-11    0.0000
# 2007-01-15    0.0000
# 2007-02-08    0.0000
# 2007-03-07    0.0000
# 2007-03-08    0.0000
#                ...
# 2022-08-20    1.9133
# 2022-08-21    1.9435
# 2022-08-22    1.9297
# 2022-08-23    1.9184
# 2022-08-24    1.8991
# Name: sentiment, Length: 5312, dtype: float64

# %% [markdown]
# variance

# %%
sentiment_results_df.groupby("date")["sentiment"].var()
# Out:
# date
# 2007-01-11         NaN
# 2007-01-15         NaN
# 2007-02-08    0.000000
# 2007-03-07         NaN
# 2007-03-08         NaN
#                 ...
# 2022-08-20    0.256484
# 2022-08-21    0.298934
# 2022-08-22    0.247622
# 2022-08-23    0.273337
# 2022-08-24    0.241610
# Name: sentiment, Length: 5312, dtype: float64

# %% [markdown]
# We are going to use evaluate inside the function in order to perform the different operations we need. For example:

# %%
operation="mean"
string_evaluate = 'sentiment_results_df.groupby("date")["sentiment"].' + operation + '().to_frame()'
string_evaluate
# Out:
# 'sentiment_results_df.groupby("date")["sentiment"].mean().to_frame()'

# %%
eval(string_evaluate)
# Out:
#             sentiment
# date
# 2007-01-11   0.458800
# 2007-01-15   0.510600
# 2007-02-08   0.458800
# 2007-03-07   0.458800
# 2007-03-08   0.458800
# ...               ...
# 2022-08-20  -0.013050
# 2022-08-21   0.008140
# 2022-08-22   0.005362
# 2022-08-23  -0.020686
# 2022-08-24  -0.029310
#
# [5312 rows x 1 columns]

# %% [markdown]
# We are interested in have a row per day, so we can exactly calculate the sentiment of 1, 10... days ago

# %%
#we can use min and max to select the earliest and latest dates
print(np.min(np.unique(sentiment_results_df["date"])))
print(np.max(np.unique(sentiment_results_df["date"])))
# Out:
# 2007-01-11T00:00:00.000000000
# 2022-08-24T00:00:00.000000000

# %%
#first calculate the time range from the earliest to latest date
idx = pd.date_range(np.min(np.unique(sentiment_results_df["date"])), 
                    np.max(np.unique(sentiment_results_df["date"])))
idx
# Out:
# DatetimeIndex(['2007-01-11', '2007-01-12', '2007-01-13', '2007-01-14',
#                '2007-01-15', '2007-01-16', '2007-01-17', '2007-01-18',
#                '2007-01-19', '2007-01-20',
#                ...
#                '2022-08-15', '2022-08-16', '2022-08-17', '2022-08-18',
#                '2022-08-19', '2022-08-20', '2022-08-21', '2022-08-22',
#                '2022-08-23', '2022-08-24'],
#               dtype='datetime64[ns]', length=5705, freq='D')

# %%
#calculate the mean sentiment in tweets per day and then re-index considering all days between the earliest and 
#latest date. Those dates without tweets will have NaN
sentiment_results_df.groupby("date")["sentiment"].mean().reindex(idx, fill_value=np.NaN)
# Out:
# 2007-01-11    0.458800
# 2007-01-12         NaN
# 2007-01-13         NaN
# 2007-01-14         NaN
# 2007-01-15    0.510600
#                 ...
# 2022-08-20   -0.013050
# 2022-08-21    0.008140
# 2022-08-22    0.005362
# 2022-08-23   -0.020686
# 2022-08-24   -0.029310
# Freq: D, Name: sentiment, Length: 5705, dtype: float64

# %% [markdown]
# You can see how there is a gap without tweets between 11 and 15 of January and, accordingly, the days between have NaN

# %%
np.unique(sentiment_results_df["date"])[0:2]
# Out:
# array(['2007-01-11T00:00:00.000000000', '2007-01-15T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %% [markdown]
# We can also shift the rows after making an operation per day, i.e., move the value of day 1 to day 2, value of day 2 to day 3, and so on...

# %%
#first calculate the average sentiment per day
sentiment_results_df.groupby("date")["sentiment"].mean().reindex(idx, fill_value=np.NaN)
# Out:
# 2007-01-11    0.458800
# 2007-01-12         NaN
# 2007-01-13         NaN
# 2007-01-14         NaN
# 2007-01-15    0.510600
#                 ...
# 2022-08-20   -0.013050
# 2022-08-21    0.008140
# 2022-08-22    0.005362
# 2022-08-23   -0.020686
# 2022-08-24   -0.029310
# Freq: D, Name: sentiment, Length: 5705, dtype: float64

# %%
#Now shift 2 days, so 2022-07-16 has now the average of the previous day (2022-07-15)
sentiment_results_df.groupby("date")["sentiment"].mean().reindex(idx, fill_value=np.NaN).shift(1)
# Out:
# 2007-01-11         NaN
# 2007-01-12    0.458800
# 2007-01-13         NaN
# 2007-01-14         NaN
# 2007-01-15         NaN
#                 ...
# 2022-08-20    0.043817
# 2022-08-21   -0.013050
# 2022-08-22    0.008140
# 2022-08-23    0.005362
# 2022-08-24   -0.020686
# Freq: D, Name: sentiment, Length: 5705, dtype: float64

# %% [markdown]
# Shift zero would be equal to the original variable, no change:

# %%
sentiment_results_df.groupby("date")["sentiment"].mean().reindex(idx, fill_value=np.NaN).shift(0).equals(sentiment_results_df.groupby("date")["sentiment"].mean().reindex(idx, fill_value=np.NaN))
# Out:
# True

# %%
sentiment_results_df["sentiment"].shift(0).equals(sentiment_results_df["sentiment"])
# Out:
# True

# %% [markdown]
# Now, we are going to calculate different summary statistics of the sentiment of the previous days (1, 5, 10, 60 days ago):

# %%
###CHECK THIS!!!

#define a function to do a given operation grouping by day but considering the a previous date
def groupby_calcs(operation, metric_name, args="", n_previous_days=2):
        
    #get the string with the operation name
    string_evaluate = 'sentiment_results_df.groupby("date")["sentiment"].' + operation + '(' + args + ').to_frame()'
        #do operations for the sentiment of each day and then convert to df

    #evaluate to get the DF with the calculations per day
    data_frame = eval(string_evaluate)
    
    #extract the range of days for which we have data
    time_range = pd.date_range(np.min(np.unique(sentiment_results_df["date"])), 
                        np.max(np.unique(sentiment_results_df["date"])))
    
    #fill with NaN those dates with data
    data_frame = data_frame.reindex(time_range, fill_value=np.NaN)
        #https://stackoverflow.com/questions/15610805/accessing-row-from-previous-day-in-pandas-dataframe-with-apply
    
    #get sentiment of the previous days
    data_frame['sentiment'] = data_frame['sentiment'].shift(n_previous_days)
        #https://stackoverflow.com/questions/19324453/add-missing-dates-to-pandas-dataframe
        
    #reset the index
    data_frame = data_frame.reset_index(level=0)
        #set the index (date) as column 
  
    #change the column name for sentiment
    data_frame = data_frame.rename(columns={'index': 'date', 'sentiment': metric_name + '_sent_previous_' + str(n_previous_days) + '_days'})

    #append the df to the list
    return data_frame
    

def groupby_calcs_across_dates(previous_date):
    
    #define a list of operations to do
    metrics_sentiment = ["quantile_0.05",
                         "quantile_0.1",
                         "quantile_0.2",
                         "quantile_0.3",
                         "quantile_0.4",
                         "quantile_0.5",
                         "quantile_0.6",
                         "quantile_0.7",
                         "quantile_0.8",
                         "quantile_0.9",
                         "quantile_0.95",
                         "mean",
                         "min",
                         "max",
                         "sum",
                         "count", 
                             #this can be useful to control for averages with low number of tweets
                             #but also to consider how much people is talking about europes economy 
                         "range", 
                         "var", 
                         "std", 
                         "iqr"]
    
    #open list to save each calculation
    list_data_frames = []
    
    #apply each operation
    for metric in metrics_sentiment:
        
        #for std
        if metric == "std":
            #use ddof=0 to get zero for cases with 1 tweet per day (see above)
            result_calc = groupby_calcs(operation=metric, 
                          metric_name=metric, 
                          args='ddof=0', 
                          n_previous_days=previous_date)
        elif "quantile" in metric: #if quantile
            #get the operation name and the quantile number
            operation_name = metric.split("_")[0]
            quantile_number = metric.split("_")[1]
            result_calc = groupby_calcs(operation=operation_name, 
                          metric_name=metric, 
                          args=quantile_number, 
                          n_previous_days=previous_date) 
        elif "range" in metric:
            result_calc = groupby_calcs(operation="apply", 
                          metric_name=metric, 
                          args="lambda x: np.max(x) - np.min(x)",
                          n_previous_days=previous_date)
        elif "iqr" in metric:
            result_calc = groupby_calcs(operation="apply", 
                          metric_name=metric, 
                          args="lambda x: (np.percentile(x, 75) - np.percentile(x, 25))",
                          n_previous_days=previous_date)   
        else: 
            result_calc = groupby_calcs(operation=metric, 
                          metric_name=metric, 
                          n_previous_days=previous_date)
           
        list_data_frames.append(result_calc)
        
    return list_data_frames

# %%
groupby_calcs_across_dates(2)
# Out:
# [           date  quantile_0.05_sent_previous_2_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                            0.458800
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                           -0.743000
#  5701 2022-08-21                           -0.813775
#  5702 2022-08-22                           -0.848260
#  5703 2022-08-23                           -0.848950
#  5704 2022-08-24                           -0.825080
#
#  [5705 rows x 2 columns],
#             date  quantile_0.1_sent_previous_2_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                            0.45880
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5700 2022-08-20                           -0.47670
#  5701 2022-08-21                           -0.69080
#  5702 2022-08-22                           -0.74984
#  5703 2022-08-23                           -0.78450
#  5704 2022-08-24                           -0.70030
#
#  [5705 rows x 2 columns],
#             date  quantile_0.2_sent_previous_2_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                            0.45880
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5700 2022-08-20                           -0.20230
#  5701 2022-08-21                           -0.45880
#  5702 2022-08-22                           -0.48142
#  5703 2022-08-23                           -0.54230
#  5704 2022-08-24                           -0.49178
#
#  [5705 rows x 2 columns],
#             date  quantile_0.3_sent_previous_2_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                            0.45880
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5700 2022-08-20                            0.00000
#  5701 2022-08-21                           -0.22025
#  5702 2022-08-22                           -0.30006
#  5703 2022-08-23                           -0.33540
#  5704 2022-08-24                           -0.28928
#
#  [5705 rows x 2 columns],
#             date  quantile_0.4_sent_previous_2_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                             0.4588
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5700 2022-08-20                             0.0000
#  5701 2022-08-21                             0.0000
#  5702 2022-08-22                            -0.1280
#  5703 2022-08-23                            -0.1007
#  5704 2022-08-24                             0.0000
#
#  [5705 rows x 2 columns],
#             date  quantile_0.5_sent_previous_2_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                             0.4588
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5700 2022-08-20                             0.1779
#  5701 2022-08-21                             0.0000
#  5702 2022-08-22                             0.0000
#  5703 2022-08-23                             0.0000
#  5704 2022-08-24                             0.0000
#
#  [5705 rows x 2 columns],
#             date  quantile_0.6_sent_previous_2_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                            0.45880
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5700 2022-08-20                            0.17790
#  5701 2022-08-21                            0.22630
#  5702 2022-08-22                            0.04936
#  5703 2022-08-23                            0.13840
#  5704 2022-08-24                            0.10270
#
#  [5705 rows x 2 columns],
#             date  quantile_0.7_sent_previous_2_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                            0.45880
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5700 2022-08-20                            0.31820
#  5701 2022-08-21                            0.39570
#  5702 2022-08-22                            0.32351
#  5703 2022-08-23                            0.37150
#  5704 2022-08-24                            0.32680
#
#  [5705 rows x 2 columns],
#             date  quantile_0.8_sent_previous_2_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                             0.4588
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5700 2022-08-20                             0.4767
#  5701 2022-08-21                             0.4404
#  5702 2022-08-22                             0.4939
#  5703 2022-08-23                             0.5719
#  5704 2022-08-24                             0.4404
#
#  [5705 rows x 2 columns],
#             date  quantile_0.9_sent_previous_2_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                            0.45880
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5700 2022-08-20                            0.64860
#  5701 2022-08-21                            0.66785
#  5702 2022-08-22                            0.67995
#  5703 2022-08-23                            0.77170
#  5704 2022-08-24                            0.67258
#
#  [5705 rows x 2 columns],
#             date  quantile_0.95_sent_previous_2_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                            0.458800
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                            0.737800
#  5701 2022-08-21                            0.757900
#  5702 2022-08-22                            0.768230
#  5703 2022-08-23                            0.854825
#  5704 2022-08-24                            0.771600
#
#  [5705 rows x 2 columns],
#             date  mean_sent_previous_2_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                   0.458800
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                   0.105090
#  5701 2022-08-21                   0.043817
#  5702 2022-08-22                  -0.013050
#  5703 2022-08-23                   0.008140
#  5704 2022-08-24                   0.005362
#
#  [5705 rows x 2 columns],
#             date  min_sent_previous_2_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                    0.4588
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5700 2022-08-20                   -0.9613
#  5701 2022-08-21                   -0.9612
#  5702 2022-08-22                   -0.9752
#  5703 2022-08-23                   -0.9834
#  5704 2022-08-24                   -0.9623
#
#  [5705 rows x 2 columns],
#             date  max_sent_previous_2_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                    0.4588
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5700 2022-08-20                    0.9403
#  5701 2022-08-21                    0.9485
#  5702 2022-08-22                    0.9381
#  5703 2022-08-23                    0.9601
#  5704 2022-08-24                    0.9674
#
#  [5705 rows x 2 columns],
#             date  sum_sent_previous_2_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                    0.4588
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5700 2022-08-20                   37.9374
#  5701 2022-08-21                   10.3408
#  5702 2022-08-22                   -2.8971
#  5703 2022-08-23                    1.4326
#  5704 2022-08-24                    1.5924
#
#  [5705 rows x 2 columns],
#             date  count_sent_previous_2_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         1.0
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5700 2022-08-20                       361.0
#  5701 2022-08-21                       236.0
#  5702 2022-08-22                       222.0
#  5703 2022-08-23                       176.0
#  5704 2022-08-24                       297.0
#
#  [5705 rows x 2 columns],
#             date  range_sent_previous_2_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                      0.0000
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5700 2022-08-20                      1.9016
#  5701 2022-08-21                      1.9097
#  5702 2022-08-22                      1.9133
#  5703 2022-08-23                      1.9435
#  5704 2022-08-24                      1.9297
#
#  [5705 rows x 2 columns],
#             date  var_sent_previous_2_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                       NaN
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5700 2022-08-20                  0.175056
#  5701 2022-08-21                  0.235059
#  5702 2022-08-22                  0.256484
#  5703 2022-08-23                  0.298934
#  5704 2022-08-24                  0.247622
#
#  [5705 rows x 2 columns],
#             date  std_sent_previous_2_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                  0.000000
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5700 2022-08-20                  0.417817
#  5701 2022-08-21                  0.483800
#  5702 2022-08-22                  0.505301
#  5703 2022-08-23                  0.545193
#  5704 2022-08-24                  0.496778
#
#  [5705 rows x 2 columns],
#             date  iqr_sent_previous_2_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                  0.000000
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5700 2022-08-20                  0.394700
#  5701 2022-08-21                  0.711775
#  5702 2022-08-22                  0.823400
#  5703 2022-08-23                  0.889600
#  5704 2022-08-24                  0.782300
#
#  [5705 rows x 2 columns]]

# %% [markdown]
# We are going to calculate the summary statistics for the sentiment several days before the current day

# %%
#get sentiment 1 and 2 weeks ago, along with 1, 2, 3, 4 and 5 months ago
list_dates = [7, 14, 30, 60, 90, 120]

#open a pool with 10 processes
pool_dates = mp.Pool(processes=10)

#apply the function for each previous day in parallel across 10 cores
list_data_frames = [pool_dates.apply_async(groupby_calcs_across_dates, args=(previous_date,)).get() for previous_date in list_dates]
    #https://stackoverflow.com/questions/42843203/how-to-get-the-result-of-multiprocessing-pool-apply-async

#close the pool
pool_dates.close()

# %%
#check we have the correct number of dfs in the list
#len(list_data_frames) == len(metrics_sentiment)*len(list_dates)

# %%
type(list_data_frames)
# Out:
# list

# %%
list_data_frames[0][0]
# Out:
#            date  quantile_0.05_sent_previous_7_days
# 0    2007-01-11                                 NaN
# 1    2007-01-12                                 NaN
# 2    2007-01-13                                 NaN
# 3    2007-01-14                                 NaN
# 4    2007-01-15                                 NaN
# ...         ...                                 ...
# 5700 2022-08-20                           -0.831400
# 5701 2022-08-21                           -0.853130
# 5702 2022-08-22                           -0.789630
# 5703 2022-08-23                           -0.858075
# 5704 2022-08-24                           -0.831710
#
# [5705 rows x 2 columns]

# %%
list_data_frames[1][1]
# Out:
#            date  quantile_0.1_sent_previous_14_days
# 0    2007-01-11                                 NaN
# 1    2007-01-12                                 NaN
# 2    2007-01-13                                 NaN
# 3    2007-01-14                                 NaN
# 4    2007-01-15                                 NaN
# ...         ...                                 ...
# 5700 2022-08-20                            -0.75790
# 5701 2022-08-21                            -0.73990
# 5702 2022-08-22                            -0.71136
# 5703 2022-08-23                            -0.72690
# 5704 2022-08-24                            -0.76500
#
# [5705 rows x 2 columns]

# %%
flat_list = [item for sublist in list_data_frames for item in sublist]
flat_list
# Out:
# [           date  quantile_0.05_sent_previous_7_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                           -0.831400
#  5701 2022-08-21                           -0.853130
#  5702 2022-08-22                           -0.789630
#  5703 2022-08-23                           -0.858075
#  5704 2022-08-24                           -0.831710
#
#  [5705 rows x 2 columns],
#             date  quantile_0.1_sent_previous_7_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                                NaN
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5700 2022-08-20                           -0.77165
#  5701 2022-08-21                           -0.75498
#  5702 2022-08-22                           -0.63250
#  5703 2022-08-23                           -0.76500
#  5704 2022-08-24                           -0.68832
#
#  [5705 rows x 2 columns],
#             date  quantile_0.2_sent_previous_7_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                                NaN
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5700 2022-08-20                           -0.51060
#  5701 2022-08-21                           -0.51694
#  5702 2022-08-22                           -0.37356
#  5703 2022-08-23                           -0.44710
#  5704 2022-08-24                           -0.26182
#
#  [5705 rows x 2 columns],
#             date  quantile_0.3_sent_previous_7_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                                NaN
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5700 2022-08-20                           -0.30850
#  5701 2022-08-21                           -0.33218
#  5702 2022-08-22                           -0.01806
#  5703 2022-08-23                           -0.15310
#  5704 2022-08-24                            0.00000
#
#  [5705 rows x 2 columns],
#             date  quantile_0.4_sent_previous_7_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                                NaN
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5700 2022-08-20                            0.00000
#  5701 2022-08-21                           -0.13176
#  5702 2022-08-22                            0.00000
#  5703 2022-08-23                            0.00000
#  5704 2022-08-24                            0.00000
#
#  [5705 rows x 2 columns],
#             date  quantile_0.5_sent_previous_7_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                                NaN
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5700 2022-08-20                             0.0000
#  5701 2022-08-21                             0.0000
#  5702 2022-08-22                             0.0000
#  5703 2022-08-23                             0.0000
#  5704 2022-08-24                             0.1779
#
#  [5705 rows x 2 columns],
#             date  quantile_0.6_sent_previous_7_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                                NaN
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5700 2022-08-20                            0.17790
#  5701 2022-08-21                            0.14690
#  5702 2022-08-22                            0.24856
#  5703 2022-08-23                            0.12800
#  5704 2022-08-24                            0.17790
#
#  [5705 rows x 2 columns],
#             date  quantile_0.7_sent_previous_7_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                                NaN
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5700 2022-08-20                            0.39760
#  5701 2022-08-21                            0.40190
#  5702 2022-08-22                            0.44040
#  5703 2022-08-23                            0.37445
#  5704 2022-08-24                            0.17790
#
#  [5705 rows x 2 columns],
#             date  quantile_0.8_sent_previous_7_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                                NaN
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5700 2022-08-20                            0.47670
#  5701 2022-08-21                            0.45880
#  5702 2022-08-22                            0.58310
#  5703 2022-08-23                            0.47670
#  5704 2022-08-24                            0.37568
#
#  [5705 rows x 2 columns],
#             date  quantile_0.9_sent_previous_7_days
#  0    2007-01-11                                NaN
#  1    2007-01-12                                NaN
#  2    2007-01-13                                NaN
#  3    2007-01-14                                NaN
#  4    2007-01-15                                NaN
#  ...         ...                                ...
#  5700 2022-08-20                            0.74300
#  5701 2022-08-21                            0.68268
#  5702 2022-08-22                            0.74142
#  5703 2022-08-23                            0.73510
#  5704 2022-08-24                            0.59764
#
#  [5705 rows x 2 columns],
#             date  quantile_0.95_sent_previous_7_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                            0.847125
#  5701 2022-08-21                            0.815570
#  5702 2022-08-22                            0.822130
#  5703 2022-08-23                            0.813600
#  5704 2022-08-24                            0.723660
#
#  [5705 rows x 2 columns],
#             date  mean_sent_previous_7_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                   0.018669
#  5701 2022-08-21                   0.001543
#  5702 2022-08-22                   0.094626
#  5703 2022-08-23                   0.027982
#  5704 2022-08-24                   0.051237
#
#  [5705 rows x 2 columns],
#             date  min_sent_previous_7_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                       NaN
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5700 2022-08-20                   -0.9571
#  5701 2022-08-21                   -0.9564
#  5702 2022-08-22                   -0.9600
#  5703 2022-08-23                   -0.9520
#  5704 2022-08-24                   -0.9613
#
#  [5705 rows x 2 columns],
#             date  max_sent_previous_7_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                       NaN
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5700 2022-08-20                    0.9638
#  5701 2022-08-21                    0.9217
#  5702 2022-08-22                    0.9978
#  5703 2022-08-23                    0.9612
#  5704 2022-08-24                    0.9118
#
#  [5705 rows x 2 columns],
#             date  sum_sent_previous_7_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                       NaN
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5700 2022-08-20                    2.7257
#  5701 2022-08-21                    0.2392
#  5702 2022-08-22                   17.3165
#  5703 2022-08-23                    5.4845
#  5704 2022-08-24                   15.3200
#
#  [5705 rows x 2 columns],
#             date  count_sent_previous_7_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5700 2022-08-20                       146.0
#  5701 2022-08-21                       155.0
#  5702 2022-08-22                       183.0
#  5703 2022-08-23                       196.0
#  5704 2022-08-24                       299.0
#
#  [5705 rows x 2 columns],
#             date  range_sent_previous_7_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5700 2022-08-20                      1.9209
#  5701 2022-08-21                      1.8781
#  5702 2022-08-22                      1.9578
#  5703 2022-08-23                      1.9132
#  5704 2022-08-24                      1.8731
#
#  [5705 rows x 2 columns],
#             date  var_sent_previous_7_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                       NaN
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5700 2022-08-20                  0.281126
#  5701 2022-08-21                  0.276042
#  5702 2022-08-22                  0.254028
#  5703 2022-08-23                  0.255476
#  5704 2022-08-24                  0.183833
#
#  [5705 rows x 2 columns],
#             date  std_sent_previous_7_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                       NaN
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5700 2022-08-20                  0.528394
#  5701 2022-08-21                  0.523700
#  5702 2022-08-22                  0.502633
#  5703 2022-08-23                  0.504155
#  5704 2022-08-24                  0.428040
#
#  [5705 rows x 2 columns],
#             date  iqr_sent_previous_7_days
#  0    2007-01-11                       NaN
#  1    2007-01-12                       NaN
#  2    2007-01-13                       NaN
#  3    2007-01-14                       NaN
#  4    2007-01-15                       NaN
#  ...         ...                       ...
#  5700 2022-08-20                  0.837275
#  5701 2022-08-21                  0.822200
#  5702 2022-08-22                  0.759050
#  5703 2022-08-23                  0.753475
#  5704 2022-08-24                  0.262600
#
#  [5705 rows x 2 columns],
#             date  quantile_0.05_sent_previous_14_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5700 2022-08-20                            -0.787310
#  5701 2022-08-21                            -0.817550
#  5702 2022-08-22                            -0.792280
#  5703 2022-08-23                            -0.830570
#  5704 2022-08-24                            -0.849415
#
#  [5705 rows x 2 columns],
#             date  quantile_0.1_sent_previous_14_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                            -0.75790
#  5701 2022-08-21                            -0.73990
#  5702 2022-08-22                            -0.71136
#  5703 2022-08-23                            -0.72690
#  5704 2022-08-24                            -0.76500
#
#  [5705 rows x 2 columns],
#             date  quantile_0.2_sent_previous_14_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                            -0.60492
#  5701 2022-08-21                            -0.49390
#  5702 2022-08-22                            -0.48358
#  5703 2022-08-23                            -0.52670
#  5704 2022-08-24                            -0.59880
#
#  [5705 rows x 2 columns],
#             date  quantile_0.3_sent_previous_14_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                            -0.42150
#  5701 2022-08-21                            -0.30710
#  5702 2022-08-22                            -0.31688
#  5703 2022-08-23                            -0.25483
#  5704 2022-08-24                            -0.36120
#
#  [5705 rows x 2 columns],
#             date  quantile_0.4_sent_previous_14_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                            -0.19742
#  5701 2022-08-21                             0.00000
#  5702 2022-08-22                             0.00000
#  5703 2022-08-23                             0.00000
#  5704 2022-08-24                             0.00000
#
#  [5705 rows x 2 columns],
#             date  quantile_0.5_sent_previous_14_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                                 0.0
#  5701 2022-08-21                                 0.0
#  5702 2022-08-22                                 0.0
#  5703 2022-08-23                                 0.0
#  5704 2022-08-24                                 0.0
#
#  [5705 rows x 2 columns],
#             date  quantile_0.6_sent_previous_14_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                             0.00000
#  5701 2022-08-21                             0.27320
#  5702 2022-08-22                             0.15270
#  5703 2022-08-23                             0.07720
#  5704 2022-08-24                             0.04644
#
#  [5705 rows x 2 columns],
#             date  quantile_0.7_sent_previous_14_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                             0.15310
#  5701 2022-08-21                             0.44040
#  5702 2022-08-22                             0.36120
#  5703 2022-08-23                             0.30470
#  5704 2022-08-24                             0.22867
#
#  [5705 rows x 2 columns],
#             date  quantile_0.8_sent_previous_14_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                             0.36552
#  5701 2022-08-21                             0.58590
#  5702 2022-08-22                             0.50982
#  5703 2022-08-23                             0.52510
#  5704 2022-08-24                             0.42906
#
#  [5705 rows x 2 columns],
#             date  quantile_0.9_sent_previous_14_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                             0.73450
#  5701 2022-08-21                             0.69080
#  5702 2022-08-22                             0.69080
#  5703 2022-08-23                             0.74999
#  5704 2022-08-24                             0.64509
#
#  [5705 rows x 2 columns],
#             date  quantile_0.95_sent_previous_14_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5700 2022-08-20                             0.810810
#  5701 2022-08-21                             0.777800
#  5702 2022-08-22                             0.793450
#  5703 2022-08-23                             0.826605
#  5704 2022-08-24                             0.799655
#
#  [5705 rows x 2 columns],
#             date  mean_sent_previous_14_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5700 2022-08-20                   -0.073022
#  5701 2022-08-21                    0.034734
#  5702 2022-08-22                    0.019362
#  5703 2022-08-23                    0.017201
#  5704 2022-08-24                   -0.041471
#
#  [5705 rows x 2 columns],
#             date  min_sent_previous_14_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                    -0.9716
#  5701 2022-08-21                    -0.9651
#  5702 2022-08-22                    -0.9625
#  5703 2022-08-23                    -0.9545
#  5704 2022-08-24                    -0.9670
#
#  [5705 rows x 2 columns],
#             date  max_sent_previous_14_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                     0.9349
#  5701 2022-08-21                     0.9626
#  5702 2022-08-22                     0.9371
#  5703 2022-08-23                     0.9576
#  5704 2022-08-24                     0.9513
#
#  [5705 rows x 2 columns],
#             date  sum_sent_previous_14_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                   -11.6105
#  5701 2022-08-21                     6.6342
#  5702 2022-08-22                     4.6275
#  5703 2022-08-23                     3.4746
#  5704 2022-08-24                    -8.0454
#
#  [5705 rows x 2 columns],
#             date  count_sent_previous_14_days
#  0    2007-01-11                          NaN
#  1    2007-01-12                          NaN
#  2    2007-01-13                          NaN
#  3    2007-01-14                          NaN
#  4    2007-01-15                          NaN
#  ...         ...                          ...
#  5700 2022-08-20                        159.0
#  5701 2022-08-21                        191.0
#  5702 2022-08-22                        239.0
#  5703 2022-08-23                        202.0
#  5704 2022-08-24                        194.0
#
#  [5705 rows x 2 columns],
#             date  range_sent_previous_14_days
#  0    2007-01-11                          NaN
#  1    2007-01-12                          NaN
#  2    2007-01-13                          NaN
#  3    2007-01-14                          NaN
#  4    2007-01-15                          NaN
#  ...         ...                          ...
#  5700 2022-08-20                       1.9065
#  5701 2022-08-21                       1.9277
#  5702 2022-08-22                       1.8996
#  5703 2022-08-23                       1.9121
#  5704 2022-08-24                       1.9183
#
#  [5705 rows x 2 columns],
#             date  var_sent_previous_14_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                   0.257640
#  5701 2022-08-21                   0.272986
#  5702 2022-08-22                   0.257050
#  5703 2022-08-23                   0.267385
#  5704 2022-08-24                   0.263063
#
#  [5705 rows x 2 columns],
#             date  std_sent_previous_14_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                   0.505984
#  5701 2022-08-21                   0.521111
#  5702 2022-08-22                   0.505939
#  5703 2022-08-23                   0.515811
#  5704 2022-08-24                   0.511573
#
#  [5705 rows x 2 columns],
#             date  iqr_sent_previous_14_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                   0.775850
#  5701 2022-08-21                   0.846050
#  5702 2022-08-22                   0.823400
#  5703 2022-08-23                   0.817050
#  5704 2022-08-24                   0.844675
#
#  [5705 rows x 2 columns],
#             date  quantile_0.05_sent_previous_30_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5700 2022-08-20                             -0.70030
#  5701 2022-08-21                             -0.79030
#  5702 2022-08-22                             -0.84689
#  5703 2022-08-23                             -0.85780
#  5704 2022-08-24                             -0.82286
#
#  [5705 rows x 2 columns],
#             date  quantile_0.1_sent_previous_30_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                            -0.52670
#  5701 2022-08-21                            -0.62490
#  5702 2022-08-22                            -0.76310
#  5703 2022-08-23                            -0.77170
#  5704 2022-08-24                            -0.67462
#
#  [5705 rows x 2 columns],
#             date  quantile_0.2_sent_previous_30_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                            -0.22630
#  5701 2022-08-21                            -0.42150
#  5702 2022-08-22                            -0.52622
#  5703 2022-08-23                            -0.54230
#  5704 2022-08-24                            -0.47136
#
#  [5705 rows x 2 columns],
#             date  quantile_0.3_sent_previous_30_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                             0.00000
#  5701 2022-08-21                            -0.05744
#  5702 2022-08-22                            -0.34684
#  5703 2022-08-23                            -0.40190
#  5704 2022-08-24                            -0.25000
#
#  [5705 rows x 2 columns],
#             date  quantile_0.4_sent_previous_30_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                              0.0000
#  5701 2022-08-21                              0.0000
#  5702 2022-08-22                             -0.0258
#  5703 2022-08-23                             -0.0790
#  5704 2022-08-24                              0.0000
#
#  [5705 rows x 2 columns],
#             date  quantile_0.5_sent_previous_30_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                              0.1779
#  5701 2022-08-21                              0.0387
#  5702 2022-08-22                              0.0000
#  5703 2022-08-23                              0.0000
#  5704 2022-08-24                              0.0000
#
#  [5705 rows x 2 columns],
#             date  quantile_0.6_sent_previous_30_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                             0.40190
#  5701 2022-08-21                             0.27320
#  5702 2022-08-22                             0.17750
#  5703 2022-08-23                             0.02580
#  5704 2022-08-24                             0.23224
#
#  [5705 rows x 2 columns],
#             date  quantile_0.7_sent_previous_30_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                             0.45880
#  5701 2022-08-21                             0.45880
#  5702 2022-08-22                             0.42906
#  5703 2022-08-23                             0.27510
#  5704 2022-08-24                             0.40190
#
#  [5705 rows x 2 columns],
#             date  quantile_0.8_sent_previous_30_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                             0.47670
#  5701 2022-08-21                             0.49390
#  5702 2022-08-22                             0.49342
#  5703 2022-08-23                             0.45880
#  5704 2022-08-24                             0.52670
#
#  [5705 rows x 2 columns],
#             date  quantile_0.9_sent_previous_30_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                             0.64860
#  5701 2022-08-21                             0.64860
#  5702 2022-08-22                             0.69136
#  5703 2022-08-23                             0.69080
#  5704 2022-08-24                             0.71036
#
#  [5705 rows x 2 columns],
#             date  quantile_0.95_sent_previous_30_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5700 2022-08-20                              0.74300
#  5701 2022-08-21                              0.76497
#  5702 2022-08-22                              0.78550
#  5703 2022-08-23                              0.80740
#  5704 2022-08-24                              0.80708
#
#  [5705 rows x 2 columns],
#             date  mean_sent_previous_30_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5700 2022-08-20                    0.146675
#  5701 2022-08-21                    0.084947
#  5702 2022-08-22                    0.011866
#  5703 2022-08-23                   -0.022601
#  5704 2022-08-24                    0.048231
#
#  [5705 rows x 2 columns],
#             date  min_sent_previous_30_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                    -0.9517
#  5701 2022-08-21                    -0.9708
#  5702 2022-08-22                    -0.9698
#  5703 2022-08-23                    -0.9574
#  5704 2022-08-24                    -0.9790
#
#  [5705 rows x 2 columns],
#             date  max_sent_previous_30_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                     0.9607
#  5701 2022-08-21                     0.9538
#  5702 2022-08-22                     0.9659
#  5703 2022-08-23                     0.9493
#  5704 2022-08-24                     0.9442
#
#  [5705 rows x 2 columns],
#             date  sum_sent_previous_30_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                   268.7085
#  5701 2022-08-21                    75.0084
#  5702 2022-08-22                     5.0194
#  5703 2022-08-23                    -7.7068
#  5704 2022-08-24                    17.2186
#
#  [5705 rows x 2 columns],
#             date  count_sent_previous_30_days
#  0    2007-01-11                          NaN
#  1    2007-01-12                          NaN
#  2    2007-01-13                          NaN
#  3    2007-01-14                          NaN
#  4    2007-01-15                          NaN
#  ...         ...                          ...
#  5700 2022-08-20                       1832.0
#  5701 2022-08-21                        883.0
#  5702 2022-08-22                        423.0
#  5703 2022-08-23                        341.0
#  5704 2022-08-24                        357.0
#
#  [5705 rows x 2 columns],
#             date  range_sent_previous_30_days
#  0    2007-01-11                          NaN
#  1    2007-01-12                          NaN
#  2    2007-01-13                          NaN
#  3    2007-01-14                          NaN
#  4    2007-01-15                          NaN
#  ...         ...                          ...
#  5700 2022-08-20                       1.9124
#  5701 2022-08-21                       1.9246
#  5702 2022-08-22                       1.9357
#  5703 2022-08-23                       1.9067
#  5704 2022-08-24                       1.9232
#
#  [5705 rows x 2 columns],
#             date  var_sent_previous_30_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                   0.188323
#  5701 2022-08-21                   0.224418
#  5702 2022-08-22                   0.273675
#  5703 2022-08-23                   0.266141
#  5704 2022-08-24                   0.254390
#
#  [5705 rows x 2 columns],
#             date  std_sent_previous_30_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                   0.433843
#  5701 2022-08-21                   0.473459
#  5702 2022-08-22                   0.522521
#  5703 2022-08-23                   0.515131
#  5704 2022-08-24                   0.503664
#
#  [5705 rows x 2 columns],
#             date  iqr_sent_previous_30_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                     0.4588
#  5701 2022-08-21                     0.7320
#  5702 2022-08-22                     0.8803
#  5703 2022-08-23                     0.8395
#  5704 2022-08-24                     0.8120
#
#  [5705 rows x 2 columns],
#             date  quantile_0.05_sent_previous_60_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5700 2022-08-20                            -0.812320
#  5701 2022-08-21                            -0.787995
#  5702 2022-08-22                            -0.790600
#  5703 2022-08-23                            -0.812600
#  5704 2022-08-24                            -0.834300
#
#  [5705 rows x 2 columns],
#             date  quantile_0.1_sent_previous_60_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                            -0.71410
#  5701 2022-08-21                            -0.60290
#  5702 2022-08-22                            -0.69232
#  5703 2022-08-23                            -0.70944
#  5704 2022-08-24                            -0.75740
#
#  [5705 rows x 2 columns],
#             date  quantile_0.2_sent_previous_60_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                            -0.48518
#  5701 2022-08-21                            -0.38180
#  5702 2022-08-22                            -0.51060
#  5703 2022-08-23                            -0.47558
#  5704 2022-08-24                            -0.55740
#
#  [5705 rows x 2 columns],
#             date  quantile_0.3_sent_previous_60_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                             -0.2732
#  5701 2022-08-21                             -0.2023
#  5702 2022-08-22                             -0.3367
#  5703 2022-08-23                             -0.2732
#  5704 2022-08-24                             -0.3612
#
#  [5705 rows x 2 columns],
#             date  quantile_0.4_sent_previous_60_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                             0.00000
#  5701 2022-08-21                             0.00000
#  5702 2022-08-22                            -0.05052
#  5703 2022-08-23                             0.00000
#  5704 2022-08-24                            -0.10270
#
#  [5705 rows x 2 columns],
#             date  quantile_0.5_sent_previous_60_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                                 0.0
#  5701 2022-08-21                                 0.0
#  5702 2022-08-22                                 0.0
#  5703 2022-08-23                                 0.0
#  5704 2022-08-24                                 0.0
#
#  [5705 rows x 2 columns],
#             date  quantile_0.6_sent_previous_60_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                             0.12800
#  5701 2022-08-21                             0.14808
#  5702 2022-08-22                             0.00000
#  5703 2022-08-23                             0.00000
#  5704 2022-08-24                             0.11540
#
#  [5705 rows x 2 columns],
#             date  quantile_0.7_sent_previous_60_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                             0.34000
#  5701 2022-08-21                             0.36120
#  5702 2022-08-22                             0.30324
#  5703 2022-08-23                             0.25000
#  5704 2022-08-24                             0.34000
#
#  [5705 rows x 2 columns],
#             date  quantile_0.8_sent_previous_60_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                             0.48950
#  5701 2022-08-21                             0.52406
#  5702 2022-08-22                             0.44040
#  5703 2022-08-23                             0.44040
#  5704 2022-08-24                             0.45220
#
#  [5705 rows x 2 columns],
#             date  quantile_0.9_sent_previous_60_days
#  0    2007-01-11                                 NaN
#  1    2007-01-12                                 NaN
#  2    2007-01-13                                 NaN
#  3    2007-01-14                                 NaN
#  4    2007-01-15                                 NaN
#  ...         ...                                 ...
#  5700 2022-08-20                             0.65796
#  5701 2022-08-21                             0.73009
#  5702 2022-08-22                             0.67050
#  5703 2022-08-23                             0.65002
#  5704 2022-08-24                             0.67050
#
#  [5705 rows x 2 columns],
#             date  quantile_0.95_sent_previous_60_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5700 2022-08-20                              0.81228
#  5701 2022-08-21                              0.81182
#  5702 2022-08-22                              0.78850
#  5703 2022-08-23                              0.76941
#  5704 2022-08-24                              0.78450
#
#  [5705 rows x 2 columns],
#             date  mean_sent_previous_60_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5700 2022-08-20                    0.010948
#  5701 2022-08-21                    0.056071
#  5702 2022-08-22                   -0.008316
#  5703 2022-08-23                   -0.002707
#  5704 2022-08-24                   -0.020259
#
#  [5705 rows x 2 columns],
#             date  min_sent_previous_60_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                    -0.9423
#  5701 2022-08-21                    -0.9657
#  5702 2022-08-22                    -0.9370
#  5703 2022-08-23                    -0.9584
#  5704 2022-08-24                    -0.9712
#
#  [5705 rows x 2 columns],
#             date  max_sent_previous_60_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                     0.9477
#  5701 2022-08-21                     0.9497
#  5702 2022-08-22                     0.9984
#  5703 2022-08-23                     0.9779
#  5704 2022-08-24                     0.9470
#
#  [5705 rows x 2 columns],
#             date  sum_sent_previous_60_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                     5.9337
#  5701 2022-08-21                    29.3811
#  5702 2022-08-22                    -4.1165
#  5703 2022-08-23                    -1.1233
#  5704 2022-08-24                    -5.4902
#
#  [5705 rows x 2 columns],
#             date  count_sent_previous_60_days
#  0    2007-01-11                          NaN
#  1    2007-01-12                          NaN
#  2    2007-01-13                          NaN
#  3    2007-01-14                          NaN
#  4    2007-01-15                          NaN
#  ...         ...                          ...
#  5700 2022-08-20                        542.0
#  5701 2022-08-21                        524.0
#  5702 2022-08-22                        495.0
#  5703 2022-08-23                        415.0
#  5704 2022-08-24                        271.0
#
#  [5705 rows x 2 columns],
#             date  range_sent_previous_60_days
#  0    2007-01-11                          NaN
#  1    2007-01-12                          NaN
#  2    2007-01-13                          NaN
#  3    2007-01-14                          NaN
#  4    2007-01-15                          NaN
#  ...         ...                          ...
#  5700 2022-08-20                       1.8900
#  5701 2022-08-21                       1.9154
#  5702 2022-08-22                       1.9354
#  5703 2022-08-23                       1.9363
#  5704 2022-08-24                       1.9182
#
#  [5705 rows x 2 columns],
#             date  var_sent_previous_60_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
# ...
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                    17.0575
#  5701 2022-08-21                    39.9337
#  5702 2022-08-22                    22.7827
#  5703 2022-08-23                    16.0766
#  5704 2022-08-24                    14.0511
#
#  [5705 rows x 2 columns],
#             date  count_sent_previous_90_days
#  0    2007-01-11                          NaN
#  1    2007-01-12                          NaN
#  2    2007-01-13                          NaN
#  3    2007-01-14                          NaN
#  4    2007-01-15                          NaN
#  ...         ...                          ...
#  5700 2022-08-20                        463.0
#  5701 2022-08-21                        730.0
#  5702 2022-08-22                        769.0
#  5703 2022-08-23                        637.0
#  5704 2022-08-24                        412.0
#
#  [5705 rows x 2 columns],
#             date  range_sent_previous_90_days
#  0    2007-01-11                          NaN
#  1    2007-01-12                          NaN
#  2    2007-01-13                          NaN
#  3    2007-01-14                          NaN
#  4    2007-01-15                          NaN
#  ...         ...                          ...
#  5700 2022-08-20                       1.9065
#  5701 2022-08-21                       1.9614
#  5702 2022-08-22                       1.9169
#  5703 2022-08-23                       1.9188
#  5704 2022-08-24                       1.9282
#
#  [5705 rows x 2 columns],
#             date  var_sent_previous_90_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                   0.207131
#  5701 2022-08-21                   0.210381
#  5702 2022-08-22                   0.180356
#  5703 2022-08-23                   0.208944
#  5704 2022-08-24                   0.240897
#
#  [5705 rows x 2 columns],
#             date  std_sent_previous_90_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                   0.454624
#  5701 2022-08-21                   0.458359
#  5702 2022-08-22                   0.424407
#  5703 2022-08-23                   0.456745
#  5704 2022-08-24                   0.490217
#
#  [5705 rows x 2 columns],
#             date  iqr_sent_previous_90_days
#  0    2007-01-11                        NaN
#  1    2007-01-12                        NaN
#  2    2007-01-13                        NaN
#  3    2007-01-14                        NaN
#  4    2007-01-15                        NaN
#  ...         ...                        ...
#  5700 2022-08-20                   0.655000
#  5701 2022-08-21                   0.682075
#  5702 2022-08-22                   0.613200
#  5703 2022-08-23                   0.655000
#  5704 2022-08-24                   0.761500
#
#  [5705 rows x 2 columns],
#             date  quantile_0.05_sent_previous_120_days
#  0    2007-01-11                                   NaN
#  1    2007-01-12                                   NaN
#  2    2007-01-13                                   NaN
#  3    2007-01-14                                   NaN
#  4    2007-01-15                                   NaN
#  ...         ...                                   ...
#  5700 2022-08-20                              -0.85910
#  5701 2022-08-21                              -0.86890
#  5702 2022-08-22                              -0.85890
#  5703 2022-08-23                              -0.81072
#  5704 2022-08-24                              -0.75790
#
#  [5705 rows x 2 columns],
#             date  quantile_0.1_sent_previous_120_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5700 2022-08-20                             -0.72690
#  5701 2022-08-21                             -0.79738
#  5702 2022-08-22                             -0.77595
#  5703 2022-08-23                             -0.68778
#  5704 2022-08-24                             -0.58590
#
#  [5705 rows x 2 columns],
#             date  quantile_0.2_sent_previous_120_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5700 2022-08-20                              -0.5267
#  5701 2022-08-21                              -0.5930
#  5702 2022-08-22                              -0.5908
#  5703 2022-08-23                              -0.4767
#  5704 2022-08-24                              -0.4019
#
#  [5705 rows x 2 columns],
#             date  quantile_0.3_sent_previous_120_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5700 2022-08-20                             -0.33780
#  5701 2022-08-21                             -0.36980
#  5702 2022-08-22                             -0.44630
#  5703 2022-08-23                             -0.25000
#  5704 2022-08-24                             -0.22554
#
#  [5705 rows x 2 columns],
#             date  quantile_0.4_sent_previous_120_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5700 2022-08-20                             -0.05160
#  5701 2022-08-21                             -0.01836
#  5702 2022-08-22                             -0.19300
#  5703 2022-08-23                              0.00000
#  5704 2022-08-24                              0.00000
#
#  [5705 rows x 2 columns],
#             date  quantile_0.5_sent_previous_120_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5700 2022-08-20                                  0.0
#  5701 2022-08-21                                  0.0
#  5702 2022-08-22                                  0.0
#  5703 2022-08-23                                  0.0
#  5704 2022-08-24                                  0.0
#
#  [5705 rows x 2 columns],
#             date  quantile_0.6_sent_previous_120_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5700 2022-08-20                              0.02220
#  5701 2022-08-21                              0.07720
#  5702 2022-08-22                              0.15310
#  5703 2022-08-23                              0.10270
#  5704 2022-08-24                              0.15008
#
#  [5705 rows x 2 columns],
#             date  quantile_0.7_sent_previous_120_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5700 2022-08-20                              0.27320
#  5701 2022-08-21                              0.31820
#  5702 2022-08-22                              0.38180
#  5703 2022-08-23                              0.36120
#  5704 2022-08-24                              0.40982
#
#  [5705 rows x 2 columns],
#             date  quantile_0.8_sent_previous_120_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5700 2022-08-20                              0.44230
#  5701 2022-08-21                              0.51382
#  5702 2022-08-22                              0.59940
#  5703 2022-08-23                              0.50308
#  5704 2022-08-24                              0.54862
#
#  [5705 rows x 2 columns],
#             date  quantile_0.9_sent_previous_120_days
#  0    2007-01-11                                  NaN
#  1    2007-01-12                                  NaN
#  2    2007-01-13                                  NaN
#  3    2007-01-14                                  NaN
#  4    2007-01-15                                  NaN
#  ...         ...                                  ...
#  5700 2022-08-20                              0.63690
#  5701 2022-08-21                              0.70776
#  5702 2022-08-22                              0.75430
#  5703 2022-08-23                              0.73060
#  5704 2022-08-24                              0.71764
#
#  [5705 rows x 2 columns],
#             date  quantile_0.95_sent_previous_120_days
#  0    2007-01-11                                   NaN
#  1    2007-01-12                                   NaN
#  2    2007-01-13                                   NaN
#  3    2007-01-14                                   NaN
#  4    2007-01-15                                   NaN
#  ...         ...                                   ...
#  5700 2022-08-20                              0.757900
#  5701 2022-08-21                              0.808440
#  5702 2022-08-22                              0.846125
#  5703 2022-08-23                              0.814415
#  5704 2022-08-24                              0.803170
#
#  [5705 rows x 2 columns],
#             date  mean_sent_previous_120_days
#  0    2007-01-11                          NaN
#  1    2007-01-12                          NaN
#  2    2007-01-13                          NaN
#  3    2007-01-14                          NaN
#  4    2007-01-15                          NaN
#  ...         ...                          ...
#  5700 2022-08-20                    -0.024616
#  5701 2022-08-21                    -0.018205
#  5702 2022-08-22                    -0.010266
#  5703 2022-08-23                     0.034963
#  5704 2022-08-24                     0.055819
#
#  [5705 rows x 2 columns],
#             date  min_sent_previous_120_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5700 2022-08-20                     -0.9649
#  5701 2022-08-21                     -0.9720
#  5702 2022-08-22                     -0.9457
#  5703 2022-08-23                     -0.9705
#  5704 2022-08-24                     -0.9538
#
#  [5705 rows x 2 columns],
#             date  max_sent_previous_120_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5700 2022-08-20                      0.9693
#  5701 2022-08-21                      0.9337
#  5702 2022-08-22                      0.9702
#  5703 2022-08-23                      0.9529
#  5704 2022-08-24                      0.9442
#
#  [5705 rows x 2 columns],
#             date  sum_sent_previous_120_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5700 2022-08-20                    -10.3633
#  5701 2022-08-21                     -4.4603
#  5702 2022-08-22                     -2.9360
#  5703 2022-08-23                     16.4325
#  5704 2022-08-24                     23.1648
#
#  [5705 rows x 2 columns],
#             date  count_sent_previous_120_days
#  0    2007-01-11                           NaN
#  1    2007-01-12                           NaN
#  2    2007-01-13                           NaN
#  3    2007-01-14                           NaN
#  4    2007-01-15                           NaN
#  ...         ...                           ...
#  5700 2022-08-20                         421.0
#  5701 2022-08-21                         245.0
#  5702 2022-08-22                         286.0
#  5703 2022-08-23                         470.0
#  5704 2022-08-24                         415.0
#
#  [5705 rows x 2 columns],
#             date  range_sent_previous_120_days
#  0    2007-01-11                           NaN
#  1    2007-01-12                           NaN
#  2    2007-01-13                           NaN
#  3    2007-01-14                           NaN
#  4    2007-01-15                           NaN
#  ...         ...                           ...
#  5700 2022-08-20                        1.9342
#  5701 2022-08-21                        1.9057
#  5702 2022-08-22                        1.9159
#  5703 2022-08-23                        1.9234
#  5704 2022-08-24                        1.8980
#
#  [5705 rows x 2 columns],
#             date  var_sent_previous_120_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5700 2022-08-20                    0.241993
#  5701 2022-08-21                    0.282052
#  5702 2022-08-22                    0.316773
#  5703 2022-08-23                    0.244661
#  5704 2022-08-24                    0.231567
#
#  [5705 rows x 2 columns],
#             date  std_sent_previous_120_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5700 2022-08-20                    0.491343
#  5701 2022-08-21                    0.530000
#  5702 2022-08-22                    0.561841
#  5703 2022-08-23                    0.494106
#  5704 2022-08-24                    0.480634
#
#  [5705 rows x 2 columns],
#             date  iqr_sent_previous_120_days
#  0    2007-01-11                         NaN
#  1    2007-01-12                         NaN
#  2    2007-01-13                         NaN
#  3    2007-01-14                         NaN
#  4    2007-01-15                         NaN
#  ...         ...                         ...
#  5700 2022-08-20                     0.76310
#  5701 2022-08-21                     0.84640
#  5702 2022-08-22                     1.02875
#  5703 2022-08-23                     0.79630
#  5704 2022-08-24                     0.75480
#
#  [5705 rows x 2 columns]]

# %%
##merge all data.frames
from functools import reduce

#merge them using reduce
df_merged = reduce(lambda left, right: pd.merge(left, right, on=['date'], how='inner'), [element for element in flat_list])
    #leave only those rows having date in the datasets of currency value and sentiment
    #https://stackoverflow.com/questions/44327999/python-pandas-merge-multiple-dataframes
df_merged
    #note that here the previous eur pricing can be different than the eur pricing of the previous row
    #because when merging we lose days without tweet sentiment, so there is no longer continuous days
# Out:
#            date  quantile_0.05_sent_previous_7_days  \
# 0    2007-01-11                                 NaN
# 1    2007-01-12                                 NaN
# 2    2007-01-13                                 NaN
# 3    2007-01-14                                 NaN
# 4    2007-01-15                                 NaN
# ...         ...                                 ...
# 5700 2022-08-20                           -0.831400
# 5701 2022-08-21                           -0.853130
# 5702 2022-08-22                           -0.789630
# 5703 2022-08-23                           -0.858075
# 5704 2022-08-24                           -0.831710
#
#       quantile_0.1_sent_previous_7_days  quantile_0.2_sent_previous_7_days  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 5700                           -0.77165                           -0.51060
# 5701                           -0.75498                           -0.51694
# 5702                           -0.63250                           -0.37356
# 5703                           -0.76500                           -0.44710
# 5704                           -0.68832                           -0.26182
#
#       quantile_0.3_sent_previous_7_days  quantile_0.4_sent_previous_7_days  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 5700                           -0.30850                            0.00000
# 5701                           -0.33218                           -0.13176
# 5702                           -0.01806                            0.00000
# 5703                           -0.15310                            0.00000
# 5704                            0.00000                            0.00000
#
#       quantile_0.5_sent_previous_7_days  quantile_0.6_sent_previous_7_days  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 5700                             0.0000                            0.17790
# 5701                             0.0000                            0.14690
# 5702                             0.0000                            0.24856
# 5703                             0.0000                            0.12800
# 5704                             0.1779                            0.17790
#
#       quantile_0.7_sent_previous_7_days  quantile_0.8_sent_previous_7_days  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 5700                            0.39760                            0.47670
# 5701                            0.40190                            0.45880
# 5702                            0.44040                            0.58310
# 5703                            0.37445                            0.47670
# 5704                            0.17790                            0.37568
#
#       ...  quantile_0.95_sent_previous_120_days  mean_sent_previous_120_days  \
# 0     ...                                   NaN                          NaN
# 1     ...                                   NaN                          NaN
# 2     ...                                   NaN                          NaN
# 3     ...                                   NaN                          NaN
# 4     ...                                   NaN                          NaN
# ...   ...                                   ...                          ...
# 5700  ...                              0.757900                    -0.024616
# 5701  ...                              0.808440                    -0.018205
# 5702  ...                              0.846125                    -0.010266
# 5703  ...                              0.814415                     0.034963
# 5704  ...                              0.803170                     0.055819
#
#       min_sent_previous_120_days  max_sent_previous_120_days  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
# ...                          ...                         ...
# 5700                     -0.9649                      0.9693
# 5701                     -0.9720                      0.9337
# 5702                     -0.9457                      0.9702
# 5703                     -0.9705                      0.9529
# 5704                     -0.9538                      0.9442
#
#       sum_sent_previous_120_days  count_sent_previous_120_days  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# ...                          ...                           ...
# 5700                    -10.3633                         421.0
# 5701                     -4.4603                         245.0
# 5702                     -2.9360                         286.0
# 5703                     16.4325                         470.0
# 5704                     23.1648                         415.0
#
#       range_sent_previous_120_days  var_sent_previous_120_days  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 5700                        1.9342                    0.241993
# 5701                        1.9057                    0.282052
# 5702                        1.9159                    0.316773
# 5703                        1.9234                    0.244661
# 5704                        1.8980                    0.231567
#
#       std_sent_previous_120_days  iqr_sent_previous_120_days
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
# ...                          ...                         ...
# 5700                    0.491343                     0.76310
# 5701                    0.530000                     0.84640
# 5702                    0.561841                     1.02875
# 5703                    0.494106                     0.79630
# 5704                    0.480634                     0.75480
#
# [5705 rows x 121 columns]

# %%
df_merged = df_merged.dropna()
df_merged
# Out:
#            date  quantile_0.05_sent_previous_7_days  \
# 715  2008-12-26                           -0.421500
# 742  2009-01-22                           -0.510600
# 751  2009-01-31                            0.002580
# 758  2009-02-07                           -0.650780
# 762  2009-02-11                           -0.664905
# ...         ...                                 ...
# 5700 2022-08-20                           -0.831400
# 5701 2022-08-21                           -0.853130
# 5702 2022-08-22                           -0.789630
# 5703 2022-08-23                           -0.858075
# 5704 2022-08-24                           -0.831710
#
#       quantile_0.1_sent_previous_7_days  quantile_0.2_sent_previous_7_days  \
# 715                            -0.42150                           -0.27320
# 742                            -0.51060                           -0.29600
# 751                             0.00516                            0.01032
# 758                            -0.61076                           -0.55740
# 762                            -0.61131                           -0.24236
# ...                                 ...                                ...
# 5700                           -0.77165                           -0.51060
# 5701                           -0.75498                           -0.51694
# 5702                           -0.63250                           -0.37356
# 5703                           -0.76500                           -0.44710
# 5704                           -0.68832                           -0.26182
#
#       quantile_0.3_sent_previous_7_days  quantile_0.4_sent_previous_7_days  \
# 715                             0.00000                            0.00000
# 742                            -0.29600                           -0.29600
# 751                             0.01548                            0.02064
# 758                            -0.55740                           -0.55740
# 762                            -0.13553                           -0.05120
# ...                                 ...                                ...
# 5700                           -0.30850                            0.00000
# 5701                           -0.33218                           -0.13176
# 5702                           -0.01806                            0.00000
# 5703                           -0.15310                            0.00000
# 5704                            0.00000                            0.00000
#
#       quantile_0.5_sent_previous_7_days  quantile_0.6_sent_previous_7_days  \
# 715                              0.0000                            0.00000
# 742                             -0.1396                           -0.04128
# 751                              0.0258                            0.03096
# 758                             -0.5574                           -0.54834
# 762                              0.0000                            0.00000
# ...                                 ...                                ...
# 5700                             0.0000                            0.17790
# 5701                             0.0000                            0.14690
# 5702                             0.0000                            0.24856
# 5703                             0.0000                            0.12800
# 5704                             0.1779                            0.17790
#
#       quantile_0.7_sent_previous_7_days  quantile_0.8_sent_previous_7_days  \
# 715                             0.00000                            0.27320
# 742                             0.20230                            0.30622
# 751                             0.03612                            0.04128
# 758                            -0.47910                           -0.28950
# 762                             0.06789                            0.25740
# ...                                 ...                                ...
# 5700                            0.39760                            0.47670
# 5701                            0.40190                            0.45880
# 5702                            0.44040                            0.58310
# 5703                            0.37445                            0.47670
# 5704                            0.17790                            0.37568
#
#       ...  quantile_0.95_sent_previous_120_days  mean_sent_previous_120_days  \
# 715   ...                              0.212500                    -0.152625
# 742   ...                              0.000000                     0.000000
# 751   ...                              0.241780                    -0.298086
# 758   ...                              0.700380                    -0.101120
# 762   ...                              0.000000                    -0.221733
# ...   ...                                   ...                          ...
# 5700  ...                              0.757900                    -0.024616
# 5701  ...                              0.808440                    -0.018205
# 5702  ...                              0.846125                    -0.010266
# 5703  ...                              0.814415                     0.034963
# 5704  ...                              0.803170                     0.055819
#
#       min_sent_previous_120_days  max_sent_previous_120_days  \
# 715                      -0.5423                      0.2500
# 742                       0.0000                      0.0000
# 751                      -0.6808                      0.6908
# 758                      -0.5719                      0.8189
# 762                      -0.6652                      0.0000
# ...                          ...                         ...
# 5700                     -0.9649                      0.9693
# 5701                     -0.9720                      0.9337
# 5702                     -0.9457                      0.9702
# 5703                     -0.9705                      0.9529
# 5704                     -0.9538                      0.9442
#
#       sum_sent_previous_120_days  count_sent_previous_120_days  \
# 715                      -0.6105                           4.0
# 742                       0.0000                           2.0
# 751                      -4.1732                          14.0
# 758                      -0.5056                           5.0
# 762                      -0.6652                           3.0
# ...                          ...                           ...
# 5700                    -10.3633                         421.0
# 5701                     -4.4603                         245.0
# 5702                     -2.9360                         286.0
# 5703                     16.4325                         470.0
# 5704                     23.1648                         415.0
#
#       range_sent_previous_120_days  var_sent_previous_120_days  \
# 715                         0.7923                    0.121554
# 742                         0.0000                    0.000000
# 751                         1.3716                    0.131047
# 758                         1.3908                    0.371527
# 762                         0.6652                    0.147497
# ...                            ...                         ...
# 5700                        1.9342                    0.241993
# 5701                        1.9057                    0.282052
# 5702                        1.9159                    0.316773
# 5703                        1.9234                    0.244661
# 5704                        1.8980                    0.231567
#
#       std_sent_previous_120_days  iqr_sent_previous_120_days
# 715                     0.301937                    0.436725
# 742                     0.000000                    0.000000
# 751                     0.348836                    0.276950
# 758                     0.545181                    0.783700
# 762                     0.313578                    0.332600
# ...                          ...                         ...
# 5700                    0.491343                    0.763100
# 5701                    0.530000                    0.846400
# 5702                    0.561841                    1.028750
# 5703                    0.494106                    0.796300
# 5704                    0.480634                    0.754800
#
# [4898 rows x 121 columns]

# %%
#check that all days with just 1 tweet have std=0
#np.unique(df_merged[df_merged["count_sent"] == 1]["std_sent"]) == 0

# %%
'''
##plot the metrics
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

#for each metric
for metric in metrics_sentiment:
    
    #open a plot with two panels
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15,4))

    #plot scatter against date and eur pricing
    ax1.scatter(x=df_merged["date"], y=df_merged[metric + "_sent"], s=0.5)
    ax2.scatter(x=df_merged["percent_change_pricing"], y=df_merged[metric + "_sent"], s=0.5)
    
    #set ylabel
    ax1.set_ylabel(metric + " negative sentiment")
    ax1.set_xlabel("Year")
    ax2.set_ylabel(metric + " negative sentiment")
    ax2.set_xlabel("Percent change in EUR/USD exchange rate")
    
    #close
    plt.show()
'''
# Out:
# '\n##plot the metrics\nimport matplotlib.pyplot as plt\nfrom matplotlib.pyplot import figure\n\n#for each metric\nfor metric in metrics_sentiment:\n    \n    #open a plot with two panels\n    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15,4))\n\n    #plot scatter against date and eur pricing\n    ax1.scatter(x=df_merged["date"], y=df_merged[metric + "_sent"], s=0.5)\n    ax2.scatter(x=df_merged["percent_change_pricing"], y=df_merged[metric + "_sent"], s=0.5)\n    \n    #set ylabel\n    ax1.set_ylabel(metric + " negative sentiment")\n    ax1.set_xlabel("Year")\n    ax2.set_ylabel(metric + " negative sentiment")\n    ax2.set_xlabel("Percent change in EUR/USD exchange rate")\n    \n    #close\n    plt.show()\n'

# %% [markdown]
# Mean shows that low currency values tend to be associated with high negative sentiment. As the value increase, there is more variation. With more negative but specially much more less negative days. This is even clearer for max. The main difference is that high currency values are associated with a lot of 0 negative days.
#
# It seems that once economic problems arise, then worries extend across economic agents and hence twitter, making less likely to have positive/neutral tweets.

# %%
#save the final data.frame with all metrics and eur pricing
df_merged.to_csv("results/twitter_sentiment_data.csv.gz", compression="gzip", index=False)
#df_merged = pd.read_csv("results/twitter_sentiment_data.csv.gz", compression="gzip")
